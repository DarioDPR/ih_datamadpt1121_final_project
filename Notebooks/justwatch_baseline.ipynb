# %%
import pandas as pd
from justwatch import JustWatch

# %%
proveedores = ['hbm']#nfx', 'dnp', 'dnp']
just_watch = JustWatch(country='ES', providers = proveedores)

# %%
just_watch.get_providers()
# Out:
# [{'id': 8,
#   'technical_name': 'netflix',
#   'short_name': 'nfx',
#   'clear_name': 'Netflix',
#   'display_priority': 1,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/207360008/{profile}',
#   'icon_blur_hash': 'KVBJXFjt1^jto1a|A;a|,Z',
#   'slug': 'netflix',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 119,
#   'technical_name': 'amazonprimevideo',
#   'short_name': 'prv',
#   'clear_name': 'Amazon Prime Video',
#   'display_priority': 2,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/52449861/{profile}',
#   'icon_blur_hash': 'KMQAQ@%M~Ux]WCjF~qj[IU',
#   'slug': 'amazon-prime-video',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': ['asf',
#    'ask',
#    'asb',
#    'acu',
#    'avt',
#    'aum',
#    'aft',
#    'aoc',
#    'abb',
#    'ang',
#    'abf',
#    'bpc',
#    'asm',
#    'ach',
#    'anh',
#    'ame',
#    'app',
#    'apo',
#    'aot',
#    'aln',
#    'afg',
#    'apg',
#    'aac',
#    'abo',
#    'alo',
#    'apm',
#    'aim',
#    'azp',
#    'azt',
#    'aep',
#    'aav',
#    'ahh',
#    'adp',
#    'ait',
#    'ado',
#    'ast',
#    'apk',
#    'ahm',
#    'ahy',
#    'amg',
#    'ash',
#    'asn',
#    'ahb',
#    'abp',
#    'nic',
#    'afm',
#    'abe',
#    'agc',
#    'aan',
#    'acb',
#    'afb',
#    'afl',
#    'amu',
#    'aen',
#    'azh',
#    'fac',
#    'aah',
#    'acs',
#    'asu',
#    'acm',
#    'afa',
#    'asd',
#    'apa',
#    'abm',
#    'adw',
#    'acn'],
#   'parent_packages': None},
#  {'id': 337,
#   'technical_name': 'disneyplus',
#   'short_name': 'dnp',
#   'clear_name': 'Disney Plus',
#   'display_priority': 3,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/147638351/{profile}',
#   'icon_blur_hash': 'KQ5=;uogRNR1f5ohIUWBt6',
#   'slug': 'disney-plus',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 257,
#   'technical_name': 'fubotv',
#   'short_name': 'fuv',
#   'clear_name': 'fuboTV',
#   'display_priority': 4,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/124248862/{profile}',
#   'icon_blur_hash': 'L~K@38j[1IayoLfQayfQaKf6kWfk',
#   'slug': 'fubotv',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 2,
#   'technical_name': 'itunes',
#   'short_name': 'itu',
#   'clear_name': 'Apple iTunes',
#   'display_priority': 5,
#   'priority': 0,
#   'monetization_types': ['rent', 'buy'],
#   'icon_url': '/icon/190848813/{profile}',
#   'icon_blur_hash': 'KSA^OK%MIUoffQay00M{%M',
#   'slug': 'apple-itunes',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 350,
#   'technical_name': 'appletvplus',
#   'short_name': 'atp',
#   'clear_name': 'Apple TV Plus',
#   'display_priority': 6,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/152862153/{profile}',
#   'icon_blur_hash': 'KH7w?1%MIUj[j[ay00IUxu',
#   'slug': 'apple-tv-plus',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 223,
#   'technical_name': 'hayu',
#   'short_name': 'hay',
#   'clear_name': 'hayu',
#   'display_priority': 7,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/89154446/{profile}',
#   'icon_blur_hash': 'KdRCMd#S.mpcS#rru4kqR6',
#   'slug': 'hayu',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 63,
#   'technical_name': 'filmin',
#   'short_name': 'fil',
#   'clear_name': 'Filmin',
#   'display_priority': 8,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/187161245/{profile}',
#   'icon_blur_hash': 'Ka72{LJ5n6kBa{f7D6$lXQ',
#   'slug': 'filmin',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 64,
#   'technical_name': 'filminplus',
#   'short_name': 'fip',
#   'clear_name': 'Filmin Plus',
#   'display_priority': 9,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/188383996/{profile}',
#   'icon_blur_hash': 'KS7et-JOVajFoLbHD5w~o|',
#   'slug': 'filmin-plus',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 384,
#   'technical_name': 'hbomax',
#   'short_name': 'hbm',
#   'clear_name': 'HBO Max',
#   'display_priority': 10,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/182948653/{profile}',
#   'icon_blur_hash': 'KI9@PAog4m_2jtD%D}WTxv',
#   'slug': 'hbo-max',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 149,
#   'technical_name': 'movistar',
#   'short_name': 'mvs',
#   'clear_name': 'Movistar Plus',
#   'display_priority': 11,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/5985414/{profile}',
#   'icon_blur_hash': 'KYQTDoM{-pRkf6of~p%MM|',
#   'slug': 'movistar-plus',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 35,
#   'technical_name': 'wuaki',
#   'short_name': 'wki',
#   'clear_name': 'Rakuten TV',
#   'display_priority': 12,
#   'priority': 0,
#   'monetization_types': ['rent', 'buy', 'flatrate'],
#   'icon_url': '/icon/128599720/{profile}',
#   'icon_blur_hash': 'KVNtRli_D4oLozozHrj[x]',
#   'slug': 'rakuten-tv',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 62,
#   'technical_name': 'atres',
#   'short_name': 'atr',
#   'clear_name': 'Atres Player',
#   'display_priority': 14,
#   'priority': 0,
#   'monetization_types': ['ads', 'flatrate'],
#   'icon_url': '/icon/179272126/{profile}',
#   'icon_blur_hash': 'K64_hC-;R*t7ofay0KIAof',
#   'slug': 'atres-player',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 3,
#   'technical_name': 'play',
#   'short_name': 'ply',
#   'clear_name': 'Google Play Movies',
#   'display_priority': 15,
#   'priority': 0,
#   'monetization_types': ['rent', 'buy'],
#   'icon_url': '/icon/169478387/{profile}',
#   'icon_blur_hash': 'KSQ,j#Ac~XK#JB$S%MxBMe',
#   'slug': 'google-play-movies',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 68,
#   'technical_name': 'microsoft',
#   'short_name': 'msf',
#   'clear_name': 'Microsoft Store',
#   'display_priority': 16,
#   'priority': 0,
#   'monetization_types': ['buy', 'rent'],
#   'icon_url': '/icon/820542/{profile}',
#   'icon_blur_hash': 'KYDBUIof0NWFjuWC4qWC?Y',
#   'slug': 'microsoft-store',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 11,
#   'technical_name': 'mubi',
#   'short_name': 'mbi',
#   'clear_name': 'Mubi',
#   'display_priority': 17,
#   'priority': 0,
#   'monetization_types': ['flatrate', 'rent'],
#   'icon_url': '/icon/164970114/{profile}',
#   'icon_blur_hash': 'KF5rQpoiRib2axj@9DWCt7',
#   'slug': 'mubi',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 100,
#   'technical_name': 'guidedoc',
#   'short_name': 'gdc',
#   'clear_name': 'GuideDoc',
#   'display_priority': 18,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/2625277/{profile}',
#   'icon_blur_hash': 'KOB6fcS50NW?ayj[4=s:-n',
#   'slug': 'guidedoc',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 188,
#   'technical_name': 'youtubered',
#   'short_name': 'ytr',
#   'clear_name': 'YouTube Premium',
#   'display_priority': 19,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/70189310/{profile}',
#   'icon_blur_hash': 'KgRx[mof*JrDf6o}*Jj[Q-',
#   'slug': 'youtube-premium',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 393,
#   'technical_name': 'flixole',
#   'short_name': 'flx',
#   'clear_name': 'FlixOlé',
#   'display_priority': 20,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/273964237/{profile}',
#   'icon_blur_hash': 'KaS6DG-pt7%Mfij@_MOURj',
#   'slug': 'flixole',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 283,
#   'technical_name': 'crunchyroll',
#   'short_name': 'cru',
#   'clear_name': 'Crunchyroll',
#   'display_priority': 21,
#   'priority': 0,
#   'monetization_types': ['free'],
#   'icon_url': '/icon/127445869/{profile}',
#   'icon_blur_hash': 'KjSD4wozQRn$kCj]UvaKpJ',
#   'slug': 'crunchyroll',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': '',
#     'webos': '',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 190,
#   'technical_name': 'curiositystream',
#   'short_name': 'cts',
#   'clear_name': 'Curiosity Stream',
#   'display_priority': 22,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/48600036/{profile}',
#   'icon_blur_hash': 'KjS#6LoeiHn#fQkCU[f6em',
#   'slug': 'curiosity-stream',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 456,
#   'technical_name': 'mitele',
#   'short_name': 'mte',
#   'clear_name': 'Mitele ',
#   'display_priority': 23,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/202925890/{profile}',
#   'icon_blur_hash': 'KsKBO7oz00R%RjV[00oKxu',
#   'slug': 'mitele',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 457,
#   'technical_name': 'vixtv',
#   'short_name': 'vix',
#   'clear_name': 'VIX ',
#   'display_priority': 24,
#   'priority': 0,
#   'monetization_types': ['ads'],
#   'icon_url': '/icon/202926990/{profile}',
#   'icon_blur_hash': 'KI9QmxayIUofj[ay00j]%M',
#   'slug': 'vix',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 475,
#   'technical_name': 'docsville',
#   'short_name': 'dsv',
#   'clear_name': 'DOCSVILLE',
#   'display_priority': 25,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/208148387/{profile}',
#   'icon_blur_hash': 'KFS=u7xuuPxuj[bHuOaenj',
#   'slug': 'docsville',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 521,
#   'technical_name': 'spamflix',
#   'short_name': 'sfx',
#   'clear_name': 'Spamflix',
#   'display_priority': 101,
#   'priority': 0,
#   'monetization_types': ['rent'],
#   'icon_url': '/icon/240831409/{profile}',
#   'icon_blur_hash': 'KY1hy+fjU[cOfRilbBfPjf',
#   'slug': 'spamflix',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 194,
#   'technical_name': 'amazonstarzplay',
#   'short_name': 'ast',
#   'clear_name': 'Starz Play Amazon Channel',
#   'display_priority': 1003,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/241732487/{profile}',
#   'icon_blur_hash': 'KyHx$%ayWB00j[WB-;ayof',
#   'slug': 'starz-play-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 541,
#   'technical_name': 'rtve',
#   'short_name': 'rtv',
#   'clear_name': 'rtve',
#   'display_priority': 1005,
#   'priority': 0,
#   'monetization_types': ['free'],
#   'icon_url': '/icon/243087006/{profile}',
#   'icon_blur_hash': 'KTSe]X%chyyBkBaJZgfjk?',
#   'slug': 'rtve',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 538,
#   'technical_name': 'plex',
#   'short_name': 'plx',
#   'clear_name': 'Plex',
#   'display_priority': 1006,
#   'priority': 0,
#   'monetization_types': ['free'],
#   'icon_url': '/icon/243059301/{profile}',
#   'icon_blur_hash': 'KJ9tM+o#IUj[j[j[01V?%M',
#   'slug': 'plex',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 546,
#   'technical_name': 'wowpresentsplus',
#   'short_name': 'wow',
#   'clear_name': 'WOW Presents Plus',
#   'display_priority': 1007,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/243229654/{profile}',
#   'icon_blur_hash': 'KZQ?aoxaae^Pjtj[UbaekC',
#   'slug': 'wow-presents-plus',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 551,
#   'technical_name': 'magellantv',
#   'short_name': 'mgl',
#   'clear_name': 'Magellan TV',
#   'display_priority': 1008,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/243233518/{profile}',
#   'icon_blur_hash': 'KF8q?BZ$9Fo}aeae00X9-p',
#   'slug': 'magellan-tv',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 554,
#   'technical_name': 'broadwayhd',
#   'short_name': 'bhd',
#   'clear_name': 'BroadwayHD',
#   'display_priority': 1009,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/243239329/{profile}',
#   'icon_blur_hash': 'KYCAn$tlPnM_baWUQ6RPq^',
#   'slug': 'broadwayhd',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 559,
#   'technical_name': 'filmzie',
#   'short_name': 'fmz',
#   'clear_name': 'Filmzie',
#   'display_priority': 1010,
#   'priority': 0,
#   'monetization_types': ['ads'],
#   'icon_url': '/icon/269433194/{profile}',
#   'icon_blur_hash': 'K43ufijuNHoejtay0Na{xZ',
#   'slug': 'filmzie',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 444,
#   'technical_name': 'dekkoo',
#   'short_name': 'dkk',
#   'clear_name': 'Dekkoo',
#   'display_priority': 1011,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/202068207/{profile}',
#   'icon_blur_hash': 'KHQm0MoM?^{xo0O?.mt7R5',
#   'slug': 'dekkoo',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 567,
#   'technical_name': 'truestory',
#   'short_name': 'trs',
#   'clear_name': 'True Story',
#   'display_priority': 1012,
#   'priority': 0,
#   'monetization_types': ['flatrate', 'rent'],
#   'icon_url': '/icon/244289819/{profile}',
#   'icon_blur_hash': 'K7J[9c~nt7%Moej[tV9JRj',
#   'slug': 'true-story',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 569,
#   'technical_name': 'dafilms',
#   'short_name': 'daf',
#   'clear_name': 'DocAlliance Films',
#   'display_priority': 1013,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/244290074/{profile}',
#   'icon_blur_hash': 'KjI5Y-ay00t7ofay4nt7t7',
#   'slug': 'docalliance-films',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 315,
#   'technical_name': 'hoichoi',
#   'short_name': 'hoc',
#   'clear_name': 'Hoichoi',
#   'display_priority': 1014,
#   'priority': 0,
#   'monetization_types': ['free'],
#   'icon_url': '/icon/141253805/{profile}',
#   'icon_blur_hash': 'KLR%r+=1y@=yniV@v2jFY5',
#   'slug': 'hoichoi',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 10,
#   'technical_name': 'amazon',
#   'short_name': 'amz',
#   'clear_name': 'Amazon Video',
#   'display_priority': 10004,
#   'priority': 0,
#   'monetization_types': ['buy', 'rent'],
#   'icon_url': '/icon/430993/{profile}',
#   'icon_blur_hash': 'KYPG%2-p-;~AIoNHXU%2s+',
#   'slug': 'amazon-video',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 43,
#   'technical_name': 'starz',
#   'short_name': 'stz',
#   'clear_name': 'Starz',
#   'display_priority': 10005,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/902247/{profile}',
#   'icon_blur_hash': 'KC7w.@WBD%xuWBay00WB-:',
#   'slug': 'starz',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 300,
#   'technical_name': 'plutotv',
#   'short_name': 'ptv',
#   'clear_name': 'Pluto TV',
#   'display_priority': 10007,
#   'priority': 0,
#   'monetization_types': ['ads'],
#   'icon_url': '/icon/131862988/{profile}',
#   'icon_blur_hash': 'KMBg3uj[00j[fQ%M4nay-;',
#   'slug': 'pluto-tv',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 524,
#   'technical_name': 'discoverypluseurope',
#   'short_name': 'dpe',
#   'clear_name': 'Discovery Plus',
#   'display_priority': 10009,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/241126382/{profile}',
#   'icon_blur_hash': 'KYDvKBIx4.#RbEOr0Kxm-o',
#   'slug': 'discovery-plus',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 677,
#   'technical_name': 'eventive',
#   'short_name': 'eve',
#   'clear_name': 'Eventive',
#   'display_priority': 10010,
#   'priority': 0,
#   'monetization_types': ['rent', 'free'],
#   'icon_url': '/icon/258768419/{profile}',
#   'icon_blur_hash': 'KRB~h^x]03tSR+V]4qM|%K',
#   'slug': 'eventive',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 296,
#   'technical_name': 'amazonhayu',
#   'short_name': 'ahy',
#   'clear_name': 'Hayu Amazon Channel',
#   'display_priority': 10011,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/241732559/{profile}',
#   'icon_blur_hash': 'K#I5MbozRj00ofWB-;WBt7',
#   'slug': 'hayu-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 201,
#   'technical_name': 'amazonmubi',
#   'short_name': 'amu',
#   'clear_name': 'Mubi Amazon Channel',
#   'display_priority': 10012,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/241732473/{profile}',
#   'icon_blur_hash': 'KzGb-]azWB02fRWB?Zayof',
#   'slug': 'mubi-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 607,
#   'technical_name': 'amazonouttv',
#   'short_name': 'aot',
#   'clear_name': 'OUTtv Amazon Channel',
#   'display_priority': 10013,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/248045085/{profile}',
#   'icon_blur_hash': 'KxJR8WodE14ToeNG.8WCxa',
#   'slug': 'outtv-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 196,
#   'technical_name': 'amazonacorntv',
#   'short_name': 'aac',
#   'clear_name': 'AcornTV Amazon Channel',
#   'display_priority': 10014,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/241732555/{profile}',
#   'icon_blur_hash': 'K$GSDmW;ax00fkWB?bayof',
#   'slug': 'acorntv-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 262,
#   'technical_name': 'amazonnoggin',
#   'short_name': 'ang',
#   'clear_name': 'Noggin Amazon Channel',
#   'display_priority': 10015,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/241732611/{profile}',
#   'icon_blur_hash': 'K+F=:paybE00j[WU?aayoN',
#   'slug': 'noggin-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 588,
#   'technical_name': 'amazonmgm',
#   'short_name': 'amg',
#   'clear_name': 'MGM Amazon Channel',
#   'display_priority': 10016,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/246682790/{profile}',
#   'icon_blur_hash': 'KmJ*uAayWB00j[WB%Mayof',
#   'slug': 'mgm-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 684,
#   'technical_name': 'amazonflixole',
#   'short_name': 'afl',
#   'clear_name': 'FlixOlé Amazon Channel',
#   'display_priority': 10017,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/259252096/{profile}',
#   'icon_blur_hash': 'K*HU^IV@ay00jZWB.8kCof',
#   'slug': 'flixole-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 689,
#   'technical_name': 'amazontvcortos',
#   'short_name': 'atc',
#   'clear_name': 'TVCortos Amazon Channel',
#   'display_priority': 10018,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/260448137/{profile}',
#   'icon_blur_hash': 'K8SPU:%2?H~W%2fR?vIoRj',
#   'slug': 'tvcortos-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 692,
#   'technical_name': 'cultpix',
#   'short_name': 'ctx',
#   'clear_name': 'Cultpix',
#   'display_priority': 10019,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/264459628/{profile}',
#   'icon_blur_hash': 'KC6$v3oLJQsofQWo1uWV$Q',
#   'slug': 'cultpix',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 701,
#   'technical_name': 'filmbox',
#   'short_name': 'flb',
#   'clear_name': 'FilmBox+',
#   'display_priority': 10020,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/269959825/{profile}',
#   'icon_blur_hash': 'KmSrQ6pwpcoLaykC*Jm,VY',
#   'slug': 'filmbox',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None}]

# %%
peli_key = 'poli'
lista_pelis = just_watch.search_for_item(query=peli_key, content_types=['movie'], providers = proveedores, monetization_types=['flatrate'])

# %%
total_list = len(lista_pelis['items'])
total_list
# Out:
# 30

# %%
total_pelis = []
for item in range(total_list):
    total_pelis.append(lista_pelis['items'][item]['id'])
total_pelis
# Out:
# [177480,
#  132303,
#  110483,
#  295177,
#  113836,
#  56719,
#  101249,
#  142794,
#  14532,
#  166586,
#  36583,
#  455670,
#  361759,
#  54023,
#  267401,
#  197920,
#  157735,
#  15897,
#  56184,
#  130044,
#  68909,
#  68272,
#  143928,
#  114752,
#  43808,
#  77588,
#  42327,
#  244376,
#  40461,
#  1019345]

# %%
len(total_pelis)
# Out:
# 30

# %%
extra_info = []
for e in range(len(total_pelis)):
    try:
        peli = just_watch.get_title(title_id=total_pelis[e])
        extra_info.append(peli)
    except:
        extra_info.append('/-----------------------------no info-----------------------------------/')
extra_info
# Out:
# [{'jw_entity_id': 'tm177480',
#   'id': 177480,
#   'title': 'Loca academia de policía',
#   'full_path': '/es/pelicula/loca-academia-de-policia',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/loca-academia-de-policia'},
#   'poster': '/poster/187245208/{profile}',
#   'poster_blur_hash': 'T:PZfVoe%Mxaj[WB_NazM{R*WBoL',
#   'backdrops': [{'backdrop_url': '/backdrop/272920477/{profile}',
#     'backdrop_blur_hash': 'L;M@Aqoe~qWC%MkCNGay-:j[NGay'},
#    {'backdrop_url': '/backdrop/9030893/{profile}',
#     'backdrop_blur_hash': 'L9ATTKIAs+%NS%s:IVt601xuxuWA'},
#    {'backdrop_url': '/backdrop/48858248/{profile}',
#     'backdrop_blur_hash': 'LBCsy_t7R%01Ioox%etQbuWCRkog'},
#    {'backdrop_url': '/backdrop/9030892/{profile}',
#     'backdrop_blur_hash': 'L-NAk.of?HWV~qofIUfQx]R*aejt'},
#    {'backdrop_url': '/backdrop/9030899/{profile}',
#     'backdrop_blur_hash': 'LFC%pbozX34UInoy%ft7knWVRko3'}],
#   'short_description': 'En la academia de policía están a punto de finalizar sus pruebas preparatorias para el cuerpo un numeroso grupo de veteranos. Durante un tiempo, coinciden con los novatos de nuevo ingreso, que serán el centro de un montón de bromas que muchas veces se lo harán pasar muy mal.',
#   'original_release_year': 1984,
#   'object_type': 'movie',
#   'original_title': 'Police Academy',
#   'offers': [{'jw_entity_id': 'tm177480',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 8.99,
#     'last_change_retail_price': 10.99,
#     'last_change_difference': -2,
#     'last_change_percent': -18.198362,
#     'last_change_date': '2022-02-28',
#     'last_change_date_provider_id': '2022-02-28_2',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/loca-academia-de-policia/umc.cmc.1a7s1v11cwu2sz5d555kseg2z?playableId=tvs.sbd.9001%3A444665351',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Floca-academia-de-policia%2Fumc.cmc.1a7s1v11cwu2sz5d555kseg2z%3FplayableId%3Dtvs.sbd.9001%253A444665351&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm177480',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/loca-academia-de-policia/umc.cmc.1a7s1v11cwu2sz5d555kseg2z?playableId=tvs.sbd.9001%3A444665351',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Floca-academia-de-policia%2Fumc.cmc.1a7s1v11cwu2sz5d555kseg2z%3FplayableId%3Dtvs.sbd.9001%253A444665351&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm177480',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 7.99,
#     'last_change_retail_price': 4.99,
#     'last_change_difference': 3,
#     'last_change_percent': 60.12024,
#     'last_change_date': '2021-11-23',
#     'last_change_date_provider_id': '2021-11-23_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.5ebbafcc-0a06-b91b-d077-f69aebe03402',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.5ebbafcc-0a06-b91b-d077-f69aebe03402',
#      'deeplink_rokuos': 'launch/13?contentID=B08VPRNBXK&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm177480',
#     'monetization_type': 'rent',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.5ebbafcc-0a06-b91b-d077-f69aebe03402',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.5ebbafcc-0a06-b91b-d077-f69aebe03402',
#      'deeplink_rokuos': 'launch/13?contentID=B08VPRNBXK&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm177480',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 8.99,
#     'last_change_retail_price': 10.99,
#     'last_change_difference': -2,
#     'last_change_percent': -18.198362,
#     'last_change_date': '2022-02-25',
#     'last_change_date_provider_id': '2022-02-25_35',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/loca-academia-de-policia'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm177480',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 8.99,
#     'last_change_retail_price': 10.99,
#     'last_change_difference': -2,
#     'last_change_percent': -18.198362,
#     'last_change_date': '2022-02-25',
#     'last_change_date_provider_id': '2022-02-25_35',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/loca-academia-de-policia'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm177480',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/loca-academia-de-policia'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm177480',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/loca-academia-de-policia'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm177480',
#     'monetization_type': 'buy',
#     'provider_id': 68,
#     'package_short_name': 'msf',
#     'retail_price': 8.99,
#     'last_change_retail_price': 9.99,
#     'last_change_difference': -1,
#     'last_change_percent': -10.01001,
#     'last_change_date': '2022-03-03',
#     'last_change_date_provider_id': '2022-03-03_68',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.microsoft.com/es-es/p/loca-academia-de-policia/8d6kgwzl5fz6'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm177480',
#     'monetization_type': 'rent',
#     'provider_id': 68,
#     'package_short_name': 'msf',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.microsoft.com/es-es/p/loca-academia-de-policia/8d6kgwzl5fz6'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm177480',
#     'monetization_type': 'flatrate',
#     'provider_id': 384,
#     'package_short_name': 'hbm',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.hbomax.com/feature/urn:hbo:feature:GXemSegUy68PCwwEAAEaT',
#      'deeplink_rokuos': 'launch/61322?contentID=urn%3Ahbo%3Afeature%3AGXemSegUy68PCwwEAAEaT&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm177480',
#     'monetization_type': 'flatrate',
#     'provider_id': 384,
#     'package_short_name': 'hbm',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.hbomax.com/feature/urn:hbo:feature:GXemSegUy68PCwwEAAEaT',
#      'deeplink_rokuos': 'launch/61322?contentID=urn%3Ahbo%3Afeature%3AGXemSegUy68PCwwEAAEaT&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'tmdb:score', 'value': 6.6},
#    {'provider_type': 'imdb:multiplied', 'value': 828629.2000000001},
#    {'provider_type': 'imdb:popularity', 'value': 883},
#    {'provider_type': 'tmdb:popularity', 'value': 15.721},
#    {'provider_type': 'tmdb:id', 'value': 9336},
#    {'provider_type': 'imdb:score', 'value': 6.7},
#    {'provider_type': 'imdb:votes', 'value': 123676}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Cadet Carey Mahoney',
#     'person_id': 19841,
#     'name': 'Steve Guttenberg'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Karen Thompson',
#     'person_id': 19022,
#     'name': 'Kim Cattrall'},
#    {'role': 'ACTOR',
#     'character_name': 'Lt. Thaddeus Harris',
#     'person_id': 19843,
#     'name': 'G.W. Bailey'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Moses Hightower',
#     'person_id': 27036,
#     'name': 'Bubba Smith'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Leslie Barbara',
#     'person_id': 11350,
#     'name': 'Donovan Scott'},
#    {'role': 'ACTOR',
#     'character_name': 'Cmndt. Eric Lassard',
#     'person_id': 27037,
#     'name': 'George Gaynes'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet George Martín',
#     'person_id': 27038,
#     'name': 'Andrew Rubin'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Eugene Tackleberry',
#     'person_id': 27039,
#     'name': 'David Graf'},
#    {'role': 'ACTOR',
#     'character_name': 'Sgt. Debbie Callahan',
#     'person_id': 24556,
#     'name': 'Leslie Easterbrook'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Larvelle Jones',
#     'person_id': 14330,
#     'name': 'Michael Winslow'},
#    {'role': 'ACTOR',
#     'character_name': 'Mrs. Fackler',
#     'person_id': 27040,
#     'name': 'Debralee Scott'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Douglas Fackler',
#     'person_id': 27041,
#     'name': 'Bruce Mahler'},
#    {'role': 'ACTOR',
#     'character_name': 'Capt. Reed',
#     'person_id': 27042,
#     'name': 'Ted Ross'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Chad Copeland',
#     'person_id': 19400,
#     'name': 'Scott Thomson'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Kyle Blankes',
#     'person_id': 27043,
#     'name': 'Brant von Hoffman'},
#    {'role': 'ACTOR',
#     'character_name': 'Laverne Hooks',
#     'person_id': 27044,
#     'name': 'Marion Ramsey'},
#    {'role': 'ACTOR',
#     'character_name': 'Booking Sergeant',
#     'person_id': 27045,
#     'name': 'Roger Dunn'},
#    {'role': 'ACTOR',
#     'character_name': 'Mrs. Thompson',
#     'person_id': 593832,
#     'name': 'Joyce Gordon'},
#    {'role': 'ACTOR',
#     'character_name': 'Hooker',
#     'person_id': 239530,
#     'name': 'Georgina Spelvin'},
#    {'role': 'ACTOR',
#     'character_name': 'Angry Driver (uncredited)',
#     'person_id': 27046,
#     'name': 'Hugh Wilson'},
#    {'role': 'ACTOR',
#     'character_name': 'Tough (Uncredited)',
#     'person_id': 78986,
#     'name': 'T.J. Scott'},
#    {'role': 'ACTOR',
#     'character_name': 'Prisoner (uncredited)',
#     'person_id': 32739,
#     'name': 'John Sampson'},
#    {'role': 'ACTOR',
#     'character_name': 'Menacing Thug in Plaid (uncredited)',
#     'person_id': 287829,
#     'name': 'Dar Robinson'},
#    {'role': 'ACTOR',
#     'character_name': 'Surprise Party Lady (uncredited)',
#     'person_id': 52675,
#     'name': 'Kay Hawtrey'},
#    {'role': 'ACTOR',
#     'character_name': 'Driver of Teskey Truck (uncredited)',
#     'person_id': 7277,
#     'name': 'John Hawkes'},
#    {'role': 'ACTOR',
#     'character_name': 'Weird Waiter (uncredited)',
#     'person_id': 12559,
#     'name': 'Charles W. Gray'},
#    {'role': 'ACTOR',
#     'character_name': "Martín's Lady",
#     'person_id': 1337008,
#     'name': 'Suzanne Barker'},
#    {'role': 'ACTOR',
#     'character_name': 'Bar Patron',
#     'person_id': 47836,
#     'name': 'Dwayne McLean'},
#    {'role': 'ACTOR',
#     'character_name': 'Bar Patron',
#     'person_id': 180941,
#     'name': 'Danny Lima'},
#    {'role': 'ACTOR',
#     'character_name': 'Pool Hall Man',
#     'person_id': 704844,
#     'name': 'Danny Pawlick'},
#    {'role': 'ACTOR',
#     'character_name': 'Drill Instructor',
#     'person_id': 87590,
#     'name': 'Bob Collins'},
#    {'role': 'ACTOR',
#     'character_name': 'Street Thug',
#     'person_id': 937469,
#     'name': 'Gene Mack'},
#    {'role': 'ACTOR',
#     'character_name': 'Arresting Cop',
#     'person_id': 82846,
#     'name': 'Gino Marrocco'},
#    {'role': 'ACTOR',
#     'character_name': 'Officer',
#     'person_id': 462221,
#     'name': 'David Clement'},
#    {'role': 'ACTOR',
#     'character_name': 'Officer',
#     'person_id': 23591,
#     'name': 'J. Winston Carroll'},
#    {'role': 'ACTOR',
#     'character_name': 'Officer',
#     'person_id': 1018831,
#     'name': 'Wally Bondarenko'},
#    {'role': 'ACTOR',
#     'character_name': 'Tough',
#     'person_id': 1115512,
#     'name': 'F. Braun McAsh'},
#    {'role': 'ACTOR',
#     'character_name': 'Tough',
#     'person_id': 93112,
#     'name': 'Marco Bianco'},
#    {'role': 'ACTOR',
#     'character_name': 'Street Punk',
#     'person_id': 714126,
#     'name': 'Fred Brigham'},
#    {'role': 'ACTOR',
#     'character_name': 'Driver',
#     'person_id': 66962,
#     'name': 'James Bearden'},
#    {'role': 'ACTOR',
#     'character_name': 'Sidewalk Store Owner',
#     'person_id': 19734,
#     'name': 'Gary Farmer'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet with Hat',
#     'person_id': 1230698,
#     'name': 'Barry Greene'},
#    {'role': 'ACTOR',
#     'character_name': 'Mrs. Lassard',
#     'person_id': 1127480,
#     'name': 'Araby Lockhart'},
#    {'role': 'ACTOR',
#     'character_name': 'Little Old Lady',
#     'person_id': 1031025,
#     'name': 'Beth Amos'},
#    {'role': 'ACTOR',
#     'character_name': 'Supply Clerk',
#     'person_id': 17457,
#     'name': 'Bruce McFee'},
#    {'role': 'ACTOR',
#     'character_name': 'Office Executive',
#     'person_id': 25205,
#     'name': 'Michael J. Reynolds'},
#    {'role': 'ACTOR',
#     'character_name': 'Mr. Wig',
#     'person_id': 1944,
#     'name': 'Don Lake'},
#    {'role': 'ACTOR',
#     'character_name': 'Chief Hurnst',
#     'person_id': 74078,
#     'name': 'George R. Robertson'},
#    {'role': 'ACTOR',
#     'character_name': 'Main Bad Guy',
#     'person_id': 26821,
#     'name': 'Doug Lennox'},
#    {'role': 'ACTOR',
#     'character_name': 'Rope Climbing Cadet in Gym (uncredited)',
#     'person_id': 450733,
#     'name': 'Wink Roberts'},
#    {'role': 'DIRECTOR', 'person_id': 27046, 'name': 'Hugh Wilson'},
#    {'role': 'EDITOR', 'person_id': 21132, 'name': 'Zach Staenberg'},
#    {'role': 'EDITOR', 'person_id': 27049, 'name': 'Robert Brown'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 11399,
#     'name': 'Robert Folk'},
#    {'role': 'PRODUCER', 'person_id': 27048, 'name': 'Paul Maslansky'},
#    {'role': 'PRODUCTION_DESIGN',
#     'person_id': 27050,
#     'name': 'Trevor Williams'},
#    {'role': 'SCREENPLAY', 'person_id': 27046, 'name': 'Hugh Wilson'},
#    {'role': 'SCREENPLAY', 'person_id': 6252, 'name': 'Pat Proft'},
#    {'role': 'SCREENPLAY', 'person_id': 27047, 'name': 'Neal Israel'}],
#   'external_ids': [{'provider': 'eidr',
#     'external_id': '10.5240/CE5D-2293-CE7C-49DB-F224-P'},
#    {'provider': 'tmdb', 'external_id': '9336'},
#    {'provider': 'rovi', 'external_id': '435303'},
#    {'provider': 'gowatchit', 'external_id': '44394'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0087928'},
#    {'provider': 'tmdb_latest', 'external_id': '9336'},
#    {'provider': 'tms', 'external_id': 'MV000171520000'},
#    {'provider': 'imdb', 'external_id': 'tt0087928'},
#    {'provider': 'iva', 'external_id': '440'}],
#   'genre_ids': [3, 4],
#   'age_certification': '12',
#   'runtime': 97,
#   'production_countries': ['US'],
#   'permanent_audiences': ['pa:6bb3c83a-bfd6-4ba5-bf3e-9bbdfd4612e1',
#    'pa:b6d69ea4-b214-4a39-b42e-4c033b850d77']},
#  {'jw_entity_id': 'tm132303',
#   'id': 132303,
#   'title': 'Loca academia de policía 2: Su primera misión',
#   'full_path': '/es/pelicula/loca-academia-de-policia-2-su-primera-mision',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/loca-academia-de-policia-2-su-primera-mision'},
#   'poster': '/poster/187306444/{profile}',
#   'poster_blur_hash': 'TaC$g4j;M|xNWTW-W^WURiR?j?W9',
#   'backdrops': [{'backdrop_url': '/backdrop/9058243/{profile}',
#     'backdrop_blur_hash': 'L25hGV9ur=-;~UIoM{ofSuspM{n#'},
#    {'backdrop_url': '/backdrop/47958171/{profile}',
#     'backdrop_blur_hash': 'L55#eJnlMw%M~qRkITxuxtayV@t7'},
#    {'backdrop_url': '/backdrop/187306451/{profile}',
#     'backdrop_blur_hash': 'LlQ9_[j[~qWBoLfQa#fQ-;ayIUkC'},
#    {'backdrop_url': '/backdrop/199781187/{profile}',
#     'backdrop_blur_hash': 'LdRMb$of~qRkxuayRjj[-;ayD%of'},
#    {'backdrop_url': '/backdrop/48940633/{profile}',
#     'backdrop_blur_hash': 'L47Axfwf,:-pavIoIoIn0zogNfo#'}],
#   'short_description': 'Mahoney y sus amigos se han graduado ya en la academia de policía y se les asigna su primera misión. ¿Estarán preparados para enfrentarse a una peligrosa banda callejera de gamberros?',
#   'original_release_year': 1985,
#   'object_type': 'movie',
#   'original_title': 'Police Academy 2: Their First Assignment',
#   'offers': [{'jw_entity_id': 'tm132303',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 10.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/police-academy-2-su-primera-mission/umc.cmc.140tum443joczsdwy7bgudd3n?playableId=tvs.sbd.9001%3A565115991',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fpolice-academy-2-su-primera-mission%2Fumc.cmc.140tum443joczsdwy7bgudd3n%3FplayableId%3Dtvs.sbd.9001%253A565115991&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 10.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/police-academy-2-su-primera-mission/umc.cmc.140tum443joczsdwy7bgudd3n?playableId=tvs.sbd.9001%3A565115991',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fpolice-academy-2-su-primera-mission%2Fumc.cmc.140tum443joczsdwy7bgudd3n%3FplayableId%3Dtvs.sbd.9001%253A565115991&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/police-academy-2-su-primera-mission/umc.cmc.140tum443joczsdwy7bgudd3n?playableId=tvs.sbd.9001%3A565115991',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fpolice-academy-2-su-primera-mission%2Fumc.cmc.140tum443joczsdwy7bgudd3n%3FplayableId%3Dtvs.sbd.9001%253A565115991&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/police-academy-2-su-primera-mission/umc.cmc.140tum443joczsdwy7bgudd3n?playableId=tvs.sbd.9001%3A565115991',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fpolice-academy-2-su-primera-mission%2Fumc.cmc.140tum443joczsdwy7bgudd3n%3FplayableId%3Dtvs.sbd.9001%253A565115991&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 10.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.8ebb29f4-5b0f-7406-9bd0-3b2af5d06f00',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.8ebb29f4-5b0f-7406-9bd0-3b2af5d06f00',
#      'deeplink_rokuos': 'launch/13?contentID=B08QH27QBB&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 7.99,
#     'last_change_retail_price': 10.99,
#     'last_change_difference': -3,
#     'last_change_percent': -27.297543,
#     'last_change_date': '2022-02-25',
#     'last_change_date_provider_id': '2022-02-25_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.8ebb29f4-5b0f-7406-9bd0-3b2af5d06f00',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.8ebb29f4-5b0f-7406-9bd0-3b2af5d06f00',
#      'deeplink_rokuos': 'launch/13?contentID=B08QH27QBB&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'rent',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.8ebb29f4-5b0f-7406-9bd0-3b2af5d06f00',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.8ebb29f4-5b0f-7406-9bd0-3b2af5d06f00',
#      'deeplink_rokuos': 'launch/13?contentID=B08QH27QBB&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'rent',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.8ebb29f4-5b0f-7406-9bd0-3b2af5d06f00',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.8ebb29f4-5b0f-7406-9bd0-3b2af5d06f00',
#      'deeplink_rokuos': 'launch/13?contentID=B08QH27QBB&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 8.99,
#     'last_change_retail_price': 10.99,
#     'last_change_difference': -2,
#     'last_change_percent': -18.198362,
#     'last_change_date': '2022-02-25',
#     'last_change_date_provider_id': '2022-02-25_35',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/loca-academia-de-policia-2-su-primera-mision'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 8.99,
#     'last_change_retail_price': 10.99,
#     'last_change_difference': -2,
#     'last_change_percent': -18.198362,
#     'last_change_date': '2022-02-25',
#     'last_change_date_provider_id': '2022-02-25_35',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/loca-academia-de-policia-2-su-primera-mision'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/loca-academia-de-policia-2-su-primera-mision'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/loca-academia-de-policia-2-su-primera-mision'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'flatrate',
#     'provider_id': 384,
#     'package_short_name': 'hbm',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.hbomax.com/feature/urn:hbo:feature:GXdu2XgU6N6XCPQEAADft',
#      'deeplink_rokuos': 'launch/61322?contentID=urn%3Ahbo%3Afeature%3AGXdu2XgU6N6XCPQEAADft&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm132303',
#     'monetization_type': 'flatrate',
#     'provider_id': 384,
#     'package_short_name': 'hbm',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.hbomax.com/feature/urn:hbo:feature:GXdu2XgU6N6XCPQEAADft',
#      'deeplink_rokuos': 'launch/61322?contentID=urn%3Ahbo%3Afeature%3AGXdu2XgU6N6XCPQEAADft&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'imdb:score', 'value': 5.7},
#    {'provider_type': 'imdb:votes', 'value': 54737},
#    {'provider_type': 'tmdb:score', 'value': 6},
#    {'provider_type': 'imdb:multiplied', 'value': 312000.9},
#    {'provider_type': 'imdb:popularity', 'value': 4897},
#    {'provider_type': 'tmdb:popularity', 'value': 18.689},
#    {'provider_type': 'tmdb:id', 'value': 10157}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Carey Mahoney',
#     'person_id': 19841,
#     'name': 'Steve Guttenberg'},
#    {'role': 'ACTOR',
#     'character_name': 'Hightower',
#     'person_id': 27036,
#     'name': 'Bubba Smith'},
#    {'role': 'ACTOR',
#     'character_name': 'Tackleberry',
#     'person_id': 27039,
#     'name': 'David Graf'},
#    {'role': 'ACTOR',
#     'character_name': 'Larvell Jones',
#     'person_id': 14330,
#     'name': 'Michael Winslow'},
#    {'role': 'ACTOR',
#     'character_name': 'Doug Fackler',
#     'person_id': 27041,
#     'name': 'Bruce Mahler'},
#    {'role': 'ACTOR',
#     'character_name': 'Laverne Hookes',
#     'person_id': 27044,
#     'name': 'Marion Ramsey'},
#    {'role': 'ACTOR',
#     'character_name': 'Kirkland',
#     'person_id': 3039,
#     'name': 'Colleen Camp'},
#    {'role': 'ACTOR',
#     'character_name': 'Pete Lassard',
#     'person_id': 19627,
#     'name': 'Howard Hesseman'},
#    {'role': 'ACTOR',
#     'character_name': 'Lt. Mauser',
#     'person_id': 70284,
#     'name': 'Art Metrano'},
#    {'role': 'ACTOR',
#     'character_name': 'Commandant Lassard',
#     'person_id': 27037,
#     'name': 'George Gaynes'},
#    {'role': 'ACTOR',
#     'character_name': 'Zed',
#     'person_id': 12172,
#     'name': 'Bobcat Goldthwait'},
#    {'role': 'ACTOR',
#     'character_name': 'Chloe',
#     'person_id': 14485,
#     'name': 'Julie Brown'},
#    {'role': 'ACTOR',
#     'character_name': 'Vinnie Schtulman',
#     'person_id': 122080,
#     'name': 'Peter Van Norden'},
#    {'role': 'ACTOR',
#     'character_name': 'Merchant',
#     'person_id': 53544,
#     'name': 'Tim Kazurinsky'},
#    {'role': 'ACTOR',
#     'character_name': 'Dooley',
#     'person_id': 29077,
#     'name': 'Ed Herlihy'},
#    {'role': 'ACTOR',
#     'character_name': 'Sistrunk',
#     'person_id': 36627,
#     'name': 'Sandy Ward'},
#    {'role': 'ACTOR',
#     'character_name': 'Proctor',
#     'person_id': 38112,
#     'name': 'Lance Kinsey'},
#    {'role': 'ACTOR',
#     'character_name': 'Mojo',
#     'person_id': 111116,
#     'name': 'Christopher Jackson'},
#    {'role': 'ACTOR',
#     'character_name': 'Flacko',
#     'person_id': 1396221,
#     'name': 'Church Ortiz'},
#    {'role': 'ACTOR',
#     'character_name': 'Chief Hurst',
#     'person_id': 74078,
#     'name': 'George R. Robertson'},
#    {'role': 'ACTOR',
#     'character_name': 'Old Man Kirkland',
#     'person_id': 219488,
#     'name': 'Arthur Batanides'},
#    {'role': 'ACTOR',
#     'character_name': 'Mrs. Kirkland',
#     'person_id': 18035,
#     'name': 'Jackie Joseph'},
#    {'role': 'ACTOR',
#     'character_name': 'Bud Kirkland',
#     'person_id': 1378820,
#     'name': 'Andrew Paris'},
#    {'role': 'ACTOR',
#     'character_name': 'Namu',
#     'person_id': 51041,
#     'name': 'Monica Parker'},
#    {'role': 'ACTOR',
#     'character_name': 'Chef',
#     'person_id': 1367061,
#     'name': 'Kenji Shintani'},
#    {'role': 'ACTOR',
#     'character_name': 'Mayor',
#     'person_id': 5463,
#     'name': 'Jennifer Darling'},
#    {'role': 'ACTOR',
#     'character_name': 'Mom in Mercedes',
#     'person_id': 82439,
#     'name': 'Lucy Lee Flippin'},
#    {'role': 'ACTOR',
#     'character_name': 'Brat',
#     'person_id': 38931,
#     'name': 'Jason Hervey'},
#    {'role': 'ACTOR',
#     'character_name': 'Nurse',
#     'person_id': 105598,
#     'name': 'Diana Bellamy'},
#    {'role': 'ACTOR',
#     'character_name': 'Check-out Girl',
#     'person_id': 1792435,
#     'name': 'Julie Paris'},
#    {'role': 'ACTOR',
#     'character_name': 'Preppy Girl',
#     'person_id': 2084165,
#     'name': 'Debra Dusay'},
#    {'role': 'ACTOR',
#     'character_name': 'Preppy Guy',
#     'person_id': 96585,
#     'name': 'Jim Boyce'},
#    {'role': 'ACTOR',
#     'character_name': 'Tim',
#     'person_id': 74631,
#     'name': 'Tim Haldeman'},
#    {'role': 'ACTOR',
#     'character_name': 'Bartender',
#     'person_id': 2054544,
#     'name': 'Bert Williams'},
#    {'role': 'ACTOR',
#     'character_name': 'Slit',
#     'person_id': 484622,
#     'name': 'Pamela Matheson'},
#    {'role': 'ACTOR',
#     'character_name': 'Gang Member',
#     'person_id': 1367124,
#     'name': 'Bufort McClerkins'},
#    {'role': 'ACTOR',
#     'character_name': 'Gas Station Attendant',
#     'person_id': 1140491,
#     'name': 'Conrad Hurtt'},
#    {'role': 'ACTOR',
#     'character_name': 'Greengrocer',
#     'person_id': 1367055,
#     'name': 'William Yamadera'},
#    {'role': 'ACTOR',
#     'character_name': 'Crook',
#     'person_id': 1367123,
#     'name': 'Morris Beers'},
#    {'role': 'ACTOR',
#     'character_name': "Zed's Gang Member (uncredited)",
#     'person_id': 31657,
#     'name': 'Brian J. Williams'},
#    {'role': 'ACTOR',
#     'character_name': 'Junior Executive (uncredited)',
#     'person_id': 1367090,
#     'name': 'Marshal Silverman'},
#    {'role': 'ACTOR',
#     'character_name': 'Crook (uncredited)',
#     'person_id': 722420,
#     'name': 'Wayne Montanio'},
#    {'role': 'ACTOR',
#     'character_name': 'Street Punk (uncredited)',
#     'person_id': 114901,
#     'name': 'Rich Hall'},
#    {'role': 'ACTOR',
#     'character_name': 'Wedding Guest (uncredited)',
#     'person_id': 19843,
#     'name': 'G.W. Bailey'},
#    {'role': 'DIRECTOR', 'person_id': 33391, 'name': 'Jerry Paris'},
#    {'role': 'EDITOR', 'person_id': 84106, 'name': 'Bob Wyman'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 11399,
#     'name': 'Robert Folk'},
#    {'role': 'PRODUCER', 'person_id': 27048, 'name': 'Paul Maslansky'},
#    {'role': 'SCREENPLAY', 'person_id': 16714, 'name': 'Barry W. Blaustein'},
#    {'role': 'SCREENPLAY', 'person_id': 16713, 'name': 'David Sheffield'},
#    {'role': 'SCREENPLAY', 'person_id': 27047, 'name': 'Neal Israel'}],
#   'external_ids': [{'provider': 'imdb_latest', 'external_id': 'tt0089822'},
#    {'provider': 'iva', 'external_id': '927'},
#    {'provider': 'tmdb_latest', 'external_id': '10157'},
#    {'provider': 'eidr', 'external_id': '10.5240/A725-9768-EEC2-A32E-8EC0-A'},
#    {'provider': 'tms', 'external_id': 'MV000187610000'},
#    {'provider': 'gowatchit', 'external_id': '5111'},
#    {'provider': 'rovi', 'external_id': '1066995'},
#    {'provider': 'tmdb', 'external_id': '10157'},
#    {'provider': 'imdb', 'external_id': 'tt0089822'}],
#   'genre_ids': [3],
#   'age_certification': 'APTA',
#   'runtime': 87,
#   'production_countries': ['US'],
#   'permanent_audiences': ['pa:b6d69ea4-b214-4a39-b42e-4c033b850d77']},
#  {'jw_entity_id': 'tm110483',
#   'id': 110483,
#   'title': 'Loca academia de policía 3: De vuelta a la escuela',
#   'full_path': '/es/pelicula/loca-academia-de-policia-3-de-vuelta-a-la-escuela',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/loca-academia-de-policia-3-de-vuelta-a-la-escuela'},
#   'poster': '/poster/187503917/{profile}',
#   'poster_blur_hash': 'TfLqb1M|_3?cR*Mx_Nt6jZM|oext',
#   'backdrops': [{'backdrop_url': '/backdrop/187503925/{profile}',
#     'backdrop_blur_hash': 'LlRC;}ay~qof-;ayIUj[%Mj[MyWC'},
#    {'backdrop_url': '/backdrop/134690537/{profile}',
#     'backdrop_blur_hash': 'LFD[|KD%?G4o~U$%IoE1xtxtRjV['},
#    {'backdrop_url': '/backdrop/199764414/{profile}',
#     'backdrop_blur_hash': 'LpQ,H]of~qWBxvayM{of%Mf6IUfk'},
#    {'backdrop_url': '/backdrop/270974015/{profile}',
#     'backdrop_blur_hash': 'LbQvtJ4n%g~q%MxuRjIU?bxuRjMy'},
#    {'backdrop_url': '/backdrop/265865291/{profile}',
#     'backdrop_blur_hash': 'LgPGgP00-;_4-;j]RjNF-;xuV@M{'}],
#   'short_description': 'La academia está a punto de desaparecer. Para evitarlo, la única solución es luchar por su supervivencia contra su competidora, la academia del comandante Mauser.',
#   'original_release_year': 1986,
#   'object_type': 'movie',
#   'original_title': 'Police Academy 3: Back in Training',
#   'offers': [{'jw_entity_id': 'tm110483',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 8.99,
#     'last_change_retail_price': 10.99,
#     'last_change_difference': -2,
#     'last_change_percent': -18.198362,
#     'last_change_date': '2022-02-28',
#     'last_change_date_provider_id': '2022-02-28_2',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/loca-academia-de-policia-3/umc.cmc.4qqq4tqzlotwpw5iik0o3t4ja?playableId=tvs.sbd.9001%3A444706322',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Floca-academia-de-policia-3%2Fumc.cmc.4qqq4tqzlotwpw5iik0o3t4ja%3FplayableId%3Dtvs.sbd.9001%253A444706322&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/loca-academia-de-policia-3/umc.cmc.4qqq4tqzlotwpw5iik0o3t4ja?playableId=tvs.sbd.9001%3A444706322',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Floca-academia-de-policia-3%2Fumc.cmc.4qqq4tqzlotwpw5iik0o3t4ja%3FplayableId%3Dtvs.sbd.9001%253A444706322&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'buy',
#     'provider_id': 3,
#     'package_short_name': 'ply',
#     'retail_price': 9.99,
#     'last_change_retail_price': 11.99,
#     'last_change_difference': -2,
#     'last_change_percent': -16.680567,
#     'last_change_date': '2022-03-05',
#     'last_change_date_provider_id': '2022-03-05_3',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.google.com/store/movies/details/Loca_Academia_de_Polic%C3%ADa_3?gl=ES&hl=en&id=nlavW-CcEZc'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'rent',
#     'provider_id': 3,
#     'package_short_name': 'ply',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.google.com/store/movies/details/Loca_Academia_de_Polic%C3%ADa_3?gl=ES&hl=en&id=nlavW-CcEZc'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 9.99,
#     'last_change_retail_price': 11.99,
#     'last_change_difference': -2,
#     'last_change_percent': -16.680567,
#     'last_change_date': '2022-03-04',
#     'last_change_date_provider_id': '2022-03-04_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.62ba968f-09ce-5f16-b14e-f6ae057d70bb',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.62ba968f-09ce-5f16-b14e-f6ae057d70bb',
#      'deeplink_rokuos': 'launch/13?contentID=B08LF2G292&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 8.99,
#     'last_change_retail_price': 10.99,
#     'last_change_difference': -2,
#     'last_change_percent': -18.198362,
#     'last_change_date': '2022-03-01',
#     'last_change_date_provider_id': '2022-03-01_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.62ba968f-09ce-5f16-b14e-f6ae057d70bb',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.62ba968f-09ce-5f16-b14e-f6ae057d70bb',
#      'deeplink_rokuos': 'launch/13?contentID=B08LF2G292&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'rent',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.62ba968f-09ce-5f16-b14e-f6ae057d70bb',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.62ba968f-09ce-5f16-b14e-f6ae057d70bb',
#      'deeplink_rokuos': 'launch/13?contentID=B08LF2G292&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'rent',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.62ba968f-09ce-5f16-b14e-f6ae057d70bb',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.62ba968f-09ce-5f16-b14e-f6ae057d70bb',
#      'deeplink_rokuos': 'launch/13?contentID=B08LF2G292&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 8.99,
#     'last_change_retail_price': 10.99,
#     'last_change_difference': -2,
#     'last_change_percent': -18.198362,
#     'last_change_date': '2022-02-25',
#     'last_change_date_provider_id': '2022-02-25_35',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/loca-academia-de-policia-3'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 8.99,
#     'last_change_retail_price': 10.99,
#     'last_change_difference': -2,
#     'last_change_percent': -18.198362,
#     'last_change_date': '2022-02-25',
#     'last_change_date_provider_id': '2022-02-25_35',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/loca-academia-de-policia-3'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/loca-academia-de-policia-3'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/loca-academia-de-policia-3'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'flatrate',
#     'provider_id': 384,
#     'package_short_name': 'hbm',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.hbomax.com/feature/urn:hbo:feature:GXdu2VgRq8qXCPQEAADfS',
#      'deeplink_rokuos': 'launch/61322?contentID=urn%3Ahbo%3Afeature%3AGXdu2VgRq8qXCPQEAADfS&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm110483',
#     'monetization_type': 'flatrate',
#     'provider_id': 384,
#     'package_short_name': 'hbm',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.hbomax.com/feature/urn:hbo:feature:GXdu2VgRq8qXCPQEAADfS',
#      'deeplink_rokuos': 'launch/61322?contentID=urn%3Ahbo%3Afeature%3AGXdu2VgRq8qXCPQEAADfS&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'tmdb:id', 'value': 12118},
#    {'provider_type': 'imdb:score', 'value': 5.3},
#    {'provider_type': 'imdb:votes', 'value': 45112},
#    {'provider_type': 'tmdb:score', 'value': 5.7},
#    {'provider_type': 'imdb:multiplied', 'value': 239093.6},
#    {'provider_type': 'imdb:popularity', 'value': 4411},
#    {'provider_type': 'tmdb:popularity', 'value': 19.595}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Sgt. Carey Mahoney',
#     'person_id': 19841,
#     'name': 'Steve Guttenberg'},
#    {'role': 'ACTOR',
#     'character_name': 'Sgt. Moses Hightower',
#     'person_id': 27036,
#     'name': 'Bubba Smith'},
#    {'role': 'ACTOR',
#     'character_name': 'Sgt. Eugene Tackleberry',
#     'person_id': 27039,
#     'name': 'David Graf'},
#    {'role': 'ACTOR',
#     'character_name': 'Sgt. Larvelle Jones',
#     'person_id': 14330,
#     'name': 'Michael Winslow'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Zed',
#     'person_id': 12172,
#     'name': 'Bobcat Goldthwait'},
#    {'role': 'ACTOR',
#     'character_name': 'Sgt. Hooks',
#     'person_id': 27044,
#     'name': 'Marion Ramsey'},
#    {'role': 'ACTOR',
#     'character_name': 'Lt. Callahan',
#     'person_id': 24556,
#     'name': 'Leslie Easterbrook'},
#    {'role': 'ACTOR',
#     'character_name': 'Comdt. Mauser',
#     'person_id': 70284,
#     'name': 'Art Metrano'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Sweetchuck',
#     'person_id': 53544,
#     'name': 'Tim Kazurinsky'},
#    {'role': 'ACTOR',
#     'character_name': 'Comdt. Lassard',
#     'person_id': 27037,
#     'name': 'George Gaynes'},
#    {'role': 'ACTOR',
#     'character_name': 'Sgt. Copeland',
#     'person_id': 19400,
#     'name': 'Scott Thomson'},
#    {'role': 'ACTOR',
#     'character_name': 'Sgt. Fackler',
#     'person_id': 27041,
#     'name': 'Bruce Mahler'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Nogata',
#     'person_id': 57137,
#     'name': 'Brian Tochi'},
#    {'role': 'ACTOR',
#     'character_name': 'Lt. Proctor',
#     'person_id': 38112,
#     'name': 'Lance Kinsey'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Fackler',
#     'person_id': 27040,
#     'name': 'Debralee Scott'},
#    {'role': 'ACTOR',
#     'character_name': 'Mr. Bellows',
#     'person_id': 48118,
#     'name': 'Jack Creley'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Karen Adams',
#     'person_id': 171896,
#     'name': 'Shawn Weatherly'},
#    {'role': 'ACTOR',
#     'character_name': 'Sgt. Blanks',
#     'person_id': 27043,
#     'name': 'Brant von Hoffman'},
#    {'role': 'ACTOR',
#     'character_name': 'Governor Neilson',
#     'person_id': 33049,
#     'name': 'Ed Nelson'},
#    {'role': 'ACTOR',
#     'character_name': 'Chief Hurst',
#     'person_id': 74078,
#     'name': 'George R. Robertson'},
#    {'role': 'ACTOR',
#     'character_name': 'The Hooker',
#     'person_id': 239530,
#     'name': 'Georgina Spelvin'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Hedges',
#     'person_id': 20985,
#     'name': 'David Huband'},
#    {'role': 'ACTOR',
#     'character_name': 'Mr. Kirkland',
#     'person_id': 219488,
#     'name': 'Arthur Batanides'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Kirkland',
#     'person_id': 1378820,
#     'name': 'Andrew Paris'},
#    {'role': 'ACTOR',
#     'character_name': 'Robber',
#     'person_id': 78986,
#     'name': 'T.J. Scott'},
#    {'role': 'ACTOR',
#     'character_name': 'Priest in Police Line-up',
#     'person_id': 33391,
#     'name': 'Jerry Paris'},
#    {'role': 'ACTOR',
#     'character_name': 'Man #4 in Police Line-up',
#     'person_id': 27048,
#     'name': 'Paul Maslansky'},
#    {'role': 'ACTOR',
#     'character_name': 'Police cadet',
#     'person_id': 1393291,
#     'name': 'Lorenzo Gaspar'},
#    {'role': 'ACTOR',
#     'character_name': 'Karate Instructor',
#     'person_id': 79722,
#     'name': 'Jean Frenette'},
#    {'role': 'ACTOR',
#     'character_name': 'Purse Snatcher',
#     'person_id': 1135807,
#     'name': 'Tye Tyukodi'},
#    {'role': 'ACTOR',
#     'character_name': 'Gang Member #2',
#     'person_id': 1393710,
#     'name': 'Alex Pauljuk'},
#    {'role': 'ACTOR',
#     'character_name': 'Gang Member #1',
#     'person_id': 463934,
#     'name': 'Peter Colvey'},
#    {'role': 'ACTOR',
#     'character_name': 'Boy on Bicycle',
#     'person_id': 1393388,
#     'name': 'Pierre Berube'},
#    {'role': 'ACTOR',
#     'character_name': 'Bartender',
#     'person_id': 1393700,
#     'name': 'Gary Flanagan'},
#    {'role': 'ACTOR',
#     'character_name': 'Hotel Manager',
#     'person_id': 212186,
#     'name': 'Elias Zarou'},
#    {'role': 'ACTOR',
#     'character_name': 'Woman at Phone Booth',
#     'person_id': 967894,
#     'name': "Gladys O'Connor"},
#    {'role': 'ACTOR',
#     'character_name': 'Elderly Man',
#     'person_id': 1393481,
#     'name': 'Fred Livingstone'},
#    {'role': 'ACTOR',
#     'character_name': 'Maid',
#     'person_id': 1393351,
#     'name': 'Gloria Summers'},
#    {'role': 'ACTOR',
#     'character_name': 'Man with Cigar',
#     'person_id': 750016,
#     'name': 'Les Nirenberg'},
#    {'role': 'ACTOR',
#     'character_name': 'Woman at Cafe',
#     'person_id': 23601,
#     'name': 'Fran Gebhard'},
#    {'role': 'ACTOR',
#     'character_name': "Sarah's Mother",
#     'person_id': 24526,
#     'name': 'Pam Hyatt'},
#    {'role': 'ACTOR',
#     'character_name': 'Sarah',
#     'person_id': 511780,
#     'name': 'Marcia Watkins'},
#    {'role': 'ACTOR',
#     'character_name': 'Basketball Player',
#     'person_id': 1393731,
#     'name': 'Susan DeRyck'},
#    {'role': 'ACTOR',
#     'character_name': 'Tommy',
#     'person_id': 427069,
#     'name': 'Theo Caesar'},
#    {'role': 'ACTOR',
#     'character_name': 'Axe Murderer',
#     'person_id': 26821,
#     'name': 'Doug Lennox'},
#    {'role': 'ACTOR',
#     'character_name': 'Line-Up Room Cop',
#     'person_id': 1393742,
#     'name': 'Bruce Pirie'},
#    {'role': 'ACTOR',
#     'character_name': 'Line-Up Room Victim',
#     'person_id': 1393567,
#     'name': 'Grant Cowan'},
#    {'role': 'ACTOR',
#     'character_name': 'Cabbie',
#     'person_id': 76538,
#     'name': 'Sam Stone'},
#    {'role': 'ACTOR',
#     'character_name': 'Mrs. Hurst',
#     'person_id': 1393734,
#     'name': 'Mary Ann Coles'},
#    {'role': 'ACTOR',
#     'character_name': 'Ms. Click',
#     'person_id': 1016914,
#     'name': 'Lyn Jackson'},
#    {'role': 'ACTOR',
#     'character_name': 'Mr. Delaney',
#     'person_id': 29357,
#     'name': 'Chas Lawther'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Baxter #2',
#     'person_id': 73802,
#     'name': 'David James Elliott'},
#    {'role': 'ACTOR',
#     'character_name': 'Cadet Baxter #1',
#     'person_id': 1393470,
#     'name': 'R. Christopher Thomas'},
#    {'role': 'DIRECTOR', 'person_id': 33391, 'name': 'Jerry Paris'},
#    {'role': 'EDITOR', 'person_id': 39384, 'name': 'Bud Molin'},
#    {'role': 'MUSIC', 'person_id': 11399, 'name': 'Robert Folk'},
#    {'role': 'PRODUCER', 'person_id': 27048, 'name': 'Paul Maslansky'},
#    {'role': 'SCREENPLAY', 'person_id': 605587, 'name': 'Gene Quintano'}],
#   'external_ids': [{'provider': 'gowatchit', 'external_id': '19897'},
#    {'provider': 'imdb', 'external_id': 'tt0091777'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0091777'},
#    {'provider': 'rovi', 'external_id': '428267'},
#    {'provider': 'tmdb_latest', 'external_id': '12118'},
#    {'provider': 'tms', 'external_id': 'MV000200340000'},
#    {'provider': 'iva', 'external_id': '418'},
#    {'provider': 'eidr', 'external_id': '10.5240/4DBD-1DFE-254D-50B9-D4D2-C'},
#    {'provider': 'tmdb', 'external_id': '12118'}],
#   'genre_ids': [4, 3],
#   'age_certification': 'APTA',
#   'runtime': 84,
#   'production_countries': ['US'],
#   'permanent_audiences': ['pa:6bb3c83a-bfd6-4ba5-bf3e-9bbdfd4612e1']},
#  {'jw_entity_id': 'tm295177',
#   'id': 295177,
#   'title': 'Es por tu bien',
#   'full_path': '/es/pelicula/es-por-tu-bien',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/es-por-tu-bien'},
#   'poster': '/poster/12139097/{profile}',
#   'poster_blur_hash': 'TIHUB[Rj9Kt:a1-P?aemRk.5$gER',
#   'backdrops': [{'backdrop_url': '/backdrop/9615174/{profile}',
#     'backdrop_blur_hash': 'LOK]lTIW0SI;S,n4^abvx[v~R+oz'}],
#   'short_description': 'La peor pesadilla que un padre puede tener con una hija es que ésta crezca y llegue el día en que le presente a su novio, y que éste sea un tipo despreciable que busca una sola cosa de su preciada y amada niñita. Y ese día es precisamente el que les llega a tres padres: a Arturo, a Poli y a Chus. Sus dulces hijas han decidido tirar su futuro a la basura echándose tres novios a su juicio abominables. Así que la única solución es aunar fuerzas para librarse de ellos como sea.',
#   'original_release_year': 2017,
#   'object_type': 'movie',
#   'original_title': 'Es por tu bien',
#   'offers': [{'jw_entity_id': 'tm295177',
#     'monetization_type': 'flatrate',
#     'provider_id': 8,
#     'package_short_name': 'nfx',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'http://www.netflix.com/title/80202503',
#      'deeplink_web': 'http://www.netflix.com/watch/80202503',
#      'deeplink_rokuos': 'launch/12?contentID=80202503&MediaType=movie'},
#     'available_to': '2022-05-23',
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm295177',
#     'monetization_type': 'flatrate',
#     'provider_id': 8,
#     'package_short_name': 'nfx',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'http://www.netflix.com/title/80202503',
# ...
#     'person_id': 5527,
#     'name': 'Joanna Cassidy'},
#    {'role': 'ACTOR',
#     'character_name': 'Hannibal Chew',
#     'person_id': 5529,
#     'name': 'James Hong'},
#    {'role': 'ACTOR',
#     'character_name': 'Bear',
#     'person_id': 5530,
#     'name': 'Kevin Thompson'},
#    {'role': 'ACTOR',
#     'character_name': 'Taffey Lewis',
#     'person_id': 5531,
#     'name': 'Hy Pyke'},
#    {'role': 'ACTOR',
#     'character_name': 'Cambodian Lady',
#     'person_id': 5534,
#     'name': 'Kimiko Hiroshige'},
#    {'role': 'ACTOR',
#     'character_name': 'Abdul Ben Hassan (uncredited)',
#     'person_id': 63295,
#     'name': 'Ben Astar'},
#    {'role': 'ACTOR',
#     'character_name': 'Showgirl (uncredited)',
#     'person_id': 249880,
#     'name': 'Dawna Lee Heising'},
#    {'role': 'ACTOR',
#     'character_name': 'Geisha #1 (uncredited)',
#     'person_id': 79430,
#     'name': 'Alexis Rhee'},
#    {'role': 'ACTOR',
#     'character_name': 'Howie Lee',
#     'person_id': 5536,
#     'name': 'Bob Okazaki'},
#    {'role': 'ACTOR',
#     'character_name': 'Holden',
#     'person_id': 5532,
#     'name': 'Morgan Paull'},
#    {'role': 'ACTOR',
#     'character_name': 'Kaiser',
#     'person_id': 5533,
#     'name': 'John Edward Allen'},
#    {'role': 'ACTOR',
#     'character_name': 'Saleslady',
#     'person_id': 5535,
#     'name': 'Carolyn DeMirjian'},
#    {'role': 'ACTOR',
#     'character_name': 'Ming-Fa (uncredited)',
#     'person_id': 55918,
#     'name': 'Judith Burnett'},
#    {'role': 'ACTOR',
#     'character_name': 'Louie - Bartender (uncredited)',
#     'person_id': 599487,
#     'name': 'Leo Gorcey Jr.'},
#    {'role': 'ACTOR',
#     'character_name': 'Bartender (uncredited)',
#     'person_id': 173805,
#     'name': 'Tom Hutchinson'},
#    {'role': 'ACTOR',
#     'character_name': 'Bartender (uncredited)',
#     'person_id': 17916,
#     'name': 'Charles Knapp'},
#    {'role': 'ACTOR',
#     'character_name': 'Policeman (uncredited)',
#     'person_id': 180855,
#     'name': 'Jirô Okazaki'},
#    {'role': 'DIRECTOR', 'person_id': 4591, 'name': 'Ridley Scott'},
#    {'role': 'EDITOR', 'person_id': 5543, 'name': 'Marsha Nakashima'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER', 'person_id': 5540, 'name': 'Vangelis'},
#    {'role': 'PRODUCER', 'person_id': 5538, 'name': 'Michael Deeley'},
#    {'role': 'PRODUCTION_DESIGN',
#     'person_id': 5541,
#     'name': 'Lawrence G. Paull'},
#    {'role': 'SCREENPLAY', 'person_id': 5544, 'name': 'David Webb Peoples'},
#    {'role': 'SCREENPLAY', 'person_id': 5542, 'name': 'Hampton Fancher'},
#    {'role': 'VISUAL_EFFECTS', 'person_id': 60157, 'name': 'Douglas Trumbull'},
#    {'role': 'VISUAL_EFFECTS', 'person_id': 705198, 'name': 'Richard Yuricich'},
#    {'role': 'VISUAL_EFFECTS', 'person_id': 843245, 'name': 'David Dryer'}],
#   'external_ids': [{'provider': 'tmdb_latest', 'external_id': '78'},
#    {'provider': 'eidr', 'external_id': '10.5240/D13B-5BB8-B190-63E5-8D19-P'},
#    {'provider': 'rovi', 'external_id': '1054339551'},
#    {'provider': 'tms', 'external_id': 'MV000070860000'},
#    {'provider': 'gowatchit', 'external_id': '46431'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0083658'},
#    {'provider': 'imdb', 'external_id': 'tt0083658'},
#    {'provider': 'iva', 'external_id': '89'},
#    {'provider': 'tmdb', 'external_id': '78'},
#    {'provider': 'tmdb', 'external_id': '937745'},
#    {'provider': 'tmdb', 'external_id': '726402'}],
#   'genre_ids': [12, 6, 1, 14],
#   'age_certification': '12',
#   'runtime': 117,
#   'production_countries': ['GB', 'US', 'HK'],
#   'permanent_audiences': ['pa:957cab85-03bc-4be6-a449-294d2b634186',
#    'pa:f8f03b1b-1a5b-4bb1-b483-8fbd6c493588']},
#  {'jw_entity_id': 'tm1019345',
#   'id': 1019345,
#   'title': 'The Fallout',
#   'full_path': '/es/pelicula/the-fallout',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/the-fallout'},
#   'poster': '/poster/261395238/{profile}',
#   'poster_blur_hash': 'TQABeM.8tRYktlt7NGWAj[m,V@R*',
#   'backdrops': [{'backdrop_url': '/backdrop/261395239/{profile}',
#     'backdrop_blur_hash': 'LCAAXT?INxNe_Nx^R+S4*0x]xDoe'},
#    {'backdrop_url': '/backdrop/256880470/{profile}',
#     'backdrop_blur_hash': 'LC8|bM~Wtno~%gtlXTX9X9t7s:bH'},
#    {'backdrop_url': '/backdrop/271274294/{profile}',
#     'backdrop_blur_hash': 'L7BC#+?bEL4o~AtQM|NHW,xaxtX9'},
#    {'backdrop_url': '/backdrop/260065982/{profile}',
#     'backdrop_blur_hash': 'L7AvqL?aIU02~UxuNaWFxW%2%2kW'},
#    {'backdrop_url': '/backdrop/260065980/{profile}',
#     'backdrop_blur_hash': 'LC8|bM~Wtmo~%NtlXTX9X9t7s:bH'}],
#   'short_description': 'Vada es una adolescente que trata de superar los efectos secundarios que sufre tras vivir una tragedia en su instituto. Tras esta experiencia, la relación con su familia y sus amigos, así como su forma de ver el mundo, cambiarán para siempre.',
#   'original_release_year': 2022,
#   'object_type': 'movie',
#   'original_title': 'The Fallout',
#   'localized_release_date': '2022-01-27T00:00:00Z',
#   'offers': [{'jw_entity_id': 'tm1019345',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 7.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/the-fallout/umc.cmc.1dhbuf1hxjvpm1azuddnofnf9?playableId=tvs.sbd.9001%3A1606479044',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fthe-fallout%2Fumc.cmc.1dhbuf1hxjvpm1azuddnofnf9%3FplayableId%3Dtvs.sbd.9001%253A1606479044&MediaType=movie'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 7.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/the-fallout/umc.cmc.1dhbuf1hxjvpm1azuddnofnf9?playableId=tvs.sbd.9001%3A1606479044',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fthe-fallout%2Fumc.cmc.1dhbuf1hxjvpm1azuddnofnf9%3FplayableId%3Dtvs.sbd.9001%253A1606479044&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 7.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/the-fallout/umc.cmc.1dhbuf1hxjvpm1azuddnofnf9?playableId=tvs.sbd.9001%3A1606479044',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fthe-fallout%2Fumc.cmc.1dhbuf1hxjvpm1azuddnofnf9%3FplayableId%3Dtvs.sbd.9001%253A1606479044&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'buy',
#     'provider_id': 3,
#     'package_short_name': 'ply',
#     'retail_price': 7.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.google.com/store/movies/details/The_Fallout_La_Vida_Despu%C3%A9s?gl=ES&hl=en&id=XXbtYdWWETg.P'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 7.99,
#     'last_change_retail_price': 13.99,
#     'last_change_difference': -6,
#     'last_change_percent': -42.887775,
#     'last_change_date': '2022-04-20',
#     'last_change_date_provider_id': '2022-04-20_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.16d0417c-f5ed-4e1b-afcb-67385d4f0569',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.16d0417c-f5ed-4e1b-afcb-67385d4f0569',
#      'deeplink_rokuos': 'launch/13?contentID=B09P4HLJ55&MediaType=movie'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 7.99,
#     'last_change_retail_price': 13.99,
#     'last_change_difference': -6,
#     'last_change_percent': -42.887775,
#     'last_change_date': '2022-04-20',
#     'last_change_date_provider_id': '2022-04-20_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.16d0417c-f5ed-4e1b-afcb-67385d4f0569',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.16d0417c-f5ed-4e1b-afcb-67385d4f0569',
#      'deeplink_rokuos': 'launch/13?contentID=B09P4HLJ55&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 7.99,
#     'last_change_retail_price': 9.99,
#     'last_change_difference': -2,
#     'last_change_percent': -20.02002,
#     'last_change_date': '2022-04-20',
#     'last_change_date_provider_id': '2022-04-20_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.16d0417c-f5ed-4e1b-afcb-67385d4f0569',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.16d0417c-f5ed-4e1b-afcb-67385d4f0569',
#      'deeplink_rokuos': 'launch/13?contentID=B09P4HLJ55&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 9.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/the-fallout-la-vida-despues'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 9.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/the-fallout-la-vida-despues'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'buy',
#     'provider_id': 68,
#     'package_short_name': 'msf',
#     'retail_price': 7.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.microsoft.com/es-es/p/the-fallout/8d6kgwxn63sp'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'buy',
#     'provider_id': 68,
#     'package_short_name': 'msf',
#     'retail_price': 7.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.microsoft.com/es-es/p/the-fallout/8d6kgwxn63sp'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'buy',
#     'provider_id': 68,
#     'package_short_name': 'msf',
#     'retail_price': 7.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.microsoft.com/es-es/p/the-fallout/8d6kgwxn63sp'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'flatrate',
#     'provider_id': 384,
#     'package_short_name': 'hbm',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.hbomax.com/feature/urn:hbo:feature:GYc3xuwu2x5rCFgEAAALb',
#      'deeplink_rokuos': 'launch/61322?contentID=urn%3Ahbo%3Afeature%3AGYc3xuwu2x5rCFgEAAALb&MediaType=movie'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'flatrate',
#     'provider_id': 384,
#     'package_short_name': 'hbm',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.hbomax.com/feature/urn:hbo:feature:GYc3xuwu2x5rCFgEAAALb',
#      'deeplink_rokuos': 'launch/61322?contentID=urn%3Ahbo%3Afeature%3AGYc3xuwu2x5rCFgEAAALb&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm1019345',
#     'monetization_type': 'flatrate',
#     'provider_id': 384,
#     'package_short_name': 'hbm',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.hbomax.com/feature/urn:hbo:feature:GYc3xuwu2x5rCFgEAAALb',
#      'deeplink_rokuos': 'launch/61322?contentID=urn%3Ahbo%3Afeature%3AGYc3xuwu2x5rCFgEAAALb&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'imdb:multiplied', 'value': 88046},
#    {'provider_type': 'imdb:popularity', 'value': 3167},
#    {'provider_type': 'tmdb:popularity', 'value': 143.28},
#    {'provider_type': 'tmdb:id', 'value': 795514},
#    {'provider_type': 'imdb:score', 'value': 7},
#    {'provider_type': 'imdb:votes', 'value': 12578},
#    {'provider_type': 'tmdb:score', 'value': 7.4}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Vada Cavell',
#     'person_id': 55794,
#     'name': 'Jenna Ortega'},
#    {'role': 'ACTOR',
#     'character_name': 'Mia Reed',
#     'person_id': 89814,
#     'name': 'Maddie Ziegler'},
#    {'role': 'ACTOR',
#     'character_name': 'Quinton Hasland',
#     'person_id': 761502,
#     'name': 'Niles Fitch'},
#    {'role': 'ACTOR',
#     'character_name': 'Amelia Cavell',
#     'person_id': 1815475,
#     'name': 'Lumi Pollack'},
#    {'role': 'ACTOR',
#     'character_name': 'Anna',
#     'person_id': 1905,
#     'name': 'Shailene Woodley'},
#    {'role': 'ACTOR',
#     'character_name': 'Patricia Cavell',
#     'person_id': 12723,
#     'name': 'Julie Bowen'},
#    {'role': 'ACTOR',
#     'character_name': 'Nick Feinstein',
#     'person_id': 1352873,
#     'name': 'Will Ropp'},
#    {'role': 'ACTOR',
#     'character_name': 'Carlos Cavell',
#     'person_id': 5680,
#     'name': 'John Ortiz'},
#    {'role': 'ACTOR',
#     'character_name': 'Megan',
#     'person_id': 230808,
#     'name': 'Yindra Zayas'},
#    {'role': 'ACTOR',
#     'character_name': 'Dan Bonavure',
#     'person_id': 657207,
#     'name': 'Austin Zajur'},
#    {'role': 'ACTOR',
#     'character_name': 'Social Worker',
#     'person_id': 1987547,
#     'name': 'Elliott Roca'},
#    {'role': 'ACTOR',
#     'character_name': 'Justin Dragonas',
#     'person_id': 1987275,
#     'name': 'Malcolm Santos'},
#    {'role': 'ACTOR',
#     'character_name': 'Mrs. Victor',
#     'person_id': 47642,
#     'name': 'Christine Horn'},
#    {'role': 'ACTOR',
#     'character_name': 'Police Officer',
#     'person_id': 2120745,
#     'name': 'Tiffany Rae Jones'},
#    {'role': 'ACTOR',
#     'character_name': 'Student',
#     'person_id': 2230970,
#     'name': 'Nancy Arnstein'},
#    {'role': 'DIRECTOR', 'person_id': 2569, 'name': 'Megan Park'},
#    {'role': 'EDITOR', 'person_id': 122256, 'name': 'Jennifer Lee'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 230818,
#     'name': 'Andrew Carlberg'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 1169888,
#     'name': 'Mark Andrews'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 111744,
#     'name': 'Stephanie Denton'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 1986454,
#     'name': 'Christina Lundbohm'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 178896,
#     'name': 'Matthew Helderman'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 227255,
#     'name': "Finneas O'Connell"},
#    {'role': 'PRODUCER', 'person_id': 1286981, 'name': 'Giulia Prenna'},
#    {'role': 'PRODUCER', 'person_id': 335887, 'name': 'Joannie Burstein'},
#    {'role': 'PRODUCER', 'person_id': 1815424, 'name': 'Todd Lundbohm'},
#    {'role': 'PRODUCER', 'person_id': 1986368, 'name': 'Rebecca Miller'},
#    {'role': 'PRODUCER', 'person_id': 1986767, 'name': 'David Brown'},
#    {'role': 'PRODUCER', 'person_id': 236608, 'name': 'Shaun S. Sanghani'},
#    {'role': 'PRODUCER', 'person_id': 1986652, 'name': 'Cara Shine Ballarini'},
#    {'role': 'PRODUCTION_DESIGN',
#     'person_id': 1986541,
#     'name': 'Justin Dragonas'},
#    {'role': 'SCREENPLAY', 'person_id': 2569, 'name': 'Megan Park'}],
#   'external_ids': [{'provider': 'imdb_latest', 'external_id': 'tt11847410'},
#    {'provider': 'tmdb_latest', 'external_id': '795514'},
#    {'provider': 'tmdb', 'external_id': '795514'},
#    {'provider': 'imdb', 'external_id': 'tt11847410'}],
#   'upcoming': [{'package_id': 384,
#     'release_window_from': '2022-01-27T00:00:00',
#     'release_window_to': '2022-01-27T23:59:59',
#     'release_window_days': 1,
#     'release_type': 'digital'}],
#   'genre_ids': [6],
#   'age_certification': '16',
#   'runtime': 96,
#   'production_countries': ['US'],
#   'permanent_audiences': ['pa:185b46c8-1ba7-4f4c-b89e-74b917a25a8a']}]

# %%
len(extra_info)
# Out:
# 30

# %%
# Generar dataframes con el listado de peliculas asociadas a lo que el usuario introduzca en peli_key 
# con todas las columnas que consideres relevantes y el total serán las pelis que te salgan del primer request (e.g.: 22)

# %%
table = pd.json_normalize(extra_info)
table
# Out:
#    jw_entity_id       id                                              title  \
# 0      tm177480   177480                           Loca academia de policía
# 1      tm132303   132303      Loca academia de policía 2: Su primera misión
# 2      tm110483   110483  Loca academia de policía 3: De vuelta a la esc...
# 3      tm295177   295177                                     Es por tu bien
# 4      tm113836   113836          Loca academia de policía: Misión en Moscú
# 5       tm56719    56719  Loca academia de policía 5: Operación Miami Beach
# 6      tm101249   101249                                  Vaya par de polis
# 7      tm142794   142794         Loca academia de policía 6: Ciudad sitiada
# 8       tm14532    14532                                        Ciudadano X
# 9      tm166586   166586                                        Prisioneros
# 10      tm36583    36583                                 Sexo en Nueva York
# 11     tm455670   455670                                              Tenet
# 12     tm361759   361759                                            Colette
# 13      tm54023    54023                                            La caza
# 14     tm267401   267401                                       Contratiempo
# 15     tm197920   197920                                   A cambio de nada
# 16     tm157735   157735                                            Perdida
# 17      tm15897    15897                                      Seven (Se7en)
# 18      tm56184    56184                                El caballero oscuro
# 19     tm130044   130044                                   The Lovely Bones
# 20      tm68909    68909                                  El show de Truman
# 21      tm68272    68272                                         Proyecto X
# 22     tm143928   143928                                           Langosta
# 23     tm114752   114752                                        El pianista
# 24      tm43808    43808                           El talento de Mr. Ripley
# 25      tm77588    77588                                         Casablanca
# 26      tm42327    42327                                               Amor
# 27     tm244376   244376                                          Yo, Tonya
# 28      tm40461    40461                                       Blade Runner
# 29    tm1019345  1019345                                        The Fallout
#
#                                             full_path  \
# 0               /es/pelicula/loca-academia-de-policia
# 1   /es/pelicula/loca-academia-de-policia-2-su-pri...
# 2   /es/pelicula/loca-academia-de-policia-3-de-vue...
# 3                         /es/pelicula/es-por-tu-bien
# 4       /es/pelicula/police-academy-mission-to-moscow
# 5   /es/pelicula/police-academy-5-assignment-miami...
# 6                      /es/pelicula/vaya-par-de-polis
# 7   /es/pelicula/loca-academia-de-policia-6-ciudad...
# 8                            /es/pelicula/ciudadano-x
# 9                            /es/pelicula/prisioneros
# 10        /es/pelicula/sexo-en-nueva-york-la-pelicula
# 11                                 /es/pelicula/tenet
# 12                               /es/pelicula/colette
# 13                               /es/pelicula/la-caza
# 14                          /es/pelicula/contratiempo
# 15                      /es/pelicula/a-cambio-de-nada
# 16                               /es/pelicula/perdida
# 17                                 /es/pelicula/seven
# 18                   /es/pelicula/el-caballero-oscuro
# 19                      /es/pelicula/the-lovely-bones
# 20                     /es/pelicula/el-show-de-truman
# 21                             /es/pelicula/project-x
# 22                              /es/pelicula/langosta
# 23                           /es/pelicula/el-pianista
# 24               /es/pelicula/el-talento-de-mr-ripley
# 25                            /es/pelicula/casablanca
# 26                                  /es/pelicula/amor
# 27                              /es/pelicula/yo-tonya
# 28                          /es/pelicula/blade-runner
# 29                           /es/pelicula/the-fallout
#
#                          poster              poster_blur_hash  \
# 0   /poster/187245208/{profile}  T:PZfVoe%Mxaj[WB_NazM{R*WBoL
# 1   /poster/187306444/{profile}  TaC$g4j;M|xNWTW-W^WURiR?j?W9
# 2   /poster/187503917/{profile}  TfLqb1M|_3?cR*Mx_Nt6jZM|oext
# 3    /poster/12139097/{profile}  TIHUB[Rj9Kt:a1-P?aemRk.5$gER
# 4   /poster/188312475/{profile}  ToQ0N@oz_Nt7aeIoxvWBMxD*j[xt
# 5   /poster/187504331/{profile}  TdOpJexa?wVsx]bv?vR*MxoNRPt6
# 6   /poster/249290420/{profile}  THE{2==|_2~CxaNHD%RjE19FRiRi
# 7   /poster/187569441/{profile}  TaKn0ht8~q?vt7x]?voe%LVXa}IA
# 8   /poster/244745240/{profile}  T996,jM{0x{~NGJ,zpIot,=yo}NG
# 9    /poster/99687201/{profile}  T7AK2L4oKQ%1EN_NDiIUxa-=-;E1
# 10   /poster/10692095/{profile}  T9AlFqS15P}vs:xHEej[xaxaR%I.
# 11  /poster/240293151/{profile}  TNI5_Jad0LxY_3ay0#oLVsj[9ZWV
# 12  /poster/237939531/{profile}  TVEVNW0NtR-oIpoz9a-.RQNHxtV@
# 13  /poster/203472445/{profile}  TQE-?Zbv0g#+NbkW0$aL%0JU-TV[
# 14   /poster/10382158/{profile}  TJCGrwD%4n_4RjNGD%xu%NOGxtae
# 15   /poster/97626458/{profile}  TiJ[9eRja#01f,oM_3oMj[aJRPWB
# 16  /poster/139623830/{profile}  TPG9X1E1a#0Mt6Rj4Uoft7%Lf8WB
# 17    /poster/8655672/{profile}  TfJ5=aMyR%|FspX8Z~S$ofT0NGjY
# 18  /poster/161130479/{profile}  TE8|-Tx]9^~BoJEMV=Rjr=GHS5,;
# 19  /poster/139857263/{profile}  TkHBGH57oeogNGt70L%1j[%3ozRj
# 20   /poster/76810863/{profile}  TcF$L$X8OE_4SgofksozxZ?ItRR*
# 21  /poster/100745974/{profile}  T98z=BbI0M~qj]IVxwt7xtENof-o
# 22  /poster/100275907/{profile}  T9AdDpx]-;.5xb?bE1Mx8{01RjIA
# 23   /poster/74766078/{profile}  T9Bq0kIT9EkERPt78^xvog?vozR.
# 24  /poster/240162960/{profile}  TMEePh9a0N^i9uIqJDM{-R58-T%K
# 25   /poster/79268357/{profile}  TMMs+b?a~p.59aWTF|$k%1z;WBWq
# 26   /poster/11506952/{profile}  TBA^8#IV0ewtt7E2x]t6soXmV[%2
# 27   /poster/73815453/{profile}  TPO:IlDht7~XxuWUMetRog-;ofR*
# 28   /poster/53055384/{profile}  T67BWNk=4:_NtlIU9Ft7r=Iorqt7
# 29  /poster/261395238/{profile}  TQABeM.8tRYktlt7NGWAj[m,V@R*
#
#                                             backdrops  \
# 0   [{'backdrop_url': '/backdrop/272920477/{profil...
# 1   [{'backdrop_url': '/backdrop/9058243/{profile}...
# 2   [{'backdrop_url': '/backdrop/187503925/{profil...
# 3   [{'backdrop_url': '/backdrop/9615174/{profile}...
# 4   [{'backdrop_url': '/backdrop/48904669/{profile...
# 5   [{'backdrop_url': '/backdrop/48940133/{profile...
# 6   [{'backdrop_url': '/backdrop/69363035/{profile...
# 7   [{'backdrop_url': '/backdrop/112564153/{profil...
# 8   [{'backdrop_url': '/backdrop/179633518/{profil...
# 9   [{'backdrop_url': '/backdrop/9032891/{profile}...
# 10  [{'backdrop_url': '/backdrop/10692097/{profile...
# 11  [{'backdrop_url': '/backdrop/239195307/{profil...
# 12  [{'backdrop_url': '/backdrop/244754692/{profil...
# 13  [{'backdrop_url': '/backdrop/74132743/{profile...
# 14  [{'backdrop_url': '/backdrop/5236870/{profile}...
# 15  [{'backdrop_url': '/backdrop/245083626/{profil...
# 16  [{'backdrop_url': '/backdrop/8704835/{profile}...
# 17  [{'backdrop_url': '/backdrop/8655713/{profile}...
# 18  [{'backdrop_url': '/backdrop/179938654/{profil...
# 19  [{'backdrop_url': '/backdrop/10682683/{profile...
# 20  [{'backdrop_url': '/backdrop/181467477/{profil...
# 21  [{'backdrop_url': '/backdrop/182133683/{profil...
# 22  [{'backdrop_url': '/backdrop/71952251/{profile...
# 23  [{'backdrop_url': '/backdrop/188501069/{profil...
# 24  [{'backdrop_url': '/backdrop/176302000/{profil...
# 25  [{'backdrop_url': '/backdrop/176707264/{profil...
# 26  [{'backdrop_url': '/backdrop/11506793/{profile...
# 27  [{'backdrop_url': '/backdrop/37664059/{profile...
# 28  [{'backdrop_url': '/backdrop/116503912/{profil...
# 29  [{'backdrop_url': '/backdrop/261395239/{profil...
#
#                                     short_description  original_release_year  \
# 0   En la academia de policía están a punto de fin...                   1984
# 1   Mahoney y sus amigos se han graduado ya en la ...                   1985
# 2   La academia está a punto de desaparecer. Para ...                   1986
# 3   La peor pesadilla que un padre puede tener con...                   2017
# 4   Ahora, los agentes más famosos y peculiares de...                   1994
# 5   El viejo capitán Lassard, el jefe de la academ...                   1988
# 6   Bruce Willis y Tracy Morgan dan vida a dos pol...                   2010
# 7   El comandante Lassard y su variopinto equipo d...                   1989
# 8   El joven y brillante especialista en medicina ...                   1995
# 9   Keller Dover se enfrenta a la peor de las pesa...                   2013
# 10  Carrie Bradshaw, columnista del "New York Star...                   2008
# 11  Armado solamente con una palabra, Tenet, el pr...                   2020
# 12  Cuenta la historia de Sidonie-Gabrielle Colett...                   2018
# 13  Tras un divorcio difícil, Lucas, de cuarenta a...                   2012
# 14  Barcelona, España. Adrián Doria, un joven y ex...                   2017
# 15  Darío, un chico de dieciséis años, disfruta de...                   2015
# 16  El día de su quinto aniversario de boda, Nick ...                   2014
# 17  El teniente Somerset, del departamento de homi...                   1995
# 18  Batman/Bruce Wayne regresa para continuar su g...                   2008
# 19  La historia gira en torno a Susie Salmon, que ...                   2009
# 20  Truman Burbank es un hombre corriente y algo i...                   1998
# 21  Tres estudiantes de último curso de instituto,...                   2012
# 22  Narra una historia de amor no convencional, am...                   2015
# 23  Varsovia, 1939. El pianista polaco de origen j...                   2002
# 24  Ser joven y despreocupado en medio de un paisa...                   1999
# 25  Durante la Segunda Guerra Mundial, Casablanca ...                   1942
# 26  Crudo retrato de la vejez y de la muerte. Jean...                   2012
# 27  Tonya Harding fue la primera mujer estadounide...                   2017
# 28  A principios del siglo XXI, la Tyrell Corporat...                   1982
# 29  Vada es una adolescente que trata de superar l...                   2022
#
#    object_type  ...                                       external_ids  \
# 0        movie  ...  [{'provider': 'eidr', 'external_id': '10.5240/...
# 1        movie  ...  [{'provider': 'imdb_latest', 'external_id': 't...
# 2        movie  ...  [{'provider': 'gowatchit', 'external_id': '198...
# 3        movie  ...  [{'provider': 'imdb_latest', 'external_id': 't...
# 4        movie  ...  [{'provider': 'tmdb', 'external_id': '11546'},...
# 5        movie  ...  [{'provider': 'rovi', 'external_id': '15356104...
# 6        movie  ...  [{'provider': 'iva', 'external_id': '201412'},...
# 7        movie  ...  [{'provider': 'eidr', 'external_id': '10.5240/...
# 8        movie  ...  [{'provider': 'tms', 'external_id': 'MV0004108...
# 9        movie  ...  [{'provider': 'rovi', 'external_id': '31789950...
# 10       movie  ...  [{'provider': 'rovi', 'external_id': '2340460'...
# 11       movie  ...  [{'provider': 'tms', 'external_id': 'MV0136185...
# 12       movie  ...  [{'provider': 'tmdb', 'external_id': '454652'}...
# 13       movie  ...  [{'provider': 'tms', 'external_id': 'MV0041150...
# 14       movie  ...  [{'provider': 'tmdb', 'external_id': '411088'}...
# 15       movie  ...  [{'provider': 'tmdb_latest', 'external_id': '3...
# 16       movie  ...  [{'provider': 'gowatchit', 'external_id': '122...
# 17       movie  ...  [{'provider': 'tms', 'external_id': 'MV0004354...
# 18       movie  ...  [{'provider': 'tmdb_latest', 'external_id': '1...
# 19       movie  ...  [{'provider': 'gowatchit', 'external_id': '510...
# 20       movie  ...  [{'provider': 'imdb_latest', 'external_id': 't...
# 21       movie  ...  [{'provider': 'tmdb', 'external_id': '57214'},...
# 22       movie  ...  [{'provider': 'rovi', 'external_id': '15148153...
# 23       movie  ...  [{'provider': 'gowatchit', 'external_id': '372...
# 24       movie  ...  [{'provider': 'gowatchit', 'external_id': '299...
# 25       movie  ...  [{'provider': 'gowatchit', 'external_id': '120...
# 26       movie  ...  [{'provider': 'imdb', 'external_id': 'tt160262...
# 27       movie  ...  [{'provider': 'gowatchit', 'external_id': '622...
# 28       movie  ...  [{'provider': 'tmdb_latest', 'external_id': '7...
# 29       movie  ...  [{'provider': 'imdb_latest', 'external_id': 't...
#
#                  genre_ids age_certification runtime  production_countries  \
# 0                   [3, 4]                12      97                  [US]
# 1                      [3]              APTA      87                  [US]
# 2                   [4, 3]              APTA      84                  [US]
# 3                  [3, 18]                12      93                  [ES]
# 4                   [4, 3]              APTA      83                  [US]
# 5                   [3, 4]              APTA      90                  [US]
# 6            [3, 1, 4, 12]              APTA     107                  [US]
# 7                   [4, 3]              APTA      84                  [US]
# 8            [6, 8, 12, 4]                18     105                  [US]
# 9               [12, 4, 6]                16     153                  [US]
# 10              [6, 13, 3]                16     145                  [US]
# 11          [12, 14, 6, 1]                12     150              [US, GB]
# 12          [6, 8, 13, 18]                12     111              [GB, US]
# 13                 [6, 18]                12     116              [SE, DK]
# 14          [12, 6, 4, 18]                12     107                  [ES]
# 15                 [6, 18]                12      97                  [ES]
# 16                 [6, 12]                16     149                  [US]
# 17              [12, 4, 6]                18     127                  [US]
# 18           [6, 1, 12, 4]                16     152              [GB, US]
# 19              [7, 12, 6]                12     130          [US, GB, NZ]
# 20              [3, 6, 14]              APTA     104                  [US]
# 21                     [3]                18      88                  [US]
# 22  [3, 6, 18, 13, 14, 12]                16     118  [NL, GB, FR, GR, IE]
# 23         [6, 11, 16, 18]                12     150      [PL, GB, FR, DE]
# 24              [12, 6, 4]                12     139                  [US]
# 25             [6, 16, 13]              APTA     102                  [US]
# 26             [6, 18, 13]                12     127          [DE, FR, AT]
# 27              [6, 3, 15]                16     120                  [US]
# 28          [12, 6, 1, 14]                12     117          [GB, US, HK]
# 29                     [6]                16      96                  [US]
#
#                                   permanent_audiences  \
# 0   [pa:6bb3c83a-bfd6-4ba5-bf3e-9bbdfd4612e1, pa:b...
# 1           [pa:b6d69ea4-b214-4a39-b42e-4c033b850d77]
# 2           [pa:6bb3c83a-bfd6-4ba5-bf3e-9bbdfd4612e1]
# 3           [pa:26715c6d-a4a0-4815-aa63-845b291f1c41]
# 4           [pa:b6d69ea4-b214-4a39-b42e-4c033b850d77]
# 5           [pa:b6d69ea4-b214-4a39-b42e-4c033b850d77]
# 6           [pa:b6d69ea4-b214-4a39-b42e-4c033b850d77]
# 7           [pa:b6d69ea4-b214-4a39-b42e-4c033b850d77]
# 8   [pa:1e97eaa0-4736-41b2-b33d-e95517d0f8cb, pa:9...
# 9           [pa:e995ff56-e2ad-460e-a897-f70f4e1c5e3e]
# 10  [pa:12415b46-6819-4d98-b4f9-8dcc123c86f8, pa:8...
# 11  [pa:2c03342b-2c25-4383-8dfe-aca8c057ec5a, pa:5...
# 12          [pa:79245f22-9849-4566-b304-a021a7da5a4f]
# 13  [pa:185b46c8-1ba7-4f4c-b89e-74b917a25a8a, pa:5...
# 14          [pa:e995ff56-e2ad-460e-a897-f70f4e1c5e3e]
# 15          [pa:cb7b2cf6-1808-4f7b-a188-c95655e9f629]
# 16  [pa:2c5458e6-511b-4f28-949b-186be91744a4, pa:e...
# 17  [pa:6f295818-b61f-495f-91f1-af373c542f0a, pa:e...
# 18  [pa:46a3aa21-94a3-4635-bdc2-f494354e47b8, pa:b...
# 19          [pa:e995ff56-e2ad-460e-a897-f70f4e1c5e3e]
# 20          [pa:9a1c71b9-6530-49ab-b8fc-54f16a94a006]
# 21          [pa:6bb3c83a-bfd6-4ba5-bf3e-9bbdfd4612e1]
# 22  [pa:12415b46-6819-4d98-b4f9-8dcc123c86f8, pa:3...
# 23          [pa:46630a63-79c2-43a4-ba6c-b6a5917d6ef4]
# 24          [pa:e995ff56-e2ad-460e-a897-f70f4e1c5e3e]
# 25  [pa:b879dad8-8dd3-4518-a89e-243ddda6f514, pa:d...
# 26          [pa:185b46c8-1ba7-4f4c-b89e-74b917a25a8a]
# 27          [pa:79245f22-9849-4566-b304-a021a7da5a4f]
# 28  [pa:957cab85-03bc-4be6-a449-294d2b634186, pa:f...
# 29          [pa:185b46c8-1ba7-4f4c-b89e-74b917a25a8a]
#
#                      full_paths.MOVIE_DETAIL_OVERVIEW  \
# 0               /es/pelicula/loca-academia-de-policia
# 1   /es/pelicula/loca-academia-de-policia-2-su-pri...
# 2   /es/pelicula/loca-academia-de-policia-3-de-vue...
# 3                         /es/pelicula/es-por-tu-bien
# 4       /es/pelicula/police-academy-mission-to-moscow
# 5   /es/pelicula/police-academy-5-assignment-miami...
# 6                      /es/pelicula/vaya-par-de-polis
# 7   /es/pelicula/loca-academia-de-policia-6-ciudad...
# 8                            /es/pelicula/ciudadano-x
# 9                            /es/pelicula/prisioneros
# 10        /es/pelicula/sexo-en-nueva-york-la-pelicula
# 11                                 /es/pelicula/tenet
# 12                               /es/pelicula/colette
# 13                               /es/pelicula/la-caza
# 14                          /es/pelicula/contratiempo
# 15                      /es/pelicula/a-cambio-de-nada
# 16                               /es/pelicula/perdida
# 17                                 /es/pelicula/seven
# 18                   /es/pelicula/el-caballero-oscuro
# 19                      /es/pelicula/the-lovely-bones
# 20                     /es/pelicula/el-show-de-truman
# 21                             /es/pelicula/project-x
# 22                              /es/pelicula/langosta
# 23                           /es/pelicula/el-pianista
# 24               /es/pelicula/el-talento-de-mr-ripley
# 25                            /es/pelicula/casablanca
# 26                                  /es/pelicula/amor
# 27                              /es/pelicula/yo-tonya
# 28                          /es/pelicula/blade-runner
# 29                           /es/pelicula/the-fallout
#
#                                                 clips localized_release_date  \
# 0                                                 NaN                    NaN
# 1                                                 NaN                    NaN
# 2                                                 NaN                    NaN
# 3   [{'type': 'clip', 'provider': 'youtube', 'exte...                    NaN
# 4                                                 NaN                    NaN
# 5                                                 NaN                    NaN
# 6                                                 NaN                    NaN
# 7                                                 NaN                    NaN
# 8                                                 NaN                    NaN
# 9   [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 10                                                NaN                    NaN
# 11  [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 12                                                NaN                    NaN
# 13  [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 14  [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 15  [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 16  [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 17  [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 18  [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 19                                                NaN                    NaN
# 20  [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 21  [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 22  [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 23                                                NaN                    NaN
# 24                                                NaN                    NaN
# 25  [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 26                                                NaN   2013-01-11T00:00:00Z
# 27                                                NaN                    NaN
# 28  [{'type': 'trailer', 'provider': 'youtube', 'e...                    NaN
# 29                                                NaN   2022-01-27T00:00:00Z
#
#                                              upcoming
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  [{'package_id': 384, 'release_window_from': '2...
#
# [30 rows x 24 columns]

# %%
offers = pd.json_normalize(table['offers'][1])
offers
# Out:
#    jw_entity_id monetization_type  provider_id package_short_name  \
# 0      tm132303               buy            2                itu
# 1      tm132303               buy            2                itu
# 2      tm132303              rent            2                itu
# 3      tm132303              rent            2                itu
# 4      tm132303               buy           10                amz
# 5      tm132303               buy           10                amz
# 6      tm132303              rent           10                amz
# 7      tm132303              rent           10                amz
# 8      tm132303               buy           35                wki
# 9      tm132303               buy           35                wki
# 10     tm132303              rent           35                wki
# 11     tm132303              rent           35                wki
# 12     tm132303          flatrate          384                hbm
# 13     tm132303          flatrate          384                hbm
#
#     retail_price currency presentation_type country  \
# 0          10.99      EUR                hd      ES
# 1          10.99      EUR                sd      ES
# 2           3.99      EUR                hd      ES
# 3           3.99      EUR                sd      ES
# 4          10.99      EUR                hd      ES
# 5           7.99      EUR                sd      ES
# 6           3.99      EUR                hd      ES
# 7           3.99      EUR                sd      ES
# 8           8.99      EUR                hd      ES
# 9           8.99      EUR                sd      ES
# 10          3.99      EUR                hd      ES
# 11          3.99      EUR                sd      ES
# 12           NaN      EUR                hd      ES
# 13           NaN      EUR                sd      ES
#
#                                     urls.standard_web  \
# 0   https://tv.apple.com/es/movie/police-academy-2...
# 1   https://tv.apple.com/es/movie/police-academy-2...
# 2   https://tv.apple.com/es/movie/police-academy-2...
# 3   https://tv.apple.com/es/movie/police-academy-2...
# 4   https://app.primevideo.com/detail?gti=amzn1.dv...
# 5   https://app.primevideo.com/detail?gti=amzn1.dv...
# 6   https://app.primevideo.com/detail?gti=amzn1.dv...
# 7   https://app.primevideo.com/detail?gti=amzn1.dv...
# 8   https://rakuten.tv/es/movies/loca-academia-de-...
# 9   https://rakuten.tv/es/movies/loca-academia-de-...
# 10  https://rakuten.tv/es/movies/loca-academia-de-...
# 11  https://rakuten.tv/es/movies/loca-academia-de-...
# 12  https://play.hbomax.com/feature/urn:hbo:featur...
# 13  https://play.hbomax.com/feature/urn:hbo:featur...
#
#                                  urls.deeplink_rokuos  \
# 0   launch/551012?contentID=https%3A%2F%2Ftv.apple...
# 1   launch/551012?contentID=https%3A%2F%2Ftv.apple...
# 2   launch/551012?contentID=https%3A%2F%2Ftv.apple...
# 3   launch/551012?contentID=https%3A%2F%2Ftv.apple...
# 4      launch/13?contentID=B08QH27QBB&MediaType=movie
# 5      launch/13?contentID=B08QH27QBB&MediaType=movie
# 6      launch/13?contentID=B08QH27QBB&MediaType=movie
# 7      launch/13?contentID=B08QH27QBB&MediaType=movie
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  launch/61322?contentID=urn%3Ahbo%3Afeature%3AG...
# 13  launch/61322?contentID=urn%3Ahbo%3Afeature%3AG...
#
#                                     urls.deeplink_web  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   https://app.primevideo.com/watch?gti=amzn1.dv....
# 5   https://app.primevideo.com/watch?gti=amzn1.dv....
# 6   https://app.primevideo.com/watch?gti=amzn1.dv....
# 7   https://app.primevideo.com/watch?gti=amzn1.dv....
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
#
#     last_change_retail_price  last_change_difference  last_change_percent  \
# 0                        NaN                     NaN                  NaN
# 1                        NaN                     NaN                  NaN
# 2                        NaN                     NaN                  NaN
# 3                        NaN                     NaN                  NaN
# 4                        NaN                     NaN                  NaN
# 5                      10.99                    -3.0           -27.297543
# 6                        NaN                     NaN                  NaN
# 7                        NaN                     NaN                  NaN
# 8                      10.99                    -2.0           -18.198362
# 9                      10.99                    -2.0           -18.198362
# 10                       NaN                     NaN                  NaN
# 11                       NaN                     NaN                  NaN
# 12                       NaN                     NaN                  NaN
# 13                       NaN                     NaN                  NaN
#
#    last_change_date last_change_date_provider_id
# 0               NaN                          NaN
# 1               NaN                          NaN
# 2               NaN                          NaN
# 3               NaN                          NaN
# 4               NaN                          NaN
# 5        2022-02-25                2022-02-25_10
# 6               NaN                          NaN
# 7               NaN                          NaN
# 8        2022-02-25                2022-02-25_35
# 9        2022-02-25                2022-02-25_35
# 10              NaN                          NaN
# 11              NaN                          NaN
# 12              NaN                          NaN
# 13              NaN                          NaN

# %%
table.columns
# Out:
# Index(['jw_entity_id', 'id', 'title', 'full_path', 'poster',
#        'poster_blur_hash', 'backdrops', 'short_description',
#        'original_release_year', 'object_type', 'original_title', 'offers',
#        'scoring', 'credits', 'external_ids', 'genre_ids', 'age_certification',
#        'runtime', 'production_countries', 'permanent_audiences',
#        'full_paths.MOVIE_DETAIL_OVERVIEW', 'clips', 'localized_release_date',
#        'upcoming'],
#       dtype='object')

# %%
table_col = table.drop(['backdrops', 'external_ids', 'genre_ids', 'permanent_audiences', 
                            'localized_release_date','poster_blur_hash', 
                            'full_paths.MOVIE_DETAIL_OVERVIEW','clips', 'scoring','credits'], axis = 1)
table_col
# Out:
#    jw_entity_id       id                                              title  \
# 0      tm177480   177480                           Loca academia de policía
# 1      tm132303   132303      Loca academia de policía 2: Su primera misión
# 2      tm110483   110483  Loca academia de policía 3: De vuelta a la esc...
# 3      tm295177   295177                                     Es por tu bien
# 4      tm113836   113836          Loca academia de policía: Misión en Moscú
# 5       tm56719    56719  Loca academia de policía 5: Operación Miami Beach
# 6      tm101249   101249                                  Vaya par de polis
# 7      tm142794   142794         Loca academia de policía 6: Ciudad sitiada
# 8       tm14532    14532                                        Ciudadano X
# 9      tm166586   166586                                        Prisioneros
# 10      tm36583    36583                                 Sexo en Nueva York
# 11     tm455670   455670                                              Tenet
# 12     tm361759   361759                                            Colette
# 13      tm54023    54023                                            La caza
# 14     tm267401   267401                                       Contratiempo
# 15     tm197920   197920                                   A cambio de nada
# 16     tm157735   157735                                            Perdida
# 17      tm15897    15897                                      Seven (Se7en)
# 18      tm56184    56184                                El caballero oscuro
# 19     tm130044   130044                                   The Lovely Bones
# 20      tm68909    68909                                  El show de Truman
# 21      tm68272    68272                                         Proyecto X
# 22     tm143928   143928                                           Langosta
# 23     tm114752   114752                                        El pianista
# 24      tm43808    43808                           El talento de Mr. Ripley
# 25      tm77588    77588                                         Casablanca
# 26      tm42327    42327                                               Amor
# 27     tm244376   244376                                          Yo, Tonya
# 28      tm40461    40461                                       Blade Runner
# 29    tm1019345  1019345                                        The Fallout
#
#                                             full_path  \
# 0               /es/pelicula/loca-academia-de-policia
# 1   /es/pelicula/loca-academia-de-policia-2-su-pri...
# 2   /es/pelicula/loca-academia-de-policia-3-de-vue...
# 3                         /es/pelicula/es-por-tu-bien
# 4       /es/pelicula/police-academy-mission-to-moscow
# 5   /es/pelicula/police-academy-5-assignment-miami...
# 6                      /es/pelicula/vaya-par-de-polis
# 7   /es/pelicula/loca-academia-de-policia-6-ciudad...
# 8                            /es/pelicula/ciudadano-x
# 9                            /es/pelicula/prisioneros
# 10        /es/pelicula/sexo-en-nueva-york-la-pelicula
# 11                                 /es/pelicula/tenet
# 12                               /es/pelicula/colette
# 13                               /es/pelicula/la-caza
# 14                          /es/pelicula/contratiempo
# 15                      /es/pelicula/a-cambio-de-nada
# 16                               /es/pelicula/perdida
# 17                                 /es/pelicula/seven
# 18                   /es/pelicula/el-caballero-oscuro
# 19                      /es/pelicula/the-lovely-bones
# 20                     /es/pelicula/el-show-de-truman
# 21                             /es/pelicula/project-x
# 22                              /es/pelicula/langosta
# 23                           /es/pelicula/el-pianista
# 24               /es/pelicula/el-talento-de-mr-ripley
# 25                            /es/pelicula/casablanca
# 26                                  /es/pelicula/amor
# 27                              /es/pelicula/yo-tonya
# 28                          /es/pelicula/blade-runner
# 29                           /es/pelicula/the-fallout
#
#                          poster  \
# 0   /poster/187245208/{profile}
# 1   /poster/187306444/{profile}
# 2   /poster/187503917/{profile}
# 3    /poster/12139097/{profile}
# 4   /poster/188312475/{profile}
# 5   /poster/187504331/{profile}
# 6   /poster/249290420/{profile}
# 7   /poster/187569441/{profile}
# 8   /poster/244745240/{profile}
# 9    /poster/99687201/{profile}
# 10   /poster/10692095/{profile}
# 11  /poster/240293151/{profile}
# 12  /poster/237939531/{profile}
# 13  /poster/203472445/{profile}
# 14   /poster/10382158/{profile}
# 15   /poster/97626458/{profile}
# 16  /poster/139623830/{profile}
# 17    /poster/8655672/{profile}
# 18  /poster/161130479/{profile}
# 19  /poster/139857263/{profile}
# 20   /poster/76810863/{profile}
# 21  /poster/100745974/{profile}
# 22  /poster/100275907/{profile}
# 23   /poster/74766078/{profile}
# 24  /poster/240162960/{profile}
# 25   /poster/79268357/{profile}
# 26   /poster/11506952/{profile}
# 27   /poster/73815453/{profile}
# 28   /poster/53055384/{profile}
# 29  /poster/261395238/{profile}
#
#                                     short_description  original_release_year  \
# 0   En la academia de policía están a punto de fin...                   1984
# 1   Mahoney y sus amigos se han graduado ya en la ...                   1985
# 2   La academia está a punto de desaparecer. Para ...                   1986
# 3   La peor pesadilla que un padre puede tener con...                   2017
# 4   Ahora, los agentes más famosos y peculiares de...                   1994
# 5   El viejo capitán Lassard, el jefe de la academ...                   1988
# 6   Bruce Willis y Tracy Morgan dan vida a dos pol...                   2010
# 7   El comandante Lassard y su variopinto equipo d...                   1989
# 8   El joven y brillante especialista en medicina ...                   1995
# 9   Keller Dover se enfrenta a la peor de las pesa...                   2013
# 10  Carrie Bradshaw, columnista del "New York Star...                   2008
# 11  Armado solamente con una palabra, Tenet, el pr...                   2020
# 12  Cuenta la historia de Sidonie-Gabrielle Colett...                   2018
# 13  Tras un divorcio difícil, Lucas, de cuarenta a...                   2012
# 14  Barcelona, España. Adrián Doria, un joven y ex...                   2017
# 15  Darío, un chico de dieciséis años, disfruta de...                   2015
# 16  El día de su quinto aniversario de boda, Nick ...                   2014
# 17  El teniente Somerset, del departamento de homi...                   1995
# 18  Batman/Bruce Wayne regresa para continuar su g...                   2008
# 19  La historia gira en torno a Susie Salmon, que ...                   2009
# 20  Truman Burbank es un hombre corriente y algo i...                   1998
# 21  Tres estudiantes de último curso de instituto,...                   2012
# 22  Narra una historia de amor no convencional, am...                   2015
# 23  Varsovia, 1939. El pianista polaco de origen j...                   2002
# 24  Ser joven y despreocupado en medio de un paisa...                   1999
# 25  Durante la Segunda Guerra Mundial, Casablanca ...                   1942
# 26  Crudo retrato de la vejez y de la muerte. Jean...                   2012
# 27  Tonya Harding fue la primera mujer estadounide...                   2017
# 28  A principios del siglo XXI, la Tyrell Corporat...                   1982
# 29  Vada es una adolescente que trata de superar l...                   2022
#
#    object_type                            original_title  \
# 0        movie                            Police Academy
# 1        movie  Police Academy 2: Their First Assignment
# 2        movie        Police Academy 3: Back in Training
# 3        movie                            Es por tu bien
# 4        movie         Police Academy: Mission to Moscow
# 5        movie  Police Academy 5: Assignment Miami Beach
# 6        movie                                   Cop Out
# 7        movie        Police Academy 6: City Under Siege
# 8        movie                                 Citizen X
# 9        movie                                 Prisoners
# 10       movie                          Sex and the City
# 11       movie                                     Tenet
# 12       movie                                   Colette
# 13       movie                                    Jagten
# 14       movie                              Contratiempo
# 15       movie                          A cambio de nada
# 16       movie                                 Gone Girl
# 17       movie                                     Se7en
# 18       movie                           The Dark Knight
# 19       movie                          The Lovely Bones
# 20       movie                           The Truman Show
# 21       movie                                 Project X
# 22       movie                               The Lobster
# 23       movie                               The Pianist
# 24       movie                   The Talented Mr. Ripley
# 25       movie                                Casablanca
# 26       movie                                     Amour
# 27       movie                                  I, Tonya
# 28       movie                              Blade Runner
# 29       movie                               The Fallout
#
#                                                offers age_certification  \
# 0   [{'jw_entity_id': 'tm177480', 'monetization_ty...                12
# 1   [{'jw_entity_id': 'tm132303', 'monetization_ty...              APTA
# 2   [{'jw_entity_id': 'tm110483', 'monetization_ty...              APTA
# 3   [{'jw_entity_id': 'tm295177', 'monetization_ty...                12
# 4   [{'jw_entity_id': 'tm113836', 'monetization_ty...              APTA
# 5   [{'jw_entity_id': 'tm56719', 'monetization_typ...              APTA
# 6   [{'jw_entity_id': 'tm101249', 'monetization_ty...              APTA
# 7   [{'jw_entity_id': 'tm142794', 'monetization_ty...              APTA
# 8   [{'jw_entity_id': 'tm14532', 'monetization_typ...                18
# 9   [{'jw_entity_id': 'tm166586', 'monetization_ty...                16
# 10  [{'jw_entity_id': 'tm36583', 'monetization_typ...                16
# 11  [{'jw_entity_id': 'tm455670', 'monetization_ty...                12
# 12  [{'jw_entity_id': 'tm361759', 'monetization_ty...                12
# 13  [{'jw_entity_id': 'tm54023', 'monetization_typ...                12
# 14  [{'jw_entity_id': 'tm267401', 'monetization_ty...                12
# 15  [{'jw_entity_id': 'tm197920', 'monetization_ty...                12
# 16  [{'jw_entity_id': 'tm157735', 'monetization_ty...                16
# 17  [{'jw_entity_id': 'tm15897', 'monetization_typ...                18
# 18  [{'jw_entity_id': 'tm56184', 'monetization_typ...                16
# 19  [{'jw_entity_id': 'tm130044', 'monetization_ty...                12
# 20  [{'jw_entity_id': 'tm68909', 'monetization_typ...              APTA
# 21  [{'jw_entity_id': 'tm68272', 'monetization_typ...                18
# 22  [{'jw_entity_id': 'tm143928', 'monetization_ty...                16
# 23  [{'jw_entity_id': 'tm114752', 'monetization_ty...                12
# 24  [{'jw_entity_id': 'tm43808', 'monetization_typ...                12
# 25  [{'jw_entity_id': 'tm77588', 'monetization_typ...              APTA
# 26  [{'jw_entity_id': 'tm42327', 'monetization_typ...                12
# 27  [{'jw_entity_id': 'tm244376', 'monetization_ty...                16
# 28  [{'jw_entity_id': 'tm40461', 'monetization_typ...                12
# 29  [{'jw_entity_id': 'tm1019345', 'monetization_t...                16
#
#     runtime  production_countries  \
# 0        97                  [US]
# 1        87                  [US]
# 2        84                  [US]
# 3        93                  [ES]
# 4        83                  [US]
# 5        90                  [US]
# 6       107                  [US]
# 7        84                  [US]
# 8       105                  [US]
# 9       153                  [US]
# 10      145                  [US]
# 11      150              [US, GB]
# 12      111              [GB, US]
# 13      116              [SE, DK]
# 14      107                  [ES]
# 15       97                  [ES]
# 16      149                  [US]
# 17      127                  [US]
# 18      152              [GB, US]
# 19      130          [US, GB, NZ]
# 20      104                  [US]
# 21       88                  [US]
# 22      118  [NL, GB, FR, GR, IE]
# 23      150      [PL, GB, FR, DE]
# 24      139                  [US]
# 25      102                  [US]
# 26      127          [DE, FR, AT]
# 27      120                  [US]
# 28      117          [GB, US, HK]
# 29       96                  [US]
#
#                                              upcoming
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  [{'package_id': 384, 'release_window_from': '2...

# %%
table_col.rename(columns = {'original_title':'originalTitle'}, inplace = True)
table_col
# Out:
#    jw_entity_id       id                                              title  \
# 0      tm177480   177480                           Loca academia de policía
# 1      tm132303   132303      Loca academia de policía 2: Su primera misión
# 2      tm110483   110483  Loca academia de policía 3: De vuelta a la esc...
# 3      tm295177   295177                                     Es por tu bien
# 4      tm113836   113836          Loca academia de policía: Misión en Moscú
# 5       tm56719    56719  Loca academia de policía 5: Operación Miami Beach
# 6      tm101249   101249                                  Vaya par de polis
# 7      tm142794   142794         Loca academia de policía 6: Ciudad sitiada
# 8       tm14532    14532                                        Ciudadano X
# 9      tm166586   166586                                        Prisioneros
# 10      tm36583    36583                                 Sexo en Nueva York
# 11     tm455670   455670                                              Tenet
# 12     tm361759   361759                                            Colette
# 13      tm54023    54023                                            La caza
# 14     tm267401   267401                                       Contratiempo
# 15     tm197920   197920                                   A cambio de nada
# 16     tm157735   157735                                            Perdida
# 17      tm15897    15897                                      Seven (Se7en)
# 18      tm56184    56184                                El caballero oscuro
# 19     tm130044   130044                                   The Lovely Bones
# 20      tm68909    68909                                  El show de Truman
# 21      tm68272    68272                                         Proyecto X
# 22     tm143928   143928                                           Langosta
# 23     tm114752   114752                                        El pianista
# 24      tm43808    43808                           El talento de Mr. Ripley
# 25      tm77588    77588                                         Casablanca
# 26      tm42327    42327                                               Amor
# 27     tm244376   244376                                          Yo, Tonya
# 28      tm40461    40461                                       Blade Runner
# 29    tm1019345  1019345                                        The Fallout
#
#                                             full_path  \
# 0               /es/pelicula/loca-academia-de-policia
# 1   /es/pelicula/loca-academia-de-policia-2-su-pri...
# 2   /es/pelicula/loca-academia-de-policia-3-de-vue...
# 3                         /es/pelicula/es-por-tu-bien
# 4       /es/pelicula/police-academy-mission-to-moscow
# 5   /es/pelicula/police-academy-5-assignment-miami...
# 6                      /es/pelicula/vaya-par-de-polis
# 7   /es/pelicula/loca-academia-de-policia-6-ciudad...
# 8                            /es/pelicula/ciudadano-x
# 9                            /es/pelicula/prisioneros
# 10        /es/pelicula/sexo-en-nueva-york-la-pelicula
# 11                                 /es/pelicula/tenet
# 12                               /es/pelicula/colette
# 13                               /es/pelicula/la-caza
# 14                          /es/pelicula/contratiempo
# 15                      /es/pelicula/a-cambio-de-nada
# 16                               /es/pelicula/perdida
# 17                                 /es/pelicula/seven
# 18                   /es/pelicula/el-caballero-oscuro
# 19                      /es/pelicula/the-lovely-bones
# 20                     /es/pelicula/el-show-de-truman
# 21                             /es/pelicula/project-x
# 22                              /es/pelicula/langosta
# 23                           /es/pelicula/el-pianista
# 24               /es/pelicula/el-talento-de-mr-ripley
# 25                            /es/pelicula/casablanca
# 26                                  /es/pelicula/amor
# 27                              /es/pelicula/yo-tonya
# 28                          /es/pelicula/blade-runner
# 29                           /es/pelicula/the-fallout
#
#                          poster  \
# 0   /poster/187245208/{profile}
# 1   /poster/187306444/{profile}
# 2   /poster/187503917/{profile}
# 3    /poster/12139097/{profile}
# 4   /poster/188312475/{profile}
# 5   /poster/187504331/{profile}
# 6   /poster/249290420/{profile}
# 7   /poster/187569441/{profile}
# 8   /poster/244745240/{profile}
# 9    /poster/99687201/{profile}
# 10   /poster/10692095/{profile}
# 11  /poster/240293151/{profile}
# 12  /poster/237939531/{profile}
# 13  /poster/203472445/{profile}
# 14   /poster/10382158/{profile}
# 15   /poster/97626458/{profile}
# 16  /poster/139623830/{profile}
# 17    /poster/8655672/{profile}
# 18  /poster/161130479/{profile}
# 19  /poster/139857263/{profile}
# 20   /poster/76810863/{profile}
# 21  /poster/100745974/{profile}
# 22  /poster/100275907/{profile}
# 23   /poster/74766078/{profile}
# 24  /poster/240162960/{profile}
# 25   /poster/79268357/{profile}
# 26   /poster/11506952/{profile}
# 27   /poster/73815453/{profile}
# 28   /poster/53055384/{profile}
# 29  /poster/261395238/{profile}
#
#                                     short_description  original_release_year  \
# 0   En la academia de policía están a punto de fin...                   1984
# 1   Mahoney y sus amigos se han graduado ya en la ...                   1985
# 2   La academia está a punto de desaparecer. Para ...                   1986
# 3   La peor pesadilla que un padre puede tener con...                   2017
# 4   Ahora, los agentes más famosos y peculiares de...                   1994
# 5   El viejo capitán Lassard, el jefe de la academ...                   1988
# 6   Bruce Willis y Tracy Morgan dan vida a dos pol...                   2010
# 7   El comandante Lassard y su variopinto equipo d...                   1989
# 8   El joven y brillante especialista en medicina ...                   1995
# 9   Keller Dover se enfrenta a la peor de las pesa...                   2013
# 10  Carrie Bradshaw, columnista del "New York Star...                   2008
# 11  Armado solamente con una palabra, Tenet, el pr...                   2020
# 12  Cuenta la historia de Sidonie-Gabrielle Colett...                   2018
# 13  Tras un divorcio difícil, Lucas, de cuarenta a...                   2012
# 14  Barcelona, España. Adrián Doria, un joven y ex...                   2017
# 15  Darío, un chico de dieciséis años, disfruta de...                   2015
# 16  El día de su quinto aniversario de boda, Nick ...                   2014
# 17  El teniente Somerset, del departamento de homi...                   1995
# 18  Batman/Bruce Wayne regresa para continuar su g...                   2008
# 19  La historia gira en torno a Susie Salmon, que ...                   2009
# 20  Truman Burbank es un hombre corriente y algo i...                   1998
# 21  Tres estudiantes de último curso de instituto,...                   2012
# 22  Narra una historia de amor no convencional, am...                   2015
# 23  Varsovia, 1939. El pianista polaco de origen j...                   2002
# 24  Ser joven y despreocupado en medio de un paisa...                   1999
# 25  Durante la Segunda Guerra Mundial, Casablanca ...                   1942
# 26  Crudo retrato de la vejez y de la muerte. Jean...                   2012
# 27  Tonya Harding fue la primera mujer estadounide...                   2017
# 28  A principios del siglo XXI, la Tyrell Corporat...                   1982
# 29  Vada es una adolescente que trata de superar l...                   2022
#
#    object_type                             originalTitle  \
# 0        movie                            Police Academy
# 1        movie  Police Academy 2: Their First Assignment
# 2        movie        Police Academy 3: Back in Training
# 3        movie                            Es por tu bien
# 4        movie         Police Academy: Mission to Moscow
# 5        movie  Police Academy 5: Assignment Miami Beach
# 6        movie                                   Cop Out
# 7        movie        Police Academy 6: City Under Siege
# 8        movie                                 Citizen X
# 9        movie                                 Prisoners
# 10       movie                          Sex and the City
# 11       movie                                     Tenet
# 12       movie                                   Colette
# 13       movie                                    Jagten
# 14       movie                              Contratiempo
# 15       movie                          A cambio de nada
# 16       movie                                 Gone Girl
# 17       movie                                     Se7en
# 18       movie                           The Dark Knight
# 19       movie                          The Lovely Bones
# 20       movie                           The Truman Show
# 21       movie                                 Project X
# 22       movie                               The Lobster
# 23       movie                               The Pianist
# 24       movie                   The Talented Mr. Ripley
# 25       movie                                Casablanca
# 26       movie                                     Amour
# 27       movie                                  I, Tonya
# 28       movie                              Blade Runner
# 29       movie                               The Fallout
#
#                                                offers age_certification  \
# 0   [{'jw_entity_id': 'tm177480', 'monetization_ty...                12
# 1   [{'jw_entity_id': 'tm132303', 'monetization_ty...              APTA
# 2   [{'jw_entity_id': 'tm110483', 'monetization_ty...              APTA
# 3   [{'jw_entity_id': 'tm295177', 'monetization_ty...                12
# 4   [{'jw_entity_id': 'tm113836', 'monetization_ty...              APTA
# 5   [{'jw_entity_id': 'tm56719', 'monetization_typ...              APTA
# 6   [{'jw_entity_id': 'tm101249', 'monetization_ty...              APTA
# 7   [{'jw_entity_id': 'tm142794', 'monetization_ty...              APTA
# 8   [{'jw_entity_id': 'tm14532', 'monetization_typ...                18
# 9   [{'jw_entity_id': 'tm166586', 'monetization_ty...                16
# 10  [{'jw_entity_id': 'tm36583', 'monetization_typ...                16
# 11  [{'jw_entity_id': 'tm455670', 'monetization_ty...                12
# 12  [{'jw_entity_id': 'tm361759', 'monetization_ty...                12
# 13  [{'jw_entity_id': 'tm54023', 'monetization_typ...                12
# 14  [{'jw_entity_id': 'tm267401', 'monetization_ty...                12
# 15  [{'jw_entity_id': 'tm197920', 'monetization_ty...                12
# 16  [{'jw_entity_id': 'tm157735', 'monetization_ty...                16
# 17  [{'jw_entity_id': 'tm15897', 'monetization_typ...                18
# 18  [{'jw_entity_id': 'tm56184', 'monetization_typ...                16
# 19  [{'jw_entity_id': 'tm130044', 'monetization_ty...                12
# 20  [{'jw_entity_id': 'tm68909', 'monetization_typ...              APTA
# 21  [{'jw_entity_id': 'tm68272', 'monetization_typ...                18
# 22  [{'jw_entity_id': 'tm143928', 'monetization_ty...                16
# 23  [{'jw_entity_id': 'tm114752', 'monetization_ty...                12
# 24  [{'jw_entity_id': 'tm43808', 'monetization_typ...                12
# 25  [{'jw_entity_id': 'tm77588', 'monetization_typ...              APTA
# 26  [{'jw_entity_id': 'tm42327', 'monetization_typ...                12
# 27  [{'jw_entity_id': 'tm244376', 'monetization_ty...                16
# 28  [{'jw_entity_id': 'tm40461', 'monetization_typ...                12
# 29  [{'jw_entity_id': 'tm1019345', 'monetization_t...                16
#
#     runtime  production_countries  \
# 0        97                  [US]
# 1        87                  [US]
# 2        84                  [US]
# 3        93                  [ES]
# 4        83                  [US]
# 5        90                  [US]
# 6       107                  [US]
# 7        84                  [US]
# 8       105                  [US]
# 9       153                  [US]
# 10      145                  [US]
# 11      150              [US, GB]
# 12      111              [GB, US]
# 13      116              [SE, DK]
# 14      107                  [ES]
# 15       97                  [ES]
# 16      149                  [US]
# 17      127                  [US]
# 18      152              [GB, US]
# 19      130          [US, GB, NZ]
# 20      104                  [US]
# 21       88                  [US]
# 22      118  [NL, GB, FR, GR, IE]
# 23      150      [PL, GB, FR, DE]
# 24      139                  [US]
# 25      102                  [US]
# 26      127          [DE, FR, AT]
# 27      120                  [US]
# 28      117          [GB, US, HK]
# 29       96                  [US]
#
#                                              upcoming
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  [{'package_id': 384, 'release_window_from': '2...

# %%
recommend = pd.read_csv('../data/recommend.csv')
recommend
# Out:
#                          tconst  averageRating  numVotes  \
# 0     imdb.com/title/tt15097216            9.4    185162
# 1      imdb.com/title/tt0252487            9.3     39990
# 2      imdb.com/title/tt0111161            9.3   2572812
# 3      imdb.com/title/tt5354160            9.2     25759
# 4     imdb.com/title/tt10189514            9.2    109309
# ...                         ...            ...       ...
# 2546   imdb.com/title/tt0099763            7.0     35438
# 2547   imdb.com/title/tt6324278            7.0     37215
# 2548   imdb.com/title/tt0061747            7.0     38612
# 2549  imdb.com/title/tt10083340            7.0     38248
# 2550   imdb.com/title/tt0048750            7.0     37818
#
#                             primaryTitle                       originalTitle  \
# 0                               Jai Bhim                            Jai Bhim
# 1                        The Chaos Class                      Hababam Sinifi
# 2               The Shawshank Redemption            The Shawshank Redemption
# 3                            Mirror Game                            Aynabaji
# 4                        Soorarai Pottru                     Soorarai Pottru
# ...                                  ...                                 ...
# 2546  Henry: Portrait of a Serial Killer  Henry: Portrait of a Serial Killer
# 2547                          Abominable                          Abominable
# 2548                       Hang 'Em High                       Hang 'Em High
# 2549                 Gangubai Kathiawadi                 Gangubai Kathiawadi
# 2550              The Trouble with Harry              The Trouble with Harry
#
#       startYear  runtimeMinutes                      genres
# 0          2021             164         Crime,Drama,Mystery
# 1          1975              87                Comedy,Drama
# 2          1994             142                       Drama
# 3          2016             147      Crime,Mystery,Thriller
# 4          2020             153                       Drama
# ...         ...             ...                         ...
# 2546       1986              83       Biography,Crime,Drama
# 2547       2019              97  Adventure,Animation,Comedy
# 2548       1968             114               Drama,Western
# 2549       2022             152       Biography,Crime,Drama
# 2550       1955              99              Comedy,Mystery
#
# [2551 rows x 8 columns]

# %%
my_recommendation = pd.merge(recommend, table_col, how='inner', on=['originalTitle'], left_on=None, right_on=None,
left_index=False, right_index=False, sort=True)
my_recommendation
# Out:
#                       tconst  averageRating  numVotes  \
# 0   imdb.com/title/tt1602620            7.9     98773
# 1   imdb.com/title/tt0083658            8.1    745775
# 2   imdb.com/title/tt0034583            8.5    557603
# 3   imdb.com/title/tt4857264            8.0    169470
# 4   imdb.com/title/tt2267998            8.1    946438
# 5   imdb.com/title/tt5580036            7.5    207802
# 6   imdb.com/title/tt2106476            8.3    317692
# 7   imdb.com/title/tt1392214            8.1    674835
# 8   imdb.com/title/tt0114369            8.6   1578001
# 9   imdb.com/title/tt6723592            7.3    462510
# 10  imdb.com/title/tt0468569            9.0   2539302
# 11  imdb.com/title/tt3464902            7.1    246582
# 12  imdb.com/title/tt0253474            8.5    801406
# 13  imdb.com/title/tt0134119            7.4    204068
# 14  imdb.com/title/tt0120382            8.2   1029781
#
#                primaryTitle            originalTitle  startYear  \
# 0                     Amour                    Amour       2012
# 1              Blade Runner             Blade Runner       1982
# 2                Casablanca               Casablanca       1942
# 3       The Invisible Guest             Contratiempo       2016
# 4                 Gone Girl                Gone Girl       2014
# 5                  I, Tonya                 I, Tonya       2017
# 6                  The Hunt                   Jagten       2012
# 7                 Prisoners                Prisoners       2013
# 8                     Se7en                    Se7en       1995
# 9                     Tenet                    Tenet       2020
# 10          The Dark Knight          The Dark Knight       2008
# 11              The Lobster              The Lobster       2015
# 12              The Pianist              The Pianist       2002
# 13  The Talented Mr. Ripley  The Talented Mr. Ripley       1999
# 14          The Truman Show          The Truman Show       1998
#
#     runtimeMinutes                  genres jw_entity_id      id  ...  \
# 0              127                   Drama      tm42327   42327  ...
# 1              117     Action,Drama,Sci-Fi      tm40461   40461  ...
# 2              102       Drama,Romance,War      tm77588   77588  ...
# 3              106     Crime,Drama,Mystery     tm267401  267401  ...
# 4              149  Drama,Mystery,Thriller     tm157735  157735  ...
# 5              119  Biography,Comedy,Drama     tm244376  244376  ...
# 6              115                   Drama      tm54023   54023  ...
# 7              153     Crime,Drama,Mystery     tm166586  166586  ...
# 8              127     Crime,Drama,Mystery      tm15897   15897  ...
# 9              150  Action,Sci-Fi,Thriller     tm455670  455670  ...
# 10             152      Action,Crime,Drama      tm56184   56184  ...
# 11             119    Comedy,Drama,Romance     tm143928  143928  ...
# 12             150   Biography,Drama,Music     tm114752  114752  ...
# 13             139    Crime,Drama,Thriller      tm43808   43808  ...
# 14             103            Comedy,Drama      tm68909   68909  ...
#
#                                full_path                       poster  \
# 0                      /es/pelicula/amor   /poster/11506952/{profile}
# 1              /es/pelicula/blade-runner   /poster/53055384/{profile}
# 2                /es/pelicula/casablanca   /poster/79268357/{profile}
# 3              /es/pelicula/contratiempo   /poster/10382158/{profile}
# 4                   /es/pelicula/perdida  /poster/139623830/{profile}
# 5                  /es/pelicula/yo-tonya   /poster/73815453/{profile}
# 6                   /es/pelicula/la-caza  /poster/203472445/{profile}
# 7               /es/pelicula/prisioneros   /poster/99687201/{profile}
# 8                     /es/pelicula/seven    /poster/8655672/{profile}
# 9                     /es/pelicula/tenet  /poster/240293151/{profile}
# 10      /es/pelicula/el-caballero-oscuro  /poster/161130479/{profile}
# 11                 /es/pelicula/langosta  /poster/100275907/{profile}
# 12              /es/pelicula/el-pianista   /poster/74766078/{profile}
# 13  /es/pelicula/el-talento-de-mr-ripley  /poster/240162960/{profile}
# 14        /es/pelicula/el-show-de-truman   /poster/76810863/{profile}
#
#                                     short_description original_release_year  \
# 0   Crudo retrato de la vejez y de la muerte. Jean...                  2012
# 1   A principios del siglo XXI, la Tyrell Corporat...                  1982
# 2   Durante la Segunda Guerra Mundial, Casablanca ...                  1942
# 3   Barcelona, España. Adrián Doria, un joven y ex...                  2017
# 4   El día de su quinto aniversario de boda, Nick ...                  2014
# 5   Tonya Harding fue la primera mujer estadounide...                  2017
# 6   Tras un divorcio difícil, Lucas, de cuarenta a...                  2012
# 7   Keller Dover se enfrenta a la peor de las pesa...                  2013
# 8   El teniente Somerset, del departamento de homi...                  1995
# 9   Armado solamente con una palabra, Tenet, el pr...                  2020
# 10  Batman/Bruce Wayne regresa para continuar su g...                  2008
# 11  Narra una historia de amor no convencional, am...                  2015
# 12  Varsovia, 1939. El pianista polaco de origen j...                  2002
# 13  Ser joven y despreocupado en medio de un paisa...                  1999
# 14  Truman Burbank es un hombre corriente y algo i...                  1998
#
#     object_type                                             offers  \
# 0         movie  [{'jw_entity_id': 'tm42327', 'monetization_typ...
# 1         movie  [{'jw_entity_id': 'tm40461', 'monetization_typ...
# 2         movie  [{'jw_entity_id': 'tm77588', 'monetization_typ...
# 3         movie  [{'jw_entity_id': 'tm267401', 'monetization_ty...
# 4         movie  [{'jw_entity_id': 'tm157735', 'monetization_ty...
# 5         movie  [{'jw_entity_id': 'tm244376', 'monetization_ty...
# 6         movie  [{'jw_entity_id': 'tm54023', 'monetization_typ...
# 7         movie  [{'jw_entity_id': 'tm166586', 'monetization_ty...
# 8         movie  [{'jw_entity_id': 'tm15897', 'monetization_typ...
# 9         movie  [{'jw_entity_id': 'tm455670', 'monetization_ty...
# 10        movie  [{'jw_entity_id': 'tm56184', 'monetization_typ...
# 11        movie  [{'jw_entity_id': 'tm143928', 'monetization_ty...
# 12        movie  [{'jw_entity_id': 'tm114752', 'monetization_ty...
# 13        movie  [{'jw_entity_id': 'tm43808', 'monetization_typ...
# 14        movie  [{'jw_entity_id': 'tm68909', 'monetization_typ...
#
#    age_certification runtime  production_countries upcoming
# 0                 12     127          [DE, FR, AT]      NaN
# 1                 12     117          [GB, US, HK]      NaN
# 2               APTA     102                  [US]      NaN
# 3                 12     107                  [ES]      NaN
# 4                 16     149                  [US]      NaN
# 5                 16     120                  [US]      NaN
# 6                 12     116              [SE, DK]      NaN
# 7                 16     153                  [US]      NaN
# 8                 18     127                  [US]      NaN
# 9                 12     150              [US, GB]      NaN
# 10                16     152              [GB, US]      NaN
# 11                16     118  [NL, GB, FR, GR, IE]      NaN
# 12                12     150      [PL, GB, FR, DE]      NaN
# 13                12     139                  [US]      NaN
# 14              APTA     104                  [US]      NaN
#
# [15 rows x 21 columns]
