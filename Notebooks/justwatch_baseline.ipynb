# %%
import pandas as pd
from justwatch import JustWatch

# %%
proveedor = 'dsn'
just_watch = JustWatch(country='ES', providers=[proveedor])

# %%
peli_key = 'rain'
lista_pelis = just_watch.search_for_item(query=peli_key, content_types=['movie'])

# %%
total_list = len(lista_pelis['items'])
total_list
# Out:
# 30

# %%
total_pelis = []
for item in range(total_list):
    total_pelis.append(lista_pelis['items'][item]['id'])
total_pelis
# Out:
# [108123,
#  51622,
#  6677,
#  68670,
#  43389,
#  221534,
#  61543,
#  49812,
#  36538,
#  211285,
#  112770,
#  31389,
#  148335,
#  122601,
#  192727,
#  192362,
#  471779,
#  32384,
#  239761,
#  375780,
#  1390,
#  499045,
#  178089,
#  410590,
#  170082,
#  156806,
#  137046,
#  311319,
#  138802,
#  193388]

# %%
len(total_pelis)
# Out:
# 30

# %%
extra_info = []
for e in range(len(total_pelis)):
    try:
        peli = just_watch.get_title(title_id=total_pelis[e])
        extra_info.append(peli)
    except:
        extra_info.append('/-----------------------------no info-----------------------------------/')
extra_info
# Out:
# [{'jw_entity_id': 'tm108123',
#   'id': 108123,
#   'title': 'El pasajero de la lluvia',
#   'full_path': '/es/pelicula/el-pasajero-de-la-lluvia',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/el-pasajero-de-la-lluvia'},
#   'poster': '/poster/137559485/{profile}',
#   'poster_blur_hash': 'TLG*p7^$0g4T9aJ:pJ$%%0OFniX9',
#   'backdrops': [{'backdrop_url': '/backdrop/175179036/{profile}',
#     'backdrop_blur_hash': 'L5AvIQ-V0ew]jERjR*Nb}@s:IoI='},
#    {'backdrop_url': '/backdrop/175179035/{profile}',
#     'backdrop_blur_hash': 'LBDuoP,pnO0L-;bHE1s:S~IVkWs:'},
#    {'backdrop_url': '/backdrop/209465524/{profile}',
#     'backdrop_blur_hash': 'LSNb3=%eE20#9]s:RkNGadRjsA-A'},
#    {'backdrop_url': '/backdrop/175179037/{profile}',
#     'backdrop_blur_hash': 'L99%^?8^.9RO%NoeV@niemjFoLay'},
#    {'backdrop_url': '/backdrop/246931496/{profile}',
#     'backdrop_blur_hash': 'LCAT4qDgXo9@xbNGt7s:SNRjs;n+'}],
#   'short_description': 'Mélancolie, una atractiva joven, es asaltada y violada por un misterioso desconocido. La chica consigue quitarle la pistola al violador y lo asesina; después arroja el cadáver al fondo del océano. Al cabo de unos días, cuando el cuerpo sale a flote, un oficial del ejército americano acusa a Mélancolie no sólo de asesinato, sino también del robo de un dinero destinado al ejército de los Estados Unidos.',
#   'original_release_year': 1970,
#   'object_type': 'movie',
#   'original_title': 'Le passager de la pluie',
#   'offers': [{'jw_entity_id': 'tm108123',
#     'monetization_type': 'flatrate',
#     'provider_id': 119,
#     'package_short_name': 'prv',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.b4698f29-17d4-465f-8be1-6740cae03ea0',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.b4698f29-17d4-465f-8be1-6740cae03ea0',
#      'deeplink_rokuos': 'launch/13?contentID=B09QG6DXL4&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm108123',
#     'monetization_type': 'flatrate',
#     'provider_id': 119,
#     'package_short_name': 'prv',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.b4698f29-17d4-465f-8be1-6740cae03ea0',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.b4698f29-17d4-465f-8be1-6740cae03ea0',
#      'deeplink_rokuos': 'launch/13?contentID=B09QG6DXL4&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'tmdb:id', 'value': 27889},
#    {'provider_type': 'imdb:score', 'value': 6.7},
#    {'provider_type': 'imdb:votes', 'value': 3239},
#    {'provider_type': 'tmdb:score', 'value': 6.4},
#    {'provider_type': 'imdb:multiplied', 'value': 21701.3},
#    {'provider_type': 'tmdb:popularity', 'value': 6.659}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Col. Harry Dobbs',
#     'person_id': 16868,
#     'name': 'Charles Bronson'},
#    {'role': 'ACTOR',
#     'character_name': "Mélancolie 'Mellie' Mau",
#     'person_id': 127226,
#     'name': 'Marlène Jobert'},
#    {'role': 'ACTOR',
#     'character_name': 'Tony Mau',
#     'person_id': 1056,
#     'name': 'Gabriele Tinti'},
#    {'role': 'ACTOR',
#     'character_name': 'Inspector Toussaint',
#     'person_id': 219001,
#     'name': 'Jean Gaven'},
#    {'role': 'ACTOR',
#     'character_name': 'M. Armand',
#     'person_id': 111647,
#     'name': 'Jean Piat'},
#    {'role': 'ACTOR',
#     'character_name': 'Nicole',
#     'person_id': 51603,
#     'name': 'Jill Ireland'},
#    {'role': 'ACTOR',
#     'character_name': 'Tania',
#     'person_id': 30518,
#     'name': 'Corinne Marchand'},
#    {'role': 'ACTOR',
#     'character_name': 'Juliette',
#     'person_id': 55692,
#     'name': 'Annie Cordy'},
#    {'role': 'ACTOR',
#     'character_name': 'Madeleine Legauff',
#     'person_id': 520491,
#     'name': 'Ellen Bahl'},
#    {'role': 'ACTOR',
#     'character_name': 'U.S. officer',
#     'person_id': 533877,
#     'name': 'Steve Eckardt'},
#    {'role': 'ACTOR',
#     'character_name': "Hostess at Tania's",
#     'person_id': 90121,
#     'name': 'Marika Green'},
#    {'role': 'ACTOR', 'person_id': 538005, 'name': 'Jean-Daniel Ehrmann'},
#    {'role': 'ACTOR', 'person_id': 504374, 'name': 'Yves Massard'},
#    {'role': 'ACTOR',
#     'character_name': 'The Passenger (Mac Guffin)',
#     'person_id': 90251,
#     'name': 'Marc Mazza'},
#    {'role': 'ACTOR',
#     'character_name': 'Station Master',
#     'person_id': 71638,
#     'name': 'Marcel Pérès'},
#    {'role': 'DIRECTOR', 'person_id': 105855, 'name': 'René Clément'},
#    {'role': 'EDITOR', 'person_id': 105859, 'name': 'Françoise Javet'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 75661,
#     'name': 'Francis Lai'},
#    {'role': 'PRODUCER', 'person_id': 33220, 'name': 'Serge Silberman'},
#    {'role': 'PRODUCTION_DESIGN', 'person_id': 28589, 'name': 'Pierre Guffroy'},
#    {'role': 'WRITER', 'person_id': 219002, 'name': 'Sébastien Japrisot'}],
#   'external_ids': [{'provider': 'tmdb', 'external_id': '27889'},
#    {'provider': 'rovi', 'external_id': '1067483'},
#    {'provider': 'gowatchit', 'external_id': '5223'},
#    {'provider': 'imdb', 'external_id': 'tt0064791'},
#    {'provider': 'imdb', 'external_id': 'tt10065674'},
#    {'provider': 'eidr', 'external_id': '10.5240/2A7D-A168-62BB-545C-1D23-W'},
#    {'provider': 'tmdb_latest', 'external_id': '27889'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0064791'},
#    {'provider': 'iva', 'external_id': '40104'},
#    {'provider': 'tms', 'external_id': 'MV000012210000'}],
#   'genre_ids': [12, 4, 6, 18],
#   'runtime': 120,
#   'production_countries': ['IT', 'FR'],
#   'permanent_audiences': ['pa:e995ff56-e2ad-460e-a897-f70f4e1c5e3e']},
#  {'jw_entity_id': 'tm51622',
#   'id': 51622,
#   'title': 'Muerte en Bangkok',
#   'full_path': '/es/pelicula/muerte-en-bangkok',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/muerte-en-bangkok'},
#   'poster': '/poster/191726124/{profile}',
#   'poster_blur_hash': 'TcFPHSQ,xv?]IB%2ITD,t5R7M|S4',
#   'backdrops': [{'backdrop_url': '/backdrop/10988782/{profile}',
#     'backdrop_blur_hash': 'LSKBE$q[vw_35QRl0M?F9HbbRiIt'},
#    {'backdrop_url': '/backdrop/10988783/{profile}',
#     'backdrop_blur_hash': 'LT9RbWp1Ma$xx_WmfSxsS7oyofjX'},
#    {'backdrop_url': '/backdrop/261670512/{profile}',
#     'backdrop_blur_hash': 'LU9b3Ep1Ma$wtTWTa~xtS8t6s,ac'},
#    {'backdrop_url': '/backdrop/252303703/{profile}',
#     'backdrop_blur_hash': 'LHG%ox0KSd,^0d}]R.rW^+v~wwt8'},
#    {'backdrop_url': '/backdrop/10988784/{profile}',
#     'backdrop_blur_hash': 'LPLqUz_4~q-=?wRkogjExut6IAoI'}],
#   'short_description': 'Kong es un asesino profesional, sordomudo desde la infancia. Trabaja en las calles más duras de Bangkok. Es letal. Es insensible. Lleva a cabo sus horribles encargos con total frialdad, es su venganza contra el mundo. Finalmente, se le presenta una oportunidad para un cambio de vida en la forma de una chica que le proporciona la única ternura y calidez que ha sentido en su vida. Podría salvarle, pero también podría matarle. Primera parte de la "trilogía de Bangkok", continuada por One Take Only (2001) y 1+1=0 (2002).',
#   'original_release_year': 1999,
#   'object_type': 'movie',
#   'original_title': 'เพชฌฆาตเงียบอันตราย',
#   'offers': [{'jw_entity_id': 'tm51622',
#     'monetization_type': 'flatrate',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/muerte-en-bangkok'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm51622',
#     'monetization_type': 'flatrate',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/muerte-en-bangkok'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm51622',
#     'monetization_type': 'rent',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'retail_price': 3.95,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/muerte-en-bangkok'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm51622',
#     'monetization_type': 'rent',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'retail_price': 3.95,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/muerte-en-bangkok'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm51622',
#     'monetization_type': 'flatrate',
#     'provider_id': 119,
#     'package_short_name': 'prv',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.c0bfb55a-a1fb-4533-a5e0-21800f801838',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.c0bfb55a-a1fb-4533-a5e0-21800f801838',
#      'deeplink_rokuos': 'launch/13?contentID=B09PMX8QHC&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm51622',
#     'monetization_type': 'flatrate',
#     'provider_id': 119,
#     'package_short_name': 'prv',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.c0bfb55a-a1fb-4533-a5e0-21800f801838',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.c0bfb55a-a1fb-4533-a5e0-21800f801838',
#      'deeplink_rokuos': 'launch/13?contentID=B09PMX8QHC&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'imdb:votes', 'value': 3665},
#    {'provider_type': 'tmdb:id', 'value': 3173},
#    {'provider_type': 'tmdb:popularity', 'value': 4.63},
#    {'provider_type': 'tmdb:score', 'value': 5.5},
#    {'provider_type': 'imdb:multiplied', 'value': 23822.5},
#    {'provider_type': 'imdb:score', 'value': 6.5}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Fon',
#     'person_id': 445258,
#     'name': 'Premsinee Ratanasopha'},
#    {'role': 'ACTOR',
#     'character_name': 'Aorn',
#     'person_id': 145366,
#     'name': 'Patharawarin Timkul'},
#    {'role': 'ACTOR',
#     'character_name': 'Jo',
#     'person_id': 143643,
#     'name': 'Pisek Intrakanchit'},
#    {'role': 'ACTOR', 'person_id': 445259, 'name': 'Korkiate Limpapat'},
#    {'role': 'ACTOR', 'person_id': 445260, 'name': 'Piya Boonnak'},
#    {'role': 'ACTOR',
#     'character_name': 'Kong',
#     'person_id': 143528,
#     'name': 'Pawarith Monkolpisit'},
#    {'role': 'DIRECTOR', 'person_id': 74347, 'name': 'Oxide Pang Chun'},
#    {'role': 'DIRECTOR', 'person_id': 21936, 'name': 'Danny Pang'},
#    {'role': 'EDITOR', 'person_id': 74347, 'name': 'Oxide Pang Chun'},
#    {'role': 'EDITOR', 'person_id': 21936, 'name': 'Danny Pang'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 412397,
#     'name': 'Brian L. Marcar'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 419935,
#     'name': 'Pracha Maleenont'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 136322,
#     'name': 'Adirek Wattaleela'},
#    {'role': 'PRODUCER', 'person_id': 136321, 'name': 'Nonzee Nimibutr'},
#    {'role': 'PRODUCER', 'person_id': 445264, 'name': 'SirLaosson Dara'},
#    {'role': 'WRITER', 'person_id': 21936, 'name': 'Danny Pang'},
#    {'role': 'WRITER', 'person_id': 74347, 'name': 'Oxide Pang Chun'}],
#   'external_ids': [{'provider': 'tms', 'external_id': 'MV002201700000'},
#    {'provider': 'tmdb_latest', 'external_id': '3173'},
#    {'provider': 'eidr', 'external_id': '10.5240/444F-A94B-C644-6904-04E0-V'},
#    {'provider': 'rovi', 'external_id': '1393796'},
#    {'provider': 'imdb', 'external_id': 'tt0263101'},
#    {'provider': 'gowatchit', 'external_id': '34848'},
#    {'provider': 'iva', 'external_id': '699865'},
#    {'provider': 'tmdb', 'external_id': '3173'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0263101'}],
#   'genre_ids': [12, 13, 1, 4, 6],
#   'age_certification': '18',
#   'runtime': 105,
#   'production_countries': ['TH']},
#  {'jw_entity_id': 'tm6677',
#   'id': 6677,
#   'title': 'Bajo la lluvia',
#   'full_path': '/es/pelicula/rain',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/rain'},
#   'poster': '/poster/111773626/{profile}',
#   'poster_blur_hash': 'TJBzE@aj02V^WBIUD%WCt7-:t7xt',
#   'backdrops': [{'backdrop_url': '/backdrop/174432125/{profile}',
#     'backdrop_blur_hash': 'LGCP@e%Mt7Rj%MRjj[Rj00M{WBj['},
#    {'backdrop_url': '/backdrop/267048843/{profile}',
#     'backdrop_blur_hash': 'LOIrELIUWBM{00ayD%ay-;Rjt7WB'},
#    {'backdrop_url': '/backdrop/181038095/{profile}',
#     'backdrop_blur_hash': 'LFGIcGIU~V-:_2IVM|t7RkE1s:M|'}],
#   'short_description': 'Debido a una extraña epidemia, los pasajeros de un barco son obligados a desembarcar en una isla. Entre ellos se encuentran una prostituta (Joan Crawford) y un misionero que la acosa.',
#   'original_release_year': 1932,
#   'object_type': 'movie',
#   'original_title': 'Rain',
#   'offers': [{'jw_entity_id': 'tm6677',
#     'monetization_type': 'flatrate',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/bajo-la-lluvia'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm6677',
#     'monetization_type': 'rent',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'retail_price': 1.95,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/bajo-la-lluvia'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm6677',
#     'monetization_type': 'flatrate',
#     'provider_id': 445,
#     'package_short_name': 'cla',
#     'urls': {'standard_web': 'http://www.classixapp.com'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'imdb:multiplied', 'value': 18609.3},
#    {'provider_type': 'tmdb:popularity', 'value': 3.696},
#    {'provider_type': 'tmdb:id', 'value': 61369},
#    {'provider_type': 'imdb:score', 'value': 6.9},
#    {'provider_type': 'imdb:votes', 'value': 2697},
#    {'provider_type': 'tmdb:score', 'value': 7.3}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Sadie Thompson',
#     'person_id': 33316,
#     'name': 'Joan Crawford'},
#    {'role': 'ACTOR',
#     'character_name': 'Alfred Davidson',
#     'person_id': 27571,
#     'name': 'Walter Huston'},
#    {'role': 'ACTOR',
#     'character_name': 'Dr. Robert MacPhail',
#     'person_id': 53977,
#     'name': 'Matt Moore'},
#    {'role': 'ACTOR',
#     'character_name': 'Joe Horn',
#     'person_id': 27177,
#     'name': 'Guy Kibbee'},
#    {'role': 'ACTOR',
#     'character_name': "Sergeant Tim O'Hara",
#     'person_id': 137835,
#     'name': 'William Gargan'},
#    {'role': 'ACTOR',
#     'character_name': 'Mrs. Davidson',
#     'person_id': 27179,
#     'name': 'Beulah Bondi'},
#    {'role': 'ACTOR',
#     'character_name': 'Mrs. MacPhail',
#     'person_id': 578549,
#     'name': 'Kendall Lee'},
#    {'role': 'ACTOR',
#     'character_name': 'Hodgson',
#     'person_id': 544532,
#     'name': 'Fred Howard'},
#    {'role': 'ACTOR',
#     'character_name': 'Griggs',
#     'person_id': 152841,
#     'name': 'Ben Hendricks Jr.'},
#    {'role': 'ACTOR',
#     'character_name': 'Ameena',
#     'person_id': 579921,
#     'name': 'Mary Shaw'},
#    {'role': 'ACTOR',
#     'character_name': 'Quartermaster Bates',
#     'person_id': 49040,
#     'name': 'Walter Catlett'},
#    {'role': 'ASSISTANT_DIRECTOR', 'person_id': 154306, 'name': 'Nate Watt'},
#    {'role': 'DIRECTOR', 'person_id': 21692, 'name': 'Lewis Milestone'},
#    {'role': 'EDITOR', 'person_id': 154978, 'name': 'Duncan Mansfield'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 28734,
#     'name': 'Joseph M. Schenck'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 21793,
#     'name': 'Alfred Newman'},
#    {'role': 'PRODUCER', 'person_id': 21692, 'name': 'Lewis Milestone'},
#    {'role': 'SCREENPLAY', 'person_id': 21701, 'name': 'Maxwell Anderson'}],
#   'external_ids': [{'provider': 'tmdb_latest', 'external_id': '61369'},
#    {'provider': 'imdb', 'external_id': 'tt0023369'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0023369'},
#    {'provider': 'tms', 'external_id': 'MV000047550000'},
#    {'provider': 'eidr', 'external_id': '10.5240/2C7A-424B-9526-6353-21D6-U'},
#    {'provider': 'rovi', 'external_id': '422963'},
#    {'provider': 'iva', 'external_id': '56061'},
#    {'provider': 'tmdb', 'external_id': '61369'},
#    {'provider': 'gowatchit', 'external_id': '23912'}],
#   'genre_ids': [6],
#   'runtime': 94,
#   'production_countries': ['US']},
#  {'jw_entity_id': 'tm68670',
#   'id': 68670,
#   'title': 'Rain',
#   'full_path': '/es/pelicula/rain-2012',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/rain-2012'},
#   'poster': '/poster/139151921/{profile}',
#   'poster_blur_hash': 'ThEyb|s:ay00f7WB?ba|kBIUayWV',
#   'short_description': "A poetic portrait of the world-renowned Ballet de l'Opéra national de Paris as they mount a new work by famed contemporary choreographer Anne Teresa De Keersmaeker, Rain is a formalist exercise in documentary filmmaking that at times resembles long lost outtakes from The Red Shoes.",
#   'original_release_year': 2012,
#   'object_type': 'movie',
#   'original_title': 'Rain',
#   'offers': [{'jw_entity_id': 'tm68670',
#     'monetization_type': 'flatrate',
#     'provider_id': 100,
#     'package_short_name': 'gdc',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://guidedoc.tv/documentary/rain___-documentary-film/'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'imdb:score', 'value': 7.8},
#    {'provider_type': 'imdb:votes', 'value': 23},
#    {'provider_type': 'tmdb:score', 'value': 6.3},
#    {'provider_type': 'imdb:multiplied', 'value': 179.4},
#    {'provider_type': 'tmdb:popularity', 'value': 0.964},
#    {'provider_type': 'tmdb:id', 'value': 201781}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Herself',
#     'person_id': 256095,
#     'name': 'Anne Teresa De Keersmaeker'},
#    {'role': 'DIRECTOR', 'person_id': 331008, 'name': 'Gerard-Jan Claes'},
#    {'role': 'DIRECTOR', 'person_id': 331010, 'name': 'Olivia Rochette'},
#    {'role': 'PRODUCER', 'person_id': 201377, 'name': 'Bart Van Langendonck'}],
#   'external_ids': [{'provider': 'imdb', 'external_id': 'tt2338038'},
#    {'provider': 'tmdb_latest', 'external_id': '201781'},
#    {'provider': 'iva', 'external_id': '82355'},
#    {'provider': 'gowatchit', 'external_id': '267345'},
#    {'provider': 'tms', 'external_id': 'MV007742250000'},
#    {'provider': 'eidr', 'external_id': '10.5240/DBC0-3E06-3AFC-1610-29B2-N'},
#    {'provider': 'rovi', 'external_id': '441900178'},
#    {'provider': 'tmdb', 'external_id': '201781'},
#    {'provider': 'imdb_latest', 'external_id': 'tt2338038'}],
#   'genre_ids': [5, 18],
#   'runtime': 80,
#   'production_countries': ['BE']},
#  {'jw_entity_id': 'tm43389',
#   'id': 43389,
#   'title': 'Rain Man',
#   'full_path': '/es/pelicula/rain-man',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/rain-man'},
#   'poster': '/poster/14863126/{profile}',
#   'poster_blur_hash': 'T6G97~^?WA_7D}x_4,0MIfEnR?Vu',
#   'backdrops': [{'backdrop_url': '/backdrop/188686345/{profile}',
#     'backdrop_blur_hash': 'LXEL:1Mx0LtRD%kDxus.IUj[xuWB'},
#    {'backdrop_url': '/backdrop/8723252/{profile}',
#     'backdrop_blur_hash': 'LYKwkI9t.9xu~ptRozn+cFjFVsIo'},
#    {'backdrop_url': '/backdrop/196889662/{profile}',
#     'backdrop_blur_hash': 'LJFsb_?^0zL}EL9FWC%MtmVsrqkr'},
#    {'backdrop_url': '/backdrop/177780985/{profile}',
#     'backdrop_blur_hash': 'LVJjO|Stj10yoZ9vN4xHbbR*xV%0'},
#    {'backdrop_url': '/backdrop/177780984/{profile}',
#     'backdrop_blur_hash': 'LTH1}JniS~bc01enbwMxS4RjkCof'}],
#   'short_description': 'Charlie Babbitt, un joven sin corazón, espera recibir una considerable herencia tras la muerte de su padre, del que estaba distanciado. Sin embargo, alguien a quien Charlie no ha tenido en absoluto en cuenta, su hermano mayor Raymond, recluido en una institución medica, recibe toda la fortuna del testamento. Raymond es un autista con capacidad mental limitada en algunos aspectos, pero con dotes de genio en otros.',
#   'original_release_year': 1988,
#   'object_type': 'movie',
#   'original_title': 'Rain Man',
#   'offers': [{'jw_entity_id': 'tm43389',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 9.99,
#     'last_change_retail_price': 5.99,
#     'last_change_difference': 4,
#     'last_change_percent': 66.77796,
#     'last_change_date': '2020-12-25',
#     'last_change_date_provider_id': '2020-12-25_2',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/rain-man---el-hombre-de-la-lluvia/umc.cmc.60tlefmlnwzxo1epq9ropxi1w?playableId=tvs.sbd.9001%3A303821283',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Frain-man---el-hombre-de-la-lluvia%2Fumc.cmc.60tlefmlnwzxo1epq9ropxi1w%3FplayableId%3Dtvs.sbd.9001%253A303821283&MediaType=movie'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 9.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/rain-man---el-hombre-de-la-lluvia/umc.cmc.60tlefmlnwzxo1epq9ropxi1w?playableId=tvs.sbd.9001%3A303821283',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Frain-man---el-hombre-de-la-lluvia%2Fumc.cmc.60tlefmlnwzxo1epq9ropxi1w%3FplayableId%3Dtvs.sbd.9001%253A303821283&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 8.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/rain-man---el-hombre-de-la-lluvia/umc.cmc.60tlefmlnwzxo1epq9ropxi1w?playableId=tvs.sbd.9001%3A303821283',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Frain-man---el-hombre-de-la-lluvia%2Fumc.cmc.60tlefmlnwzxo1epq9ropxi1w%3FplayableId%3Dtvs.sbd.9001%253A303821283&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/rain-man---el-hombre-de-la-lluvia/umc.cmc.60tlefmlnwzxo1epq9ropxi1w?playableId=tvs.sbd.9001%3A303821283',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Frain-man---el-hombre-de-la-lluvia%2Fumc.cmc.60tlefmlnwzxo1epq9ropxi1w%3FplayableId%3Dtvs.sbd.9001%253A303821283&MediaType=movie'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/rain-man---el-hombre-de-la-lluvia/umc.cmc.60tlefmlnwzxo1epq9ropxi1w?playableId=tvs.sbd.9001%3A303821283',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Frain-man---el-hombre-de-la-lluvia%2Fumc.cmc.60tlefmlnwzxo1epq9ropxi1w%3FplayableId%3Dtvs.sbd.9001%253A303821283&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/rain-man---el-hombre-de-la-lluvia/umc.cmc.60tlefmlnwzxo1epq9ropxi1w?playableId=tvs.sbd.9001%3A303821283',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Frain-man---el-hombre-de-la-lluvia%2Fumc.cmc.60tlefmlnwzxo1epq9ropxi1w%3FplayableId%3Dtvs.sbd.9001%253A303821283&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 9.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.36b56442-c8ef-7d30-feeb-7386b51b3692',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.36b56442-c8ef-7d30-feeb-7386b51b3692',
#      'deeplink_rokuos': 'launch/13?contentID=B07S2HFGJ1&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 8.99,
#     'last_change_retail_price': 4.99,
#     'last_change_difference': 4,
#     'last_change_percent': 80.160324,
#     'last_change_date': '2022-03-29',
#     'last_change_date_provider_id': '2022-03-29_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.36b56442-c8ef-7d30-feeb-7386b51b3692',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.36b56442-c8ef-7d30-feeb-7386b51b3692',
#      'deeplink_rokuos': 'launch/13?contentID=B07S2HFGJ1&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'rent',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.36b56442-c8ef-7d30-feeb-7386b51b3692',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.36b56442-c8ef-7d30-feeb-7386b51b3692',
#      'deeplink_rokuos': 'launch/13?contentID=B07S2HFGJ1&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'rent',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.36b56442-c8ef-7d30-feeb-7386b51b3692',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.36b56442-c8ef-7d30-feeb-7386b51b3692',
#      'deeplink_rokuos': 'launch/13?contentID=B07S2HFGJ1&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 10.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/rain-man'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 10.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/rain-man'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/rain-man'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/rain-man'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'flatrate',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/rain-man'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'flatrate',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/rain-man'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'buy',
#     'provider_id': 68,
#     'package_short_name': 'msf',
#     'retail_price': 7.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.microsoft.com/es-es/p/rain-man/8d6kgwzl5clx'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'rent',
#     'provider_id': 68,
#     'package_short_name': 'msf',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.microsoft.com/es-es/p/rain-man/8d6kgwzl5clx'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'flatrate',
#     'provider_id': 149,
#     'package_short_name': 'mvs',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'http://ver.movistarplus.es/ficha/rain-man?id=54460'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'flatrate',
#     'provider_id': 588,
#     'package_short_name': 'amg',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.36b56442-c8ef-7d30-feeb-7386b51b3692',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.36b56442-c8ef-7d30-feeb-7386b51b3692',
#      'deeplink_rokuos': 'launch/13?contentID=B07S2HFGJ1&MediaType=movie'},
#     'available_to': '2022-05-31',
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm43389',
#     'monetization_type': 'flatrate',
#     'provider_id': 588,
#     'package_short_name': 'amg',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.36b56442-c8ef-7d30-feeb-7386b51b3692',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.36b56442-c8ef-7d30-feeb-7386b51b3692',
#      'deeplink_rokuos': 'launch/13?contentID=B07S2HFGJ1&MediaType=movie'},
#     'available_to': '2022-05-31',
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'imdb:multiplied', 'value': 4018072},
#    {'provider_type': 'imdb:popularity', 'value': 1047},
#    {'provider_type': 'tmdb:popularity', 'value': 29.97},
#    {'provider_type': 'tmdb:id', 'value': 380},
#    {'provider_type': 'imdb:score', 'value': 8},
#    {'provider_type': 'imdb:votes', 'value': 502259},
#    {'provider_type': 'tmdb:score', 'value': 7.8}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Raymond Babbitt',
#     'person_id': 7737,
#     'name': 'Dustin Hoffman'},
#    {'role': 'ACTOR',
#     'character_name': 'Charlie Babbitt',
#     'person_id': 3535,
#     'name': 'Tom Cruise'},
#    {'role': 'ACTOR',
#     'character_name': 'Susanna',
#     'person_id': 11793,
#     'name': 'Valeria Golino'},
#    {'role': 'ACTOR',
#     'character_name': 'Dr. Bruner',
#     'person_id': 7042,
#     'name': 'Gerald R. Molen'},
#    {'role': 'ACTOR',
#     'character_name': 'John Mooney',
#     'person_id': 117624,
#     'name': 'Jack Murdock'},
#    {'role': 'ACTOR',
#     'character_name': 'Vern',
#     'person_id': 189555,
#     'name': 'Michael D. Roberts'},
#    {'role': 'ACTOR',
#     'character_name': 'Lenny',
#     'person_id': 30260,
#     'name': 'Ralph Seymour'},
#    {'role': 'ACTOR',
#     'character_name': 'Iris',
#     'person_id': 19382,
#     'name': 'Lucinda Jenney'},
#    {'role': 'ACTOR',
#     'character_name': 'Sally Dibbs',
#     'person_id': 1943,
#     'name': 'Bonnie Hunt'},
#    {'role': 'ACTOR',
#     'character_name': 'Township Doctor',
#     'person_id': 56098,
#     'name': 'Kim Robillard'},
#    {'role': 'ACTOR',
#     'character_name': 'Mother at Farm House',
#     'person_id': 5514,
#     'name': 'Beth Grant'},
#    {'role': 'ACTOR',
#     'character_name': 'Farm Kid#1',
#     'person_id': 199508,
#     'name': 'Dolan Dougherty'},
#    {'role': 'ACTOR',
#     'character_name': 'Farm Kid#2',
#     'person_id': 199509,
#     'name': 'Marshall Dougherty'},
#    {'role': 'ACTOR',
#     'character_name': 'Farm Kid#3',
#     'person_id': 199510,
#     'name': 'Patrick Dougherty'},
#    {'role': 'ACTOR',
#     'character_name': 'Farm Kid#5',
#     'person_id': 199511,
#     'name': 'Peter Dougherty'},
#    {'role': 'ACTOR',
#     'character_name': 'Farm Kid#6',
#     'person_id': 487517,
#     'name': 'Andrew Dougherty'},
#    {'role': 'ACTOR',
#     'character_name': 'Secretary Dr. Bruner',
#     'person_id': 487518,
#     'name': 'Loretta Wendt Jolivette'},
#    {'role': 'ACTOR',
#     'character_name': 'Minister at Funeral',
#     'person_id': 487519,
#     'name': 'Donald E. Jones'},
#    {'role': 'ACTOR',
#     'character_name': 'Patient in Waiting Room',
#     'person_id': 487520,
#     'name': 'Bryon P. Caunar'},
#    {'role': 'ACTOR',
#     'character_name': 'Nurse',
#     'person_id': 487521,
#     'name': 'Donna J. Dickson'},
#    {'role': 'ACTOR',
#     'character_name': 'Shift Boss',
#     'person_id': 29000,
#     'name': 'Ralph Tabakin'},
#    {'role': 'ACTOR',
#     'character_name': 'Mr. Kelso',
#     'person_id': 11228,
#     'name': 'Ray Baker'},
#    {'role': 'ACTOR',
#     'character_name': 'Boy at Pancake Counter',
#     'person_id': 4080,
#     'name': 'Jake Hoffman'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 21627,
#     'name': 'Royce D. Applegate'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 190624,
#     'name': 'Anna Mathias'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 31315,
#     'name': 'Archie Hahn'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 84963,
#     'name': 'Luisa Leschin'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 182147,
#     'name': 'Ira Miller'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 2429,
#     'name': 'Chris Mulkey'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 30748,
#     'name': 'Julie Payne'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 24045,
#     'name': 'Reni Santoni'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 182148,
#     'name': 'Ruth Silveira'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 51410,
#     'name': 'Jonathan Stark'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 33705,
#     'name': 'Lynne Marie Stewart'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 182149,
#     'name': 'Arnold F. Turner'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 182150,
#     'name': 'Gigi Vorgan'},
#    {'role': 'ACTOR',
#     'character_name': 'Doctor (uncredited)',
#     'person_id': 10437,
#     'name': 'Barry Levinson'},
#    {'role': 'ACTOR',
#     'character_name': 'Restaurant Patron (uncredited)',
#     'person_id': 4380,
#     'name': 'Mark Winn'},
#    {'role': 'ACTOR',
#     'character_name': '(voice)',
#     'person_id': 76805,
#     'name': 'June Christopher'},
#    {'role': 'ACTOR',
#     'character_name': 'Hotel Customer (uncredited)',
#     'person_id': 1393387,
#     'name': 'Billie Perkins'},
#    {'role': 'ASSISTANT_DIRECTOR',
#     'person_id': 7701,
#     'name': 'Cherylanne Martin'},
#    {'role': 'ASSISTANT_DIRECTOR',
#     'person_id': 20918,
#     'name': 'David McGiffert'},
#    {'role': 'ASSISTANT_DIRECTOR',
#     'person_id': 77223,
#     'name': 'Cara Giallanza'},
#    {'role': 'CO_PRODUCER', 'person_id': 7042, 'name': 'Gerald R. Molen'},
#    {'role': 'DIRECTOR', 'person_id': 10437, 'name': 'Barry Levinson'},
#    {'role': 'EDITOR', 'person_id': 19701, 'name': 'Stu Linder'},
#    {'role': 'EXECUTIVE_PRODUCER', 'person_id': 9074, 'name': 'Jon Peters'},
#    {'role': 'EXECUTIVE_PRODUCER', 'person_id': 20980, 'name': 'Peter Guber'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 1728,
#     'name': 'Hans Zimmer'},
#    {'role': 'PRODUCER', 'person_id': 10305, 'name': 'Mark Johnson'},
#    {'role': 'PRODUCTION_DESIGN', 'person_id': 16667, 'name': 'Ida Random'},
#    {'role': 'SCREENPLAY', 'person_id': 182151, 'name': 'Barry Morrow'},
#    {'role': 'SCREENPLAY', 'person_id': 33383, 'name': 'Ronald Bass'}],
#   'external_ids': [{'provider': 'imdb', 'external_id': 'tt0095953'},
#    {'provider': 'tms', 'external_id': 'MV000261880000'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0095953'},
#    {'provider': 'iva', 'external_id': '1432'},
#    {'provider': 'tmdb_latest', 'external_id': '380'},
#    {'provider': 'tmdb', 'external_id': '380'},
#    {'provider': 'eidr', 'external_id': '10.5240/E2B8-621E-FA1B-BEDF-4F78-H'},
#    {'provider': 'gowatchit', 'external_id': '5029'},
#    {'provider': 'rovi', 'external_id': '1066671'}],
#   'genre_ids': [6],
#   'age_certification': 'APTA',
#   'runtime': 134,
#   'production_countries': ['US'],
#   'permanent_audiences': ['pa:bf7c313c-eec9-47fe-a719-d572580f694d']},
#  {'jw_entity_id': 'tm221534',
#   'id': 221534,
#   'title': 'Lluvia',
#   'full_path': '/es/pelicula/lluvia',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/lluvia'},
#   'poster': '/poster/138556765/{profile}',
#   'poster_blur_hash': 'ThI3]qozS%NJn$nO0Maxng?FozXS',
#   'short_description': 'Determinadas circunstancias, entre las que se encuentran los problemas económicos derivados de la fuerte sequía que asola su granja y la infidelidad de su marido con la esposa del sheriff del lugar, llevan a Ellen a tal punto de desesperación que, una noche, dejándose llevar por la angustia y el abatimiento, acaba asesinando a su marido.',
#   'original_release_year': 2001,
#   'object_type': 'movie',
#   'original_title': 'Rain',
#   'localized_release_date': '2003-04-04T00:00:00Z',
#   'scoring': [{'provider_type': 'tmdb:id', 'value': 354307},
#    {'provider_type': 'tmdb:popularity', 'value': 1.275},
#    {'provider_type': 'tmdb:score', 'value': 3},
#    {'provider_type': 'imdb:multiplied', 'value': 1844.3999999999999},
#    {'provider_type': 'imdb:score', 'value': 5.3},
#    {'provider_type': 'imdb:votes', 'value': 348}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Ellen Biddle',
#     'person_id': 11006,
#     'name': 'Melora Walters'},
#    {'role': 'ACTOR',
#     'character_name': 'Richard Gibson',
#     'person_id': 75805,
#     'name': 'Kris Park'},
#    {'role': 'ACTOR',
#     'character_name': 'Sheriff Tom Gibson',
#     'person_id': 3359,
#     'name': 'Jamey Sheridan'},
#    {'role': 'ACTOR',
#     'character_name': 'Audrey Turnquick',
#     'person_id': 12804,
#     'name': 'Diane Ladd'},
#    {'role': 'ACTOR',
#     'character_name': 'Officer Ben Patterson',
#     'person_id': 2940,
#     'name': 'Ezra Buzzington'}],
#   'external_ids': [{'provider': 'tmdb_latest', 'external_id': '354307'},
#    {'provider': 'rovi', 'external_id': '4172094'},
#    {'provider': 'tmdb', 'external_id': '354307'},
#    {'provider': 'gowatchit', 'external_id': '83154'},
#    {'provider': 'tms', 'external_id': 'MV001486030000'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0276437'},
#    {'provider': 'imdb', 'external_id': 'tt0276437'},
#    {'provider': 'eidr', 'external_id': '10.5240/F3CA-3E4E-036A-377A-2B17-9'}],
#   'genre_ids': [18, 13, 6, 1],
#   'runtime': 97,
#   'production_countries': ['DE']},
#  {'jw_entity_id': 'tm61543',
#   'id': 61543,
#   'title': 'Barsaat',
#   'full_path': '/es/pelicula/brsaat',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/brsaat'},
#   'poster': '/poster/261091407/{profile}',
#   'poster_blur_hash': 'TRMqYLkq{#zBiwbc-qbcK0+br?S#',
#   'short_description': 'The moody, music-filled romance Barsaat was Raj Kapoor’s first megahit and first film with composers Shankar-Jaikishan, the hit-writing duo who would hereafter score Kapoor’s films. Barsaat shuttles between the stories of romantic idealist Pran (Kapoor) and his more carnally-driven best friend Gopal (Prem Nath), who both meet and romance the daughters of innkeepers. Gopal loves and leaves Neela (future star Nimmi, in her debut), vowing to return when the monsoon comes, while Pran woos Reshma (Nargis, Kapoor’s main leading lady) with music until her father ends it, claiming all city boys are degenerates. In an attempt to see Pran once more, Reshma falls into a river and is presumed dead… (Encyclopaedia of Indian Cinema). —Pacific Cinémathèque',
#   'original_release_year': 1949,
#   'object_type': 'movie',
#   'original_title': 'बरसात',
#   'offers': [{'jw_entity_id': 'tm61543',
#     'monetization_type': 'flatrate',
#     'provider_id': 11,
#     'package_short_name': 'mbi',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://mubi.com/films/monsoon-1949'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'tmdb:popularity', 'value': 1.583},
#    {'provider_type': 'tmdb:id', 'value': 198755},
#    {'provider_type': 'imdb:score', 'value': 7.3},
#    {'provider_type': 'imdb:votes', 'value': 643},
#    {'provider_type': 'tmdb:score', 'value': 7.5},
#    {'provider_type': 'imdb:multiplied', 'value': 4693.9}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Pran',
#     'person_id': 67139,
#     'name': 'Raj Kapoor'},
#    {'role': 'ACTOR',
#     'character_name': 'Reshma',
#     'person_id': 64406,
#     'name': 'Nargis'},
#    {'role': 'ACTOR',
#     'character_name': 'Gopal',
#     'person_id': 173253,
#     'name': 'Prem Nath'},
#    {'role': 'ACTOR',
#     'character_name': 'Bholu',
#     'person_id': 434348,
#     'name': 'K.N. Singh'},
#    {'role': 'ACTOR',
#     'character_name': 'Neela',
#     'person_id': 562969,
#     'name': 'Nimmi'},
#    {'role': 'ACTOR',
#     'character_name': 'Ruby',
#     'person_id': 563873,
#     'name': 'Cuckoo'},
#    {'role': 'ACTOR', 'person_id': 474962, 'name': 'B.M. Vyas'},
#    {'role': 'ACTOR', 'person_id': 543030, 'name': 'Ratan Gaurang'},
#    {'role': 'ACTOR', 'person_id': 515743, 'name': 'Vishwa Mehra'},
#    {'role': 'DIRECTOR', 'person_id': 67139, 'name': 'Raj Kapoor'},
#    {'role': 'EDITOR', 'person_id': 559984, 'name': 'G G Mayekar'},
#    {'role': 'MUSIC', 'person_id': 1782367, 'name': 'Shankarsingh Raghuwanshi'},
#    {'role': 'MUSIC',
#     'person_id': 565763,
#     'name': 'Jaikishan Dayabhai Panchal'},
#    {'role': 'PRODUCER', 'person_id': 67139, 'name': 'Raj Kapoor'},
#    {'role': 'SCREENPLAY', 'person_id': 534142, 'name': 'Ramanand Sagar'}],
#   'external_ids': [{'provider': 'rovi', 'external_id': '6652'},
#    {'provider': 'imdb', 'external_id': 'tt0041161'},
#    {'provider': 'tmdb', 'external_id': '198755'},
#    {'provider': 'gowatchit', 'external_id': '107410'},
#    {'provider': 'tms', 'external_id': 'MV007877330000'},
#    {'provider': 'tmdb_latest', 'external_id': '198755'},
#    {'provider': 'eidr', 'external_id': '10.5240/B6A2-ECAF-4CD6-3063-E8F8-P'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0041161'}],
#   'genre_ids': [6, 13],
#   'runtime': 171,
#   'production_countries': ['IN']},
#  {'jw_entity_id': 'tm49812',
#   'id': 49812,
#   'title': 'Baran (Lluvia)',
#   'full_path': '/es/pelicula/baran',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/baran'},
#   'poster': '/poster/11241812/{profile}',
#   'poster_blur_hash': 'TUE_{yysg$buR-S4EL$%-oxGbHf6',
#   'backdrops': [{'backdrop_url': '/backdrop/11241817/{profile}',
#     'backdrop_blur_hash': 'LDFi0=S1?wDitRt7jYRkIqjFV?S#'}],
#   'short_description': 'Baran es la historia de refugiados afganos contada a través de los ojos de Lateef (Hossein Abedini), un iraní adolescente. Mientras él y otros iranís pelean para llevar acabo un encuentro, los refugiados afganos pueden apenas sobrevivir, ya que ellos no pueden trabajar legalmente. Lateef, con un gran corazón pero un pícaro, trabaja como portero en una construcción, proporcionando té y comida a los trabajadores afganos que trabajan ilegalmente por un salario escaso. El jefe, un hombre amable pero frugal llamado Memar (Mohammad Amir Naji), le paga a Lateef una pequeña parte de sueldo semanal, y retiene el resto de su sueldo alegando que es por su propio bien. Cuando un trabajador afgano, Najaf, sufre una caída en la construcción, no puede decir a las autoridades dónde o cómo se ha herido, debido a su estado de trabajador ilegal. Este incidente amenaza los puestos de trabajo de todo el mundo.',
#   'original_release_year': 2001,
#   'object_type': 'movie',
#   'original_title': 'باران',
#   'scoring': [{'provider_type': 'tmdb:id', 'value': 43774},
#    {'provider_type': 'tmdb:popularity', 'value': 5.207},
#    {'provider_type': 'tmdb:score', 'value': 7.4},
#    {'provider_type': 'imdb:multiplied', 'value': 65808.59999999999},
#    {'provider_type': 'imdb:score', 'value': 7.8},
#    {'provider_type': 'imdb:votes', 'value': 8437}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Lateef',
#     'person_id': 438843,
#     'name': 'Hossein Abedini'},
#    {'role': 'ACTOR',
#     'character_name': 'Baran',
#     'person_id': 438842,
#     'name': 'Zahra Bahrami'},
#    {'role': 'ACTOR',
#     'character_name': 'Memar',
#     'person_id': 54287,
#     'name': 'Reza Naji'},
#    {'role': 'ACTOR',
#     'character_name': 'Soltan',
#     'person_id': 429346,
#     'name': 'Hossein Mahjoub'},
#    {'role': 'ACTOR',
#     'character_name': 'Soltan',
#     'person_id': 132624,
#     'name': 'Abbas Rahimi'},
#    {'role': 'ACTOR',
#     'character_name': 'Najaf',
#     'person_id': 132625,
#     'name': 'Gholam Ali Bakhshi'},
#    {'role': 'ACTOR',
#     'character_name': 'Inspector',
#     'person_id': 132626,
#     'name': 'Jafar Tawakoli'},
#    {'role': 'ACTOR',
#     'character_name': "Lors workers' chief",
#     'person_id': 132627,
#     'name': 'Yadollah Hedayati'},
#    {'role': 'ACTOR',
#     'character_name': 'Shop owner',
#     'person_id': 132628,
#     'name': 'Parviz Larijani'},
#    {'role': 'ACTOR',
#     'character_name': 'Building Contractor',
#     'person_id': 132629,
#     'name': 'Mahmoud Behraznia'},
#    {'role': 'ACTOR',
#     'character_name': 'Inspector',
#     'person_id': 132630,
#     'name': 'Pasha Barabadi'},
#    {'role': 'ACTOR',
#     'character_name': 'Inspector',
#     'person_id': 132631,
#     'name': 'Kamai Parto'},
#    {'role': 'ACTOR',
#     'character_name': "Turkish workers' chief",
#     'person_id': 132632,
#     'name': 'Maghsood Moghadan'},
#    {'role': 'ACTOR',
#     'character_name': 'Hassan',
#     'person_id': 78662,
#     'name': 'Christopher Maleki'},
#    {'role': 'ASSISTANT_DIRECTOR',
#     'person_id': 132636,
#     'name': 'Sirrus Hassanpur'},
#    {'role': 'ASSISTANT_DIRECTOR', 'person_id': 132637, 'name': 'Behzad Rafi'},
#    {'role': 'DIRECTOR', 'person_id': 54290, 'name': 'Majid Majidi'},
#    {'role': 'EDITOR', 'person_id': 1870845, 'name': 'Hassan Hassandoust'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 132633,
#     'name': 'Ahmad Pezhman'},
#    {'role': 'PRODUCER', 'person_id': 54290, 'name': 'Majid Majidi'},
#    {'role': 'PRODUCER', 'person_id': 132634, 'name': 'Fouad Nahas'},
#    {'role': 'SCREENPLAY', 'person_id': 132634, 'name': 'Fouad Nahas'},
#    {'role': 'WRITER', 'person_id': 54290, 'name': 'Majid Majidi'}],
#   'external_ids': [{'provider': 'tms', 'external_id': 'MV001157320000'},
#    {'provider': 'tmdb', 'external_id': '43774'},
#    {'provider': 'gowatchit', 'external_id': '36301'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0233841'},
#    {'provider': 'tmdb_latest', 'external_id': '43774'},
#    {'provider': 'imdb', 'external_id': 'tt0233841'},
#    {'provider': 'eidr', 'external_id': '10.5240/1040-C5A1-BE52-118A-563C-L'},
#    {'provider': 'rovi', 'external_id': '1482914'},
#    {'provider': 'iva', 'external_id': '47277'}],
#   'genre_ids': [6, 13],
#   'runtime': 90,
#   'production_countries': ['IR'],
#   'permanent_audiences': ['pa:b879dad8-8dd3-4518-a89e-243ddda6f514']},
#  {'jw_entity_id': 'tm36538',
#   'id': 36538,
#   'title': 'Rain',
#   'full_path': '/es/pelicula/rain-2001',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/rain-2001'},
#   'poster': '/poster/8811061/{profile}',
#   'poster_blur_hash': 'TrH.7,$yj]I9-oofI9xtoe~qV@af',
#   'backdrops': [{'backdrop_url': '/backdrop/8811062/{profile}',
#     'backdrop_blur_hash': 'LDD9I-_NEN57?FI;xu-:EhJC?b_3'},
#    {'backdrop_url': '/backdrop/1944677/{profile}',
#     'backdrop_blur_hash': 'LDD9I-_NEN57?FI;xu-:EhJC?b_3'}],
#   'short_description': "Janey is on vacation with her brother, Jim, mother, Kate, and father Ed, at their beach house on the Mahurangi Peninsual in New Zealand. Ed and Kate, who are on the verge of divorce, sit around in the back yard all day drinking whiskey and Janey and Jim are left to their own devices. Cady, a local boaty who is having an affair with Kate, catches Janey's pubescent eye. In response to his wife's drinking problem and recurring infidelity, Ed turns to alcohol, ignoring his children almost as much as his wife, which eventually leads to a character's fate.",
#   'original_release_year': 2001,
# ...
#     'name': 'Jun Kunimura'},
#    {'role': 'ACTOR',
#     'character_name': 'Dawn',
#     'person_id': 98332,
#     'name': 'Angeles Woo'},
#    {'role': 'ACTOR',
#     'character_name': 'Hideo Sakaguchi',
#     'person_id': 35171,
#     'name': 'Yasuaki Kurata'},
#    {'role': 'ACTOR',
#     'character_name': 'Mamoru Ito',
#     'person_id': 43841,
#     'name': 'Naoto Takenaka'},
#    {'role': 'ACTOR',
#     'character_name': 'Hiroshi Sakai',
#     'person_id': 79161,
#     'name': 'Hiroyuki Ikeuchi'},
#    {'role': 'ACTOR',
#     'character_name': 'Kiko Tanaka',
#     'person_id': 29711,
#     'name': 'Tao Okamoto'},
#    {'role': 'ACTOR',
#     'character_name': 'Rika Hyakuta',
#     'person_id': 31701,
#     'name': 'Nanami Sakuraba'},
#    {'role': 'ACTOR', 'person_id': 2230223, 'name': 'Hiroshi Urano'},
#    {'role': 'ACTOR', 'person_id': 96970, 'name': 'Takumi Saitoh'},
#    {'role': 'DIRECTOR', 'person_id': 8673, 'name': 'John Woo'},
#    {'role': 'EDITOR', 'person_id': 71193, 'name': 'Wong Hoi'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 33421,
#     'name': 'Taro Iwashiro'},
#    {'role': 'PRODUCER', 'person_id': 40398, 'name': 'Gordon Chan'},
#    {'role': 'PRODUCER', 'person_id': 46731, 'name': 'Hing-Ka Chan'},
#    {'role': 'PRODUCTION_DESIGN', 'person_id': 2271, 'name': 'Yohei Taneda'},
#    {'role': 'WRITER', 'person_id': 8673, 'name': 'John Woo'},
#    {'role': 'WRITER', 'person_id': 483519, 'name': 'Lip Wang-Fung'},
#    {'role': 'WRITER', 'person_id': 40398, 'name': 'Gordon Chan'},
#    {'role': 'WRITER', 'person_id': 35038, 'name': 'James Yuen'}],
#   'external_ids': [{'provider': 'tmdb', 'external_id': '372782'},
#    {'provider': 'tmdb_latest', 'external_id': '372782'},
#    {'provider': 'tms', 'external_id': 'MV011006850000'},
#    {'provider': 'imdb_latest', 'external_id': 'tt8630396'},
#    {'provider': 'eidr', 'external_id': '10.5240/F5A6-031F-78C4-ADA0-5AEB-E'},
#    {'provider': 'imdb', 'external_id': 'tt4537986'},
#    {'provider': 'imdb', 'external_id': 'tt8630396'},
#    {'provider': 'imdb', 'external_id': 'tt4539410'},
#    {'provider': 'iva', 'external_id': '694143'},
#    {'provider': 'gowatchit', 'external_id': '622448'}],
#   'genre_ids': [12, 1, 4],
#   'runtime': 106,
#   'production_countries': ['CN', 'HK'],
#   'permanent_audiences': ['pa:b71b706d-6c43-4573-8d96-370463aaca8f']},
#  {'jw_entity_id': 'tm138802',
#   'id': 138802,
#   'title': 'La reina del desierto',
#   'full_path': '/es/pelicula/la-reina-del-desierto',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/la-reina-del-desierto'},
#   'poster': '/poster/148035007/{profile}',
#   'poster_blur_hash': 'TKLgU#C9I;7i01RPkW#PR5IpaKM{',
#   'backdrops': [{'backdrop_url': '/backdrop/722500/{profile}',
#     'backdrop_blur_hash': 'LFB3vhkCRjof.TfPaej]o#WAWBae'},
#    {'backdrop_url': '/backdrop/722504/{profile}',
#     'backdrop_blur_hash': 'LCCsHo?bS1og8^IARjjYk?%gt7WC'},
#    {'backdrop_url': '/backdrop/722503/{profile}',
#     'backdrop_blur_hash': 'L8E.%]01WE^+Xos.s.%L?baxRkD*'}],
#   'short_description': 'Queen of the Desert es un ‘biopic’ que cuenta la historia de Gertrude Bell: la escritora, arqueóloga y cartógrafa considerada la versión femenina de Lawrence de Arabia. En el siglo XX se convirtió en toda una experta sobre el mundo árabe y, gracias a ello, aportó sus servicios al Imperio Británico ayudando a expandir sus dominios en dicho territorio.',
#   'original_release_year': 2015,
#   'object_type': 'movie',
#   'original_title': 'Queen of the Desert',
#   'offers': [{'jw_entity_id': 'tm138802',
#     'monetization_type': 'flatrate',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/la-reina-del-desierto'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm138802',
#     'monetization_type': 'flatrate',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/la-reina-del-desierto'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm138802',
#     'monetization_type': 'rent',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'retail_price': 3.95,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/la-reina-del-desierto'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm138802',
#     'monetization_type': 'rent',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'retail_price': 3.95,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/la-reina-del-desierto'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'imdb:popularity', 'value': 4490},
#    {'provider_type': 'tmdb:popularity', 'value': 10.08},
#    {'provider_type': 'tmdb:id', 'value': 157843},
#    {'provider_type': 'imdb:score', 'value': 5.7},
#    {'provider_type': 'imdb:votes', 'value': 11328},
#    {'provider_type': 'tmdb:score', 'value': 5.9},
#    {'provider_type': 'imdb:multiplied', 'value': 64569.6}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Gertrude Bell',
#     'person_id': 8956,
#     'name': 'Nicole Kidman'},
#    {'role': 'ACTOR',
#     'character_name': 'Henry Cadogan',
#     'person_id': 6206,
#     'name': 'James Franco'},
#    {'role': 'ACTOR',
#     'character_name': 'Richard Wylie',
#     'person_id': 24613,
#     'name': 'Damian Lewis'},
#    {'role': 'ACTOR',
#     'character_name': 'Fattuh',
#     'person_id': 25122,
#     'name': 'Jay Abdo'},
#    {'role': 'ACTOR',
#     'character_name': 'T.E. Lawrence',
#     'person_id': 1181,
#     'name': 'Robert Pattinson'},
#    {'role': 'ACTOR',
#     'character_name': 'Florance Bell',
#     'person_id': 25118,
#     'name': 'Jenny Agutter'},
#    {'role': 'ACTOR',
#     'character_name': 'Hugh Bell',
#     'person_id': 233,
#     'name': 'David Calder'},
#    {'role': 'ACTOR',
#     'character_name': 'Winston Churchill',
#     'person_id': 8153,
#     'name': 'Christopher Fulford'},
#    {'role': 'ACTOR',
#     'character_name': 'Sir Mark Sykes',
#     'person_id': 1232684,
#     'name': 'Nick Waring'},
#    {'role': 'ACTOR',
#     'character_name': 'Florence Lascelles',
#     'person_id': 25116,
#     'name': 'Holly Earl'},
#    {'role': 'ACTOR',
#     'character_name': 'Judith',
#     'person_id': 25121,
#     'name': 'Sophie Linfield'},
#    {'role': 'ACTOR',
#     'character_name': 'Lascelles',
#     'person_id': 595035,
#     'name': 'Mark Lewis Jones'},
#    {'role': 'ACTOR',
#     'character_name': 'Aunt Lascelles',
#     'person_id': 25124,
#     'name': 'Beth Goddard'},
#    {'role': 'ACTOR',
#     'character_name': 'Thompson',
#     'person_id': 25126,
#     'name': 'Michael Jenn'},
#    {'role': 'ACTOR',
#     'character_name': 'Earl of Chester',
#     'person_id': 670633,
#     'name': 'William Ellis'},
#    {'role': 'ACTOR',
#     'character_name': 'Arnold Runcie',
#     'person_id': 73970,
#     'name': 'John Wark'},
#    {'role': 'ACTOR',
#     'character_name': 'Havenhurst',
#     'person_id': 774916,
#     'name': 'Richard Goulding'},
#    {'role': 'ACTOR',
#     'character_name': 'Hairdresser',
#     'person_id': 101610,
#     'name': 'Charlie Hollway'},
#    {'role': 'ACTOR',
#     'character_name': 'Abdullah',
#     'person_id': 774984,
#     'name': 'Younes Benzakour'},
#    {'role': 'ACTOR',
#     'character_name': 'Omar',
#     'person_id': 1304090,
#     'name': 'Hamza El Moustaati'},
#    {'role': 'ACTOR',
#     'character_name': 'Dispatcher',
#     'person_id': 1303541,
#     'name': 'Abdellah Bensaidi'},
#    {'role': 'ACTOR',
#     'character_name': 'Lieutenant',
#     'person_id': 83476,
#     'name': 'Abdellatif Chaouqi'},
#    {'role': 'ACTOR',
#     'character_name': 'Secretary',
#     'person_id': 774923,
#     'name': 'Megan Sullivan'},
#    {'role': 'ACTOR',
#     'character_name': 'Druze Sheikh',
#     'person_id': 83464,
#     'name': 'Mohamed Boussalem'},
#    {'role': 'ACTOR',
#     'character_name': 'Warrior',
#     'person_id': 1303971,
#     'name': 'Mehdi Quazzani'},
#    {'role': 'ACTOR',
#     'character_name': 'Druze Warrior',
#     'person_id': 342358,
#     'name': 'Mostafa El Houari'},
#    {'role': 'ACTOR',
#     'character_name': 'Fortune Teller',
#     'person_id': 83474,
#     'name': 'Hamid Najah'},
#    {'role': 'ACTOR',
#     'character_name': 'Old Man',
#     'person_id': 1304226,
#     'name': 'Mohamed Ziat'},
#    {'role': 'ACTOR',
#     'character_name': 'Horseman',
#     'person_id': 258408,
#     'name': 'Anas El Baz'},
#    {'role': 'ACTOR',
#     'character_name': 'Dignitary',
#     'person_id': 775031,
#     'name': 'Qualid Mezouar'},
#    {'role': 'ACTOR',
#     'character_name': 'Minister',
#     'person_id': 1304244,
#     'name': 'Hicham Haijji'},
#    {'role': 'ACTOR',
#     'character_name': 'Sheikh Harb',
#     'person_id': 774997,
#     'name': 'Abderrahmane Baalla'},
#    {'role': 'ACTOR',
#     'character_name': 'Shop Owner',
#     'person_id': 104615,
#     'name': 'Nick N. Raslan'},
#    {'role': 'ACTOR',
#     'character_name': 'Hamad',
#     'person_id': 774993,
#     'name': 'Salah Azadou'},
#    {'role': 'ACTOR',
#     'character_name': 'Hayil Gate Keeper',
#     'person_id': 334903,
#     'name': 'Ismael Kanater'},
#    {'role': 'ACTOR',
#     'character_name': 'Ibrahim',
#     'person_id': 6000,
#     'name': 'Fehd Benchemsi'},
#    {'role': 'ACTOR',
#     'character_name': 'Fatima',
#     'person_id': 200682,
#     'name': 'Nadia Niazi'},
#    {'role': 'ACTOR',
#     'character_name': 'Turkkiyeh',
#     'person_id': 774925,
#     'name': 'Fatima ezzahra El Jaouhari'},
#    {'role': 'ACTOR',
#     'character_name': 'Emir',
#     'person_id': 1304235,
#     'name': 'Anas Cherifi'},
#    {'role': 'ACTOR',
#     'character_name': 'General',
#     'person_id': 136290,
#     'name': 'Colin Goodwin'},
#    {'role': 'ACTOR',
#     'character_name': 'King Faisal',
#     'person_id': 195038,
#     'name': 'Younes Bouab'},
#    {'role': 'ACTOR',
#     'character_name': 'Sheikh',
#     'person_id': 25120,
#     'name': 'Assaad Bouab'},
#    {'role': 'ACTOR',
#     'character_name': 'Lady Ascot (uncredited)',
#     'person_id': 25125,
#     'name': 'Sarah Crowden'},
#    {'role': 'ACTOR',
#     'character_name': 'Farsi voice actor (uncredited)',
#     'person_id': 25117,
#     'name': 'Renee Faia'},
#    {'role': 'ACTOR',
#     'character_name': 'Farsi voice actor (uncredited)',
#     'person_id': 74843,
#     'name': 'Mustafa Haidari'},
#    {'role': 'ACTOR',
#     'character_name': 'Handmaiden (uncredited)',
#     'person_id': 25123,
#     'name': 'Christina Low'},
#    {'role': 'ASSISTANT_DIRECTOR',
#     'person_id': 695095,
#     'name': 'Lorenzo Bertolazzi'},
#    {'role': 'DIRECTOR', 'person_id': 13240, 'name': 'Werner Herzog'},
#    {'role': 'EDITOR', 'person_id': 92144, 'name': 'Joe Bini'},
#    {'role': 'EXECUTIVE_PRODUCER', 'person_id': 59852, 'name': 'James Lejsek'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 477314,
#     'name': 'Cathy Gesualdo'},
#    {'role': 'EXECUTIVE_PRODUCER', 'person_id': 59857, 'name': 'Ben Sachs'},
#    {'role': 'EXECUTIVE_PRODUCER', 'person_id': 27595, 'name': 'Stephen Hays'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 386254,
#     'name': 'Jonathan Debin'},
#    {'role': 'EXECUTIVE_PRODUCER', 'person_id': 27597, 'name': 'Peter Graham'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 774959,
#     'name': 'D. Todd Shepherd'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 774956,
#     'name': 'Shelley Madison'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 3446,
#     'name': 'Klaus Badelt'},
#    {'role': 'PRODUCER', 'person_id': 104615, 'name': 'Nick N. Raslan'},
#    {'role': 'PRODUCER', 'person_id': 3052, 'name': 'Cassian Elwes'},
#    {'role': 'PRODUCER', 'person_id': 32083, 'name': 'Michael Benaroya'},
#    {'role': 'PRODUCTION_DESIGN',
#     'person_id': 468682,
#     'name': 'Ulrich Bergfelder'},
#    {'role': 'WRITER', 'person_id': 13240, 'name': 'Werner Herzog'}],
#   'external_ids': [{'provider': 'imdb_latest', 'external_id': 'tt1837636'},
#    {'provider': 'tmdb', 'external_id': '157843'},
#    {'provider': 'gowatchit', 'external_id': '268037'},
#    {'provider': 'tmdb_latest', 'external_id': '157843'},
#    {'provider': 'imdb', 'external_id': 'tt1837636'},
#    {'provider': 'iva', 'external_id': '241482'},
#    {'provider': 'eidr', 'external_id': '10.5240/69AD-7036-4D67-8D90-D0F0-5'},
#    {'provider': 'rovi', 'external_id': '1653215441'},
#    {'provider': 'tms', 'external_id': 'MV007801320000'}],
#   'genre_ids': [6, 8, 13],
#   'age_certification': '12',
#   'runtime': 128,
#   'production_countries': ['MA', 'US'],
#   'permanent_audiences': ['pa:79245f22-9849-4566-b304-a021a7da5a4f',
#    'pa:922025bb-68fe-4c20-ac75-ece0977279ff']},
#  {'jw_entity_id': 'tm193388',
#   'id': 193388,
#   'title': 'Dhanak',
#   'full_path': '/es/pelicula/dhanak',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/dhanak'},
#   'poster': '/poster/142203637/{profile}',
#   'poster_blur_hash': 'TcK1q6%MRl1TRja$9gNFafMdt7X9',
#   'backdrops': [{'backdrop_url': '/backdrop/445480/{profile}',
#     'backdrop_blur_hash': 'LZNJwFt3?FD*%$M|NIxa_4ofjtjZ'}],
#   'short_description': "Orphaned siblings Pari and Chotu embark on a journey to restore Chotu's eyesight.",
#   'original_release_year': 2015,
#   'object_type': 'movie',
#   'original_title': 'धनक',
#   'offers': [{'jw_entity_id': 'tm193388',
#     'monetization_type': 'flatrate',
#     'provider_id': 11,
#     'package_short_name': 'mbi',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://mubi.com/films/rainbow-2015'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm193388',
#     'monetization_type': 'flatrate',
#     'provider_id': 11,
#     'package_short_name': 'mbi',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://mubi.com/films/rainbow-2015'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'tmdb:score', 'value': 7.5},
#    {'provider_type': 'imdb:multiplied', 'value': 30754.7},
#    {'provider_type': 'tmdb:popularity', 'value': 2.514},
#    {'provider_type': 'tmdb:id', 'value': 320873},
#    {'provider_type': 'imdb:score', 'value': 7.9},
#    {'provider_type': 'imdb:votes', 'value': 3893}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Chotu',
#     'person_id': 255063,
#     'name': 'Krrish Chhabria'},
#    {'role': 'ACTOR',
#     'character_name': 'Pari',
#     'person_id': 1261355,
#     'name': 'Hetal Gada'},
#    {'role': 'ACTOR',
#     'character_name': 'Dungaram (uncle)',
#     'person_id': 69506,
#     'name': 'Vipin Sharma'},
#    {'role': 'ACTOR',
#     'character_name': 'Gowri (aunt)',
#     'person_id': 1261352,
#     'name': 'Gulfam Khan'},
#    {'role': 'ACTOR', 'person_id': 255062, 'name': 'Swastik Ram Chavan'},
#    {'role': 'ACTOR', 'person_id': 180340, 'name': 'Daniel Vincent Gordh'},
#    {'role': 'ACTOR', 'person_id': 255066, 'name': 'Rishi Deshpande'},
#    {'role': 'ACTOR', 'person_id': 251480, 'name': 'Vijay Maurya'},
#    {'role': 'ACTOR', 'person_id': 255064, 'name': 'Vibha Chhibber'},
#    {'role': 'ACTOR', 'person_id': 255065, 'name': 'Ramakant Dayma'},
#    {'role': 'ACTOR', 'person_id': 255067, 'name': 'Chet Dixon'},
#    {'role': 'ACTOR', 'person_id': 163711, 'name': 'Flora Saini'},
#    {'role': 'ACTOR', 'person_id': 67045, 'name': 'Suresh Menon'},
#    {'role': 'DIRECTOR', 'person_id': 69224, 'name': 'Nagesh Kukunoor'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 255070,
#     'name': 'Tapas Relia'},
#    {'role': 'PRODUCER', 'person_id': 69224, 'name': 'Nagesh Kukunoor'},
#    {'role': 'PRODUCER', 'person_id': 139144, 'name': 'Manish Mundra'},
#    {'role': 'PRODUCER', 'person_id': 69225, 'name': 'Elahe Hiptoola'},
#    {'role': 'SCREENPLAY', 'person_id': 69224, 'name': 'Nagesh Kukunoor'}],
#   'external_ids': [{'provider': 'imdb', 'external_id': 'tt4088588'},
#    {'provider': 'imdb', 'external_id': 'tt4088770'},
#    {'provider': 'eidr', 'external_id': '10.5240/E553-8D4B-B51F-AB06-E17E-P'},
#    {'provider': 'tms', 'external_id': 'MV007441770000'},
#    {'provider': 'tmdb_latest', 'external_id': '320873'},
#    {'provider': 'tmdb', 'external_id': '320873'},
#    {'provider': 'gowatchit', 'external_id': '454856'},
#    {'provider': 'imdb_latest', 'external_id': 'tt4088770'}],
#   'genre_ids': [6, 3],
#   'runtime': 106,
#   'production_countries': ['IN'],
#   'permanent_audiences': ['pa:77429883-d2d9-4be6-8746-fd36d7d449c1']}]

# %%
len(extra_info)
# Out:
# 30

# %%
# Generar dataframes con el listado de peliculas asociadas a lo que el usuario introduzca en peli_key 
# con todas las columnas que consideres relevantes y el total serán las pelis que te salgan del primer request (e.g.: 22)

# %%
table = pd.json_normalize(extra_info)
table
# Out:
#    jw_entity_id      id                              title  \
# 0      tm108123  108123           El pasajero de la lluvia
# 1       tm51622   51622                  Muerte en Bangkok
# 2        tm6677    6677                     Bajo la lluvia
# 3       tm68670   68670                               Rain
# 4       tm43389   43389                           Rain Man
# 5      tm221534  221534                             Lluvia
# 6       tm61543   61543                            Barsaat
# 7       tm49812   49812                     Baran (Lluvia)
# 8       tm36538   36538                               Rain
# 9      tm211285  211285                            Barkhaa
# 10     tm112770  112770          Golpe en la pequeña China
# 11      tm31389   31389                        Speed Racer
# 12     tm148335  148335                     Ninja Assassin
# 13     tm122601  122601                  Maridos y Mujeres
# 14     tm192727  192727        Mortal Kombat: Aniquilación
# 15     tm192362  192362  Legítima defensa, de John Grisham
# 16     tm471779  471779                  Miedo a la lluvia
# 17      tm32384   32384                      Soy un cyborg
# 18     tm239761  239761                  La reina de Katwe
# 19     tm375780  375780             La cocina del infierno
# 20       tm1390    1390             Ha nacido una estrella
# 21     tm499045  499045         Ocupación: Proyecto Lluvia
# 22     tm178089  178089                             Reinas
# 23     tm410590  410590                 Reina de corazones
# 24     tm170082  170082                Prince: Purple Rain
# 25     tm156806  156806                     Reina y patria
# 26     tm137046  137046        La reina Cristina de Suecia
# 27     tm311319  311319                            Manhunt
# 28     tm138802  138802              La reina del desierto
# 29     tm193388  193388                             Dhanak
#
#                                    full_path                       poster  \
# 0      /es/pelicula/el-pasajero-de-la-lluvia  /poster/137559485/{profile}
# 1             /es/pelicula/muerte-en-bangkok  /poster/191726124/{profile}
# 2                          /es/pelicula/rain  /poster/111773626/{profile}
# 3                     /es/pelicula/rain-2012  /poster/139151921/{profile}
# 4                      /es/pelicula/rain-man   /poster/14863126/{profile}
# 5                        /es/pelicula/lluvia  /poster/138556765/{profile}
# 6                        /es/pelicula/brsaat  /poster/261091407/{profile}
# 7                         /es/pelicula/baran   /poster/11241812/{profile}
# 8                     /es/pelicula/rain-2001    /poster/8811061/{profile}
# 9                       /es/pelicula/barkhaa   /poster/85615527/{profile}
# 10    /es/pelicula/golpe-en-la-pequena-china  /poster/248403362/{profile}
# 11                  /es/pelicula/speed-racer  /poster/250435255/{profile}
# 12               /es/pelicula/ninja-assassin  /poster/247509444/{profile}
# 13           /es/pelicula/husbands-and-wives  /poster/150179154/{profile}
# 14   /es/pelicula/mortal-kombat-aniquilacion  /poster/222301490/{profile}
# 15                /es/pelicula/the-rainmaker  /poster/131360806/{profile}
# 16            /es/pelicula/miedo-a-la-lluvia  /poster/241018036/{profile}
# 17                /es/pelicula/soy-un-cyborg   /poster/11001332/{profile}
# 18               /es/pelicula/queen-of-katwe  /poster/200315569/{profile}
# 19             /es/pelicula/the-kitchen-2019  /poster/230014180/{profile}
# 20  /es/pelicula/ha-nacido-una-estrella-1976  /poster/218102364/{profile}
# 21          /es/pelicula/occupation-rainfall  /poster/254323778/{profile}
# 22                       /es/pelicula/reinas  /poster/243440658/{profile}
# 23           /es/pelicula/reina-de-corazones  /poster/171458873/{profile}
# 24                  /es/pelicula/purple-rain  /poster/176377272/{profile}
# 25               /es/pelicula/reina-y-patria  /poster/249368696/{profile}
# 26  /es/pelicula/la-reina-cristina-de-suecia   /poster/50658774/{profile}
# 27                      /es/pelicula/manhunt   /poster/72330284/{profile}
# 28        /es/pelicula/la-reina-del-desierto  /poster/148035007/{profile}
# 29                       /es/pelicula/dhanak  /poster/142203637/{profile}
#
#                 poster_blur_hash  \
# 0   TLG*p7^$0g4T9aJ:pJ$%%0OFniX9
# 1   TcFPHSQ,xv?]IB%2ITD,t5R7M|S4
# 2   TJBzE@aj02V^WBIUD%WCt7-:t7xt
# 3   ThEyb|s:ay00f7WB?ba|kBIUayWV
# 4   T6G97~^?WA_7D}x_4,0MIfEnR?Vu
# 5   ThI3]qozS%NJn$nO0Maxng?FozXS
# 6   TRMqYLkq{#zBiwbc-qbcK0+br?S#
# 7   TUE_{yysg$buR-S4EL$%-oxGbHf6
# 8   TrH.7,$yj]I9-oofI9xtoe~qV@af
# 9   TKGkRh~B5S^0^PRS9Ev~=|^*Mxs=
# 10  TGE2m;-415D$S$Dl^j-PIutLbwNs
# 11  TdG[m9M{9Z%f%MRk4T-;x]NcM{xu
# 12  TcL4vlRP?H00D%_3-;xuWBoLt7Mx
# 13  TDE.Ibt6E114M{RO9|s:E1^jxaWV
# 14  T78ggMM_0L-TWBIq9at8t34=of${
# 15  T98ESi%MI9ocR+IU8^IUMy%OoJoJ
# 16  T34.--tS4.8yf8%M9WRj%3spjaSN
# 17  TpOW?GbIkX0#WBRkE3oebHIpt6j?
# 18  TqJk7VWC?b~Ws:NH-;ayWCNbofRP
# 19  TCFq?x4U9u1[tkI:]zOFRj$M%0R*
# 20  TlLDANs.x]0eoLxa-qWCoLxuR*NH
# 21  TrHw_l~T%f%f%Lt6RjS4RjR,ofxZ
# 22  TGQ;}%ofupNWjFrwY|jbcjvRbaX*
# 23  T99QgL%K0LESNGxWtL%KxG8{NHXS
# 24  TEA9$s}kwHNLI[IooIt7s,-U$$n$
# 25  T*NS_@Sjth~pohoyJDjcRkoeWVs8
# 26  T8D+#mxo%h]z-.NfVB$}NL.5xss=
# 27  TeNc=_Rj?b-=Rkj[_NoeIVMcNGWV
# 28  TKLgU#C9I;7i01RPkW#PR5IpaKM{
# 29  TcK1q6%MRl1TRja$9gNFafMdt7X9
#
#                                             backdrops  \
# 0   [{'backdrop_url': '/backdrop/175179036/{profil...
# 1   [{'backdrop_url': '/backdrop/10988782/{profile...
# 2   [{'backdrop_url': '/backdrop/174432125/{profil...
# 3                                                 NaN
# 4   [{'backdrop_url': '/backdrop/188686345/{profil...
# 5                                                 NaN
# 6                                                 NaN
# 7   [{'backdrop_url': '/backdrop/11241817/{profile...
# 8   [{'backdrop_url': '/backdrop/8811062/{profile}...
# 9   [{'backdrop_url': '/backdrop/85615529/{profile...
# 10  [{'backdrop_url': '/backdrop/189074089/{profil...
# 11  [{'backdrop_url': '/backdrop/250435257/{profil...
# 12  [{'backdrop_url': '/backdrop/270410655/{profil...
# 13  [{'backdrop_url': '/backdrop/177640203/{profil...
# 14  [{'backdrop_url': '/backdrop/132054801/{profil...
# 15  [{'backdrop_url': '/backdrop/180860600/{profil...
# 16  [{'backdrop_url': '/backdrop/245064861/{profil...
# 17  [{'backdrop_url': '/backdrop/11001334/{profile...
# 18  [{'backdrop_url': '/backdrop/24686564/{profile...
# 19  [{'backdrop_url': '/backdrop/143045718/{profil...
# 20  [{'backdrop_url': '/backdrop/86615587/{profile...
# 21  [{'backdrop_url': '/backdrop/246440951/{profil...
# 22  [{'backdrop_url': '/backdrop/261973612/{profil...
# 23  [{'backdrop_url': '/backdrop/112471871/{profil...
# 24  [{'backdrop_url': '/backdrop/176377275/{profil...
# 25  [{'backdrop_url': '/backdrop/199414732/{profil...
# 26  [{'backdrop_url': '/backdrop/82657396/{profile...
# 27  [{'backdrop_url': '/backdrop/182380193/{profil...
# 28  [{'backdrop_url': '/backdrop/722500/{profile}'...
# 29  [{'backdrop_url': '/backdrop/445480/{profile}'...
#
#                                     short_description  original_release_year  \
# 0   Mélancolie, una atractiva joven, es asaltada y...                   1970
# 1   Kong es un asesino profesional, sordomudo desd...                   1999
# 2   Debido a una extraña epidemia, los pasajeros d...                   1932
# 3   A poetic portrait of the world-renowned Ballet...                   2012
# 4   Charlie Babbitt, un joven sin corazón, espera ...                   1988
# 5   Determinadas circunstancias, entre las que se ...                   2001
# 6   The moody, music-filled romance Barsaat was Ra...                   1949
# 7   Baran es la historia de refugiados afganos con...                   2001
# 8   Janey is on vacation with her brother, Jim, mo...                   2001
# 9   Barkhaa is a Bollywood Romantic film, directed...                   2015
# 10  Jack Burton es un camionero que, en una de sus...                   1986
# 11  Sigue las aventuras de Speed Racer, un corredo...                   2008
# 12  Ninja Assassin narra la historia de Raizo (Rai...                   2009
# 13  Jack y Sally, dos de sus mejores amigos, sorpr...                   1992
# 14  Estamos en el universo del Emperador Shao-Khan...                   1997
# 15  Un joven abogado, recién licenciado e idealist...                   1997
# 16  Una chica con esquizofrenia empieza a tener al...                   2021
# 17  Un día ingresan a la joven Young-goon en un ho...                   2006
# 18  Protagonizada por David Oyelowo, Lupita Nyong’...                   2016
# 19  Años 70. Las esposas de un grupo de mafiosos d...                   2019
# 20  El éxito como cantante de Esther Hoffman es pa...                   1976
# 21  Dos años después de una invasión intergaláctic...                   2020
# 22  Ofelia, Magda, Reyes, Helena y Nuria forman un...                   2005
# 23  Annie es una exitosa abogada que vive en una c...                   2019
# 24  The Kid, un músico pobre y atormentado por los...                   1984
# 25  Un inglés que creció en Londres durante la II ...                   2015
# 26  Suecia, siglo XVII. Durante la guerra de los T...                   1933
# 27  Un abogado de farmacéuticas chino acusado de u...                   2017
# 28  Queen of the Desert es un ‘biopic’ que cuenta ...                   2015
# 29  Orphaned siblings Pari and Chotu embark on a j...                   2015
#
#    object_type  ...                                       external_ids  \
# 0        movie  ...  [{'provider': 'tmdb', 'external_id': '27889'},...
# 1        movie  ...  [{'provider': 'tms', 'external_id': 'MV0022017...
# 2        movie  ...  [{'provider': 'tmdb_latest', 'external_id': '6...
# 3        movie  ...  [{'provider': 'imdb', 'external_id': 'tt233803...
# 4        movie  ...  [{'provider': 'imdb', 'external_id': 'tt009595...
# 5        movie  ...  [{'provider': 'tmdb_latest', 'external_id': '3...
# 6        movie  ...  [{'provider': 'rovi', 'external_id': '6652'}, ...
# 7        movie  ...  [{'provider': 'tms', 'external_id': 'MV0011573...
# 8        movie  ...  [{'provider': 'iva', 'external_id': '629681'},...
# 9        movie  ...  [{'provider': 'gowatchit', 'external_id': '476...
# 10       movie  ...  [{'provider': 'tmdb', 'external_id': '6978'}, ...
# 11       movie  ...  [{'provider': 'tms', 'external_id': 'MV0020007...
# 12       movie  ...  [{'provider': 'gowatchit', 'external_id': '126...
# 13       movie  ...  [{'provider': 'tmdb_latest', 'external_id': '2...
# 14       movie  ...  [{'provider': 'tmdb', 'external_id': '9823'}, ...
# 15       movie  ...  [{'provider': 'imdb_latest', 'external_id': 't...
# 16       movie  ...  [{'provider': 'tmdb_latest', 'external_id': '5...
# 17       movie  ...  [{'provider': 'imdb_latest', 'external_id': 't...
# 18       movie  ...  [{'provider': 'tmdb_latest', 'external_id': '3...
# 19       movie  ...  [{'provider': 'tmdb', 'external_id': '487680'}...
# 20       movie  ...  [{'provider': 'tmdb', 'external_id': '19610'},...
# 21       movie  ...  [{'provider': 'imdb_latest', 'external_id': 't...
# 22       movie  ...  [{'provider': 'iva', 'external_id': '891079'},...
# 23       movie  ...  [{'provider': 'gowatchit', 'external_id': '868...
# 24       movie  ...  [{'provider': 'tms', 'external_id': 'MV0001703...
# 25       movie  ...  [{'provider': 'rovi', 'external_id': '10468943...
# 26       movie  ...  [{'provider': 'gowatchit', 'external_id': '540...
# 27       movie  ...  [{'provider': 'tmdb', 'external_id': '372782'}...
# 28       movie  ...  [{'provider': 'imdb_latest', 'external_id': 't...
# 29       movie  ...  [{'provider': 'imdb', 'external_id': 'tt408858...
#
#                     genre_ids runtime production_countries  \
# 0              [12, 4, 6, 18]     120             [IT, FR]
# 1           [12, 13, 1, 4, 6]     105                 [TH]
# 2                         [6]      94                 [US]
# 3                     [5, 18]      80                 [BE]
# 4                         [6]     134                 [US]
# 5              [18, 13, 6, 1]      97                 [DE]
# 6                     [6, 13]     171                 [IN]
# 7                     [6, 13]      90                 [IR]
# 8              [13, 6, 3, 18]      92                 [NZ]
# 9                     [13, 6]     127                 [IN]
# 10                  [7, 3, 1]      99                 [US]
# 11  [1, 3, 6, 10, 14, 15, 18]     135         [AU, DE, US]
# 12                [1, 12, 18]      99             [DE, US]
# 13                 [13, 3, 6]     108                 [US]
# 14             [7, 14, 12, 1]      95                 [US]
# 15                 [4, 12, 6]     135                 [US]
# 16                 [12, 9, 6]     109                 [US]
# 17             [6, 3, 13, 18]     105                 [KR]
# 18                    [6, 15]     124                 [US]
# 19                  [1, 6, 4]     102             [CA, US]
# 20                [13, 6, 11]     139                 [US]
# 21                    [1, 14]     128                 [AU]
# 22                [13, 3, 18]     107                 [ES]
# 23                    [6, 18]     127             [DK, SE]
# 24                [13, 6, 11]     111                 [US]
# 25              [6, 8, 3, 18]     114         [IE, FR, RO]
# 26                 [6, 8, 13]      99                 [US]
# 27                 [12, 1, 4]     106             [CN, HK]
# 28                 [6, 8, 13]     128             [MA, US]
# 29                     [6, 3]     106                 [IN]
#
#                                   permanent_audiences  \
# 0           [pa:e995ff56-e2ad-460e-a897-f70f4e1c5e3e]
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4           [pa:bf7c313c-eec9-47fe-a719-d572580f694d]
# 5                                                 NaN
# 6                                                 NaN
# 7           [pa:b879dad8-8dd3-4518-a89e-243ddda6f514]
# 8                                                 NaN
# 9                                                 NaN
# 10  [pa:8ba7f25a-7eb7-415b-9b62-7f037598074f, pa:9...
# 11          [pa:922025bb-68fe-4c20-ac75-ece0977279ff]
# 12          [pa:8ba7f25a-7eb7-415b-9b62-7f037598074f]
# 13  [pa:9a1c71b9-6530-49ab-b8fc-54f16a94a006, pa:b...
# 14          [pa:8922fd0e-309a-43e4-84a8-30b4d0644520]
# 15          [pa:3837ea6a-6c77-4b06-b434-a1b5a20b70ca]
# 16          [pa:7be516a7-08bd-4589-84e1-a88647a5cfc0]
# 17          [pa:286ccfff-7bbd-4b6e-837e-d2da3fd4092e]
# 18  [pa:79245f22-9849-4566-b304-a021a7da5a4f, pa:a...
# 19          [pa:678e75a7-2209-41d9-9310-df64188126da]
# 20          [pa:27c33cc8-a23b-4b43-8865-23354c5ecd90]
# 21          [pa:14031ec1-6dfb-4919-a9b1-219b14127390]
# 22          [pa:12415b46-6819-4d98-b4f9-8dcc123c86f8]
# 23          [pa:185b46c8-1ba7-4f4c-b89e-74b917a25a8a]
# 24          [pa:27c33cc8-a23b-4b43-8865-23354c5ecd90]
# 25          [pa:9a1c71b9-6530-49ab-b8fc-54f16a94a006]
# 26  [pa:1e97eaa0-4736-41b2-b33d-e95517d0f8cb, pa:7...
# 27          [pa:b71b706d-6c43-4573-8d96-370463aaca8f]
# 28  [pa:79245f22-9849-4566-b304-a021a7da5a4f, pa:9...
# 29          [pa:77429883-d2d9-4be6-8746-fd36d7d449c1]
#
#             full_paths.MOVIE_DETAIL_OVERVIEW  age_certification  \
# 0      /es/pelicula/el-pasajero-de-la-lluvia                NaN
# 1             /es/pelicula/muerte-en-bangkok                 18
# 2                          /es/pelicula/rain                NaN
# 3                     /es/pelicula/rain-2012                NaN
# 4                      /es/pelicula/rain-man               APTA
# 5                        /es/pelicula/lluvia                NaN
# 6                        /es/pelicula/brsaat                NaN
# 7                         /es/pelicula/baran                NaN
# 8                     /es/pelicula/rain-2001                NaN
# 9                       /es/pelicula/barkhaa                NaN
# 10    /es/pelicula/golpe-en-la-pequena-china                NaN
# 11                  /es/pelicula/speed-racer                  7
# 12               /es/pelicula/ninja-assassin                 18
# 13           /es/pelicula/husbands-and-wives                 12
# 14   /es/pelicula/mortal-kombat-aniquilacion                 18
# 15                /es/pelicula/the-rainmaker                NaN
# 16            /es/pelicula/miedo-a-la-lluvia                NaN
# 17                /es/pelicula/soy-un-cyborg                NaN
# 18               /es/pelicula/queen-of-katwe                NaN
# 19             /es/pelicula/the-kitchen-2019                 16
# 20  /es/pelicula/ha-nacido-una-estrella-1976                NaN
# 21          /es/pelicula/occupation-rainfall                 12
# 22                       /es/pelicula/reinas                NaN
# 23           /es/pelicula/reina-de-corazones                 18
# 24                  /es/pelicula/purple-rain                 12
# 25               /es/pelicula/reina-y-patria                 12
# 26  /es/pelicula/la-reina-cristina-de-suecia                NaN
# 27                      /es/pelicula/manhunt                NaN
# 28        /es/pelicula/la-reina-del-desierto                 12
# 29                       /es/pelicula/dhanak                NaN
#
#    localized_release_date                                              clips  \
# 0                     NaN                                                NaN
# 1                     NaN                                                NaN
# 2                     NaN                                                NaN
# 3                     NaN                                                NaN
# 4                     NaN                                                NaN
# 5    2003-04-04T00:00:00Z                                                NaN
# 6                     NaN                                                NaN
# 7                     NaN                                                NaN
# 8                     NaN                                                NaN
# 9                     NaN                                                NaN
# 10                    NaN  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 11                    NaN  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 12                    NaN  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 13                    NaN                                                NaN
# 14                    NaN                                                NaN
# 15   2021-06-15T00:00:00Z                                                NaN
# 16                    NaN  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 17                    NaN                                                NaN
# 18                    NaN  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 19                    NaN  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 20                    NaN                                                NaN
# 21   2021-10-15T00:00:00Z  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 22                    NaN                                                NaN
# 23                    NaN                                                NaN
# 24                    NaN  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 25                    NaN                                                NaN
# 26                    NaN                                                NaN
# 27                    NaN                                                NaN
# 28                    NaN                                                NaN
# 29                    NaN                                                NaN
#
#                                              upcoming
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  [{'package_id': 8, 'release_window_from': '202...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 24 columns]

# %%
table.columns
# Out:
# Index(['jw_entity_id', 'id', 'title', 'full_path', 'poster',
#        'poster_blur_hash', 'backdrops', 'short_description',
#        'original_release_year', 'object_type', 'original_title', 'offers',
#        'scoring', 'credits', 'external_ids', 'genre_ids', 'runtime',
#        'production_countries', 'permanent_audiences',
#        'full_paths.MOVIE_DETAIL_OVERVIEW', 'age_certification',
#        'localized_release_date', 'clips', 'upcoming'],
#       dtype='object')

# %%
table_col = table.drop(['backdrops', 'external_ids', 'genre_ids', 'permanent_audiences', 
                            'localized_release_date', 'upcoming', 'poster_blur_hash', 
                            'full_paths.MOVIE_DETAIL_OVERVIEW','offers', 'clips', 'scoring','credits'], axis = 1)
table_col
# Out:
#    jw_entity_id      id                              title  \
# 0      tm108123  108123           El pasajero de la lluvia
# 1       tm51622   51622                  Muerte en Bangkok
# 2        tm6677    6677                     Bajo la lluvia
# 3       tm68670   68670                               Rain
# 4       tm43389   43389                           Rain Man
# 5      tm221534  221534                             Lluvia
# 6       tm61543   61543                            Barsaat
# 7       tm49812   49812                     Baran (Lluvia)
# 8       tm36538   36538                               Rain
# 9      tm211285  211285                            Barkhaa
# 10     tm112770  112770          Golpe en la pequeña China
# 11      tm31389   31389                        Speed Racer
# 12     tm148335  148335                     Ninja Assassin
# 13     tm122601  122601                  Maridos y Mujeres
# 14     tm192727  192727        Mortal Kombat: Aniquilación
# 15     tm192362  192362  Legítima defensa, de John Grisham
# 16     tm471779  471779                  Miedo a la lluvia
# 17      tm32384   32384                      Soy un cyborg
# 18     tm239761  239761                  La reina de Katwe
# 19     tm375780  375780             La cocina del infierno
# 20       tm1390    1390             Ha nacido una estrella
# 21     tm499045  499045         Ocupación: Proyecto Lluvia
# 22     tm178089  178089                             Reinas
# 23     tm410590  410590                 Reina de corazones
# 24     tm170082  170082                Prince: Purple Rain
# 25     tm156806  156806                     Reina y patria
# 26     tm137046  137046        La reina Cristina de Suecia
# 27     tm311319  311319                            Manhunt
# 28     tm138802  138802              La reina del desierto
# 29     tm193388  193388                             Dhanak
#
#                                    full_path                       poster  \
# 0      /es/pelicula/el-pasajero-de-la-lluvia  /poster/137559485/{profile}
# 1             /es/pelicula/muerte-en-bangkok  /poster/191726124/{profile}
# 2                          /es/pelicula/rain  /poster/111773626/{profile}
# 3                     /es/pelicula/rain-2012  /poster/139151921/{profile}
# 4                      /es/pelicula/rain-man   /poster/14863126/{profile}
# 5                        /es/pelicula/lluvia  /poster/138556765/{profile}
# 6                        /es/pelicula/brsaat  /poster/261091407/{profile}
# 7                         /es/pelicula/baran   /poster/11241812/{profile}
# 8                     /es/pelicula/rain-2001    /poster/8811061/{profile}
# 9                       /es/pelicula/barkhaa   /poster/85615527/{profile}
# 10    /es/pelicula/golpe-en-la-pequena-china  /poster/248403362/{profile}
# 11                  /es/pelicula/speed-racer  /poster/250435255/{profile}
# 12               /es/pelicula/ninja-assassin  /poster/247509444/{profile}
# 13           /es/pelicula/husbands-and-wives  /poster/150179154/{profile}
# 14   /es/pelicula/mortal-kombat-aniquilacion  /poster/222301490/{profile}
# 15                /es/pelicula/the-rainmaker  /poster/131360806/{profile}
# 16            /es/pelicula/miedo-a-la-lluvia  /poster/241018036/{profile}
# 17                /es/pelicula/soy-un-cyborg   /poster/11001332/{profile}
# 18               /es/pelicula/queen-of-katwe  /poster/200315569/{profile}
# 19             /es/pelicula/the-kitchen-2019  /poster/230014180/{profile}
# 20  /es/pelicula/ha-nacido-una-estrella-1976  /poster/218102364/{profile}
# 21          /es/pelicula/occupation-rainfall  /poster/254323778/{profile}
# 22                       /es/pelicula/reinas  /poster/243440658/{profile}
# 23           /es/pelicula/reina-de-corazones  /poster/171458873/{profile}
# 24                  /es/pelicula/purple-rain  /poster/176377272/{profile}
# 25               /es/pelicula/reina-y-patria  /poster/249368696/{profile}
# 26  /es/pelicula/la-reina-cristina-de-suecia   /poster/50658774/{profile}
# 27                      /es/pelicula/manhunt   /poster/72330284/{profile}
# 28        /es/pelicula/la-reina-del-desierto  /poster/148035007/{profile}
# 29                       /es/pelicula/dhanak  /poster/142203637/{profile}
#
#                                     short_description  original_release_year  \
# 0   Mélancolie, una atractiva joven, es asaltada y...                   1970
# 1   Kong es un asesino profesional, sordomudo desd...                   1999
# 2   Debido a una extraña epidemia, los pasajeros d...                   1932
# 3   A poetic portrait of the world-renowned Ballet...                   2012
# 4   Charlie Babbitt, un joven sin corazón, espera ...                   1988
# 5   Determinadas circunstancias, entre las que se ...                   2001
# 6   The moody, music-filled romance Barsaat was Ra...                   1949
# 7   Baran es la historia de refugiados afganos con...                   2001
# 8   Janey is on vacation with her brother, Jim, mo...                   2001
# 9   Barkhaa is a Bollywood Romantic film, directed...                   2015
# 10  Jack Burton es un camionero que, en una de sus...                   1986
# 11  Sigue las aventuras de Speed Racer, un corredo...                   2008
# 12  Ninja Assassin narra la historia de Raizo (Rai...                   2009
# 13  Jack y Sally, dos de sus mejores amigos, sorpr...                   1992
# 14  Estamos en el universo del Emperador Shao-Khan...                   1997
# 15  Un joven abogado, recién licenciado e idealist...                   1997
# 16  Una chica con esquizofrenia empieza a tener al...                   2021
# 17  Un día ingresan a la joven Young-goon en un ho...                   2006
# 18  Protagonizada por David Oyelowo, Lupita Nyong’...                   2016
# 19  Años 70. Las esposas de un grupo de mafiosos d...                   2019
# 20  El éxito como cantante de Esther Hoffman es pa...                   1976
# 21  Dos años después de una invasión intergaláctic...                   2020
# 22  Ofelia, Magda, Reyes, Helena y Nuria forman un...                   2005
# 23  Annie es una exitosa abogada que vive en una c...                   2019
# 24  The Kid, un músico pobre y atormentado por los...                   1984
# 25  Un inglés que creció en Londres durante la II ...                   2015
# 26  Suecia, siglo XVII. Durante la guerra de los T...                   1933
# 27  Un abogado de farmacéuticas chino acusado de u...                   2017
# 28  Queen of the Desert es un ‘biopic’ que cuenta ...                   2015
# 29  Orphaned siblings Pari and Chotu embark on a j...                   2015
#
#    object_type               original_title  runtime production_countries  \
# 0        movie      Le passager de la pluie      120             [IT, FR]
# 1        movie          เพชฌฆาตเงียบอันตราย      105                 [TH]
# 2        movie                         Rain       94                 [US]
# 3        movie                         Rain       80                 [BE]
# 4        movie                     Rain Man      134                 [US]
# 5        movie                         Rain       97                 [DE]
# 6        movie                        बरसात      171                 [IN]
# 7        movie                        باران       90                 [IR]
# 8        movie                         Rain       92                 [NZ]
# 9        movie                      Barkhaa      127                 [IN]
# 10       movie  Big Trouble in Little China       99                 [US]
# 11       movie                  Speed Racer      135         [AU, DE, US]
# 12       movie               Ninja Assassin       99             [DE, US]
# 13       movie           Husbands and Wives      108                 [US]
# 14       movie  Mortal Kombat: Annihilation       95                 [US]
# 15       movie                The Rainmaker      135                 [US]
# 16       movie                 Fear of Rain      109                 [US]
# 17       movie                   싸이보그지만 괜찮아      105                 [KR]
# 18       movie               Queen of Katwe      124                 [US]
# 19       movie                  The Kitchen      102             [CA, US]
# 20       movie               A Star Is Born      139                 [US]
# 21       movie         Occupation: Rainfall      128                 [AU]
# 22       movie                       Reinas      107                 [ES]
# 23       movie                   Dronningen      127             [DK, SE]
# 24       movie                  Purple Rain      111                 [US]
# 25       movie              Queen & Country      114         [IE, FR, RO]
# 26       movie              Queen Christina       99                 [US]
# 27       movie                           追捕      106             [CN, HK]
# 28       movie          Queen of the Desert      128             [MA, US]
# 29       movie                          धनक      106                 [IN]
#
#    age_certification
# 0                NaN
# 1                 18
# 2                NaN
# 3                NaN
# 4               APTA
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11                 7
# 12                18
# 13                12
# 14                18
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19                16
# 20               NaN
# 21                12
# 22               NaN
# 23                18
# 24                12
# 25                12
# 26               NaN
# 27               NaN
# 28                12
# 29               NaN

# %%
table_col.rename(columns = {'original_title':'originalTitle'}, inplace = True)
table_col
# Out:
#    jw_entity_id      id                              title  \
# 0      tm108123  108123           El pasajero de la lluvia
# 1       tm51622   51622                  Muerte en Bangkok
# 2        tm6677    6677                     Bajo la lluvia
# 3       tm68670   68670                               Rain
# 4       tm43389   43389                           Rain Man
# 5      tm221534  221534                             Lluvia
# 6       tm61543   61543                            Barsaat
# 7       tm49812   49812                     Baran (Lluvia)
# 8       tm36538   36538                               Rain
# 9      tm211285  211285                            Barkhaa
# 10     tm112770  112770          Golpe en la pequeña China
# 11      tm31389   31389                        Speed Racer
# 12     tm148335  148335                     Ninja Assassin
# 13     tm122601  122601                  Maridos y Mujeres
# 14     tm192727  192727        Mortal Kombat: Aniquilación
# 15     tm192362  192362  Legítima defensa, de John Grisham
# 16     tm471779  471779                  Miedo a la lluvia
# 17      tm32384   32384                      Soy un cyborg
# 18     tm239761  239761                  La reina de Katwe
# 19     tm375780  375780             La cocina del infierno
# 20       tm1390    1390             Ha nacido una estrella
# 21     tm499045  499045         Ocupación: Proyecto Lluvia
# 22     tm178089  178089                             Reinas
# 23     tm410590  410590                 Reina de corazones
# 24     tm170082  170082                Prince: Purple Rain
# 25     tm156806  156806                     Reina y patria
# 26     tm137046  137046        La reina Cristina de Suecia
# 27     tm311319  311319                            Manhunt
# 28     tm138802  138802              La reina del desierto
# 29     tm193388  193388                             Dhanak
#
#                                    full_path                       poster  \
# 0      /es/pelicula/el-pasajero-de-la-lluvia  /poster/137559485/{profile}
# 1             /es/pelicula/muerte-en-bangkok  /poster/191726124/{profile}
# 2                          /es/pelicula/rain  /poster/111773626/{profile}
# 3                     /es/pelicula/rain-2012  /poster/139151921/{profile}
# 4                      /es/pelicula/rain-man   /poster/14863126/{profile}
# 5                        /es/pelicula/lluvia  /poster/138556765/{profile}
# 6                        /es/pelicula/brsaat  /poster/261091407/{profile}
# 7                         /es/pelicula/baran   /poster/11241812/{profile}
# 8                     /es/pelicula/rain-2001    /poster/8811061/{profile}
# 9                       /es/pelicula/barkhaa   /poster/85615527/{profile}
# 10    /es/pelicula/golpe-en-la-pequena-china  /poster/248403362/{profile}
# 11                  /es/pelicula/speed-racer  /poster/250435255/{profile}
# 12               /es/pelicula/ninja-assassin  /poster/247509444/{profile}
# 13           /es/pelicula/husbands-and-wives  /poster/150179154/{profile}
# 14   /es/pelicula/mortal-kombat-aniquilacion  /poster/222301490/{profile}
# 15                /es/pelicula/the-rainmaker  /poster/131360806/{profile}
# 16            /es/pelicula/miedo-a-la-lluvia  /poster/241018036/{profile}
# 17                /es/pelicula/soy-un-cyborg   /poster/11001332/{profile}
# 18               /es/pelicula/queen-of-katwe  /poster/200315569/{profile}
# 19             /es/pelicula/the-kitchen-2019  /poster/230014180/{profile}
# 20  /es/pelicula/ha-nacido-una-estrella-1976  /poster/218102364/{profile}
# 21          /es/pelicula/occupation-rainfall  /poster/254323778/{profile}
# 22                       /es/pelicula/reinas  /poster/243440658/{profile}
# 23           /es/pelicula/reina-de-corazones  /poster/171458873/{profile}
# 24                  /es/pelicula/purple-rain  /poster/176377272/{profile}
# 25               /es/pelicula/reina-y-patria  /poster/249368696/{profile}
# 26  /es/pelicula/la-reina-cristina-de-suecia   /poster/50658774/{profile}
# 27                      /es/pelicula/manhunt   /poster/72330284/{profile}
# 28        /es/pelicula/la-reina-del-desierto  /poster/148035007/{profile}
# 29                       /es/pelicula/dhanak  /poster/142203637/{profile}
#
#                                     short_description  original_release_year  \
# 0   Mélancolie, una atractiva joven, es asaltada y...                   1970
# 1   Kong es un asesino profesional, sordomudo desd...                   1999
# 2   Debido a una extraña epidemia, los pasajeros d...                   1932
# 3   A poetic portrait of the world-renowned Ballet...                   2012
# 4   Charlie Babbitt, un joven sin corazón, espera ...                   1988
# 5   Determinadas circunstancias, entre las que se ...                   2001
# 6   The moody, music-filled romance Barsaat was Ra...                   1949
# 7   Baran es la historia de refugiados afganos con...                   2001
# 8   Janey is on vacation with her brother, Jim, mo...                   2001
# 9   Barkhaa is a Bollywood Romantic film, directed...                   2015
# 10  Jack Burton es un camionero que, en una de sus...                   1986
# 11  Sigue las aventuras de Speed Racer, un corredo...                   2008
# 12  Ninja Assassin narra la historia de Raizo (Rai...                   2009
# 13  Jack y Sally, dos de sus mejores amigos, sorpr...                   1992
# 14  Estamos en el universo del Emperador Shao-Khan...                   1997
# 15  Un joven abogado, recién licenciado e idealist...                   1997
# 16  Una chica con esquizofrenia empieza a tener al...                   2021
# 17  Un día ingresan a la joven Young-goon en un ho...                   2006
# 18  Protagonizada por David Oyelowo, Lupita Nyong’...                   2016
# 19  Años 70. Las esposas de un grupo de mafiosos d...                   2019
# 20  El éxito como cantante de Esther Hoffman es pa...                   1976
# 21  Dos años después de una invasión intergaláctic...                   2020
# 22  Ofelia, Magda, Reyes, Helena y Nuria forman un...                   2005
# 23  Annie es una exitosa abogada que vive en una c...                   2019
# 24  The Kid, un músico pobre y atormentado por los...                   1984
# 25  Un inglés que creció en Londres durante la II ...                   2015
# 26  Suecia, siglo XVII. Durante la guerra de los T...                   1933
# 27  Un abogado de farmacéuticas chino acusado de u...                   2017
# 28  Queen of the Desert es un ‘biopic’ que cuenta ...                   2015
# 29  Orphaned siblings Pari and Chotu embark on a j...                   2015
#
#    object_type                originalTitle  runtime production_countries  \
# 0        movie      Le passager de la pluie      120             [IT, FR]
# 1        movie          เพชฌฆาตเงียบอันตราย      105                 [TH]
# 2        movie                         Rain       94                 [US]
# 3        movie                         Rain       80                 [BE]
# 4        movie                     Rain Man      134                 [US]
# 5        movie                         Rain       97                 [DE]
# 6        movie                        बरसात      171                 [IN]
# 7        movie                        باران       90                 [IR]
# 8        movie                         Rain       92                 [NZ]
# 9        movie                      Barkhaa      127                 [IN]
# 10       movie  Big Trouble in Little China       99                 [US]
# 11       movie                  Speed Racer      135         [AU, DE, US]
# 12       movie               Ninja Assassin       99             [DE, US]
# 13       movie           Husbands and Wives      108                 [US]
# 14       movie  Mortal Kombat: Annihilation       95                 [US]
# 15       movie                The Rainmaker      135                 [US]
# 16       movie                 Fear of Rain      109                 [US]
# 17       movie                   싸이보그지만 괜찮아      105                 [KR]
# 18       movie               Queen of Katwe      124                 [US]
# 19       movie                  The Kitchen      102             [CA, US]
# 20       movie               A Star Is Born      139                 [US]
# 21       movie         Occupation: Rainfall      128                 [AU]
# 22       movie                       Reinas      107                 [ES]
# 23       movie                   Dronningen      127             [DK, SE]
# 24       movie                  Purple Rain      111                 [US]
# 25       movie              Queen & Country      114         [IE, FR, RO]
# 26       movie              Queen Christina       99                 [US]
# 27       movie                           追捕      106             [CN, HK]
# 28       movie          Queen of the Desert      128             [MA, US]
# 29       movie                          धनक      106                 [IN]
#
#    age_certification
# 0                NaN
# 1                 18
# 2                NaN
# 3                NaN
# 4               APTA
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11                 7
# 12                18
# 13                12
# 14                18
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19                16
# 20               NaN
# 21                12
# 22               NaN
# 23                18
# 24                12
# 25                12
# 26               NaN
# 27               NaN
# 28                12
# 29               NaN

# %%
recommend = pd.read_csv('../data/recommend.csv')
recommend
# Out:
#                          tconst  averageRating  numVotes  \
# 0     imdb.com/title/tt15097216            9.4    185162
# 1      imdb.com/title/tt0252487            9.3     39990
# 2      imdb.com/title/tt0111161            9.3   2572812
# 3      imdb.com/title/tt5354160            9.2     25759
# 4     imdb.com/title/tt10189514            9.2    109309
# ...                         ...            ...       ...
# 2546   imdb.com/title/tt0099763            7.0     35438
# 2547   imdb.com/title/tt6324278            7.0     37215
# 2548   imdb.com/title/tt0061747            7.0     38612
# 2549  imdb.com/title/tt10083340            7.0     38248
# 2550   imdb.com/title/tt0048750            7.0     37818
#
#                             primaryTitle                       originalTitle  \
# 0                               Jai Bhim                            Jai Bhim
# 1                        The Chaos Class                      Hababam Sinifi
# 2               The Shawshank Redemption            The Shawshank Redemption
# 3                            Mirror Game                            Aynabaji
# 4                        Soorarai Pottru                     Soorarai Pottru
# ...                                  ...                                 ...
# 2546  Henry: Portrait of a Serial Killer  Henry: Portrait of a Serial Killer
# 2547                          Abominable                          Abominable
# 2548                       Hang 'Em High                       Hang 'Em High
# 2549                 Gangubai Kathiawadi                 Gangubai Kathiawadi
# 2550              The Trouble with Harry              The Trouble with Harry
#
#       startYear  runtimeMinutes                      genres
# 0          2021             164         Crime,Drama,Mystery
# 1          1975              87                Comedy,Drama
# 2          1994             142                       Drama
# 3          2016             147      Crime,Mystery,Thriller
# 4          2020             153                       Drama
# ...         ...             ...                         ...
# 2546       1986              83       Biography,Crime,Drama
# 2547       2019              97  Adventure,Animation,Comedy
# 2548       1968             114               Drama,Western
# 2549       2022             152       Biography,Crime,Drama
# 2550       1955              99              Comedy,Mystery
#
# [2551 rows x 8 columns]

# %%
my_recommendation = pd.merge(recommend, table_col, how='inner', on=['originalTitle'], left_on=None, right_on=None,
left_index=False, right_index=False, sort=True)
my_recommendation
# Out:
#                      tconst  averageRating  numVotes  \
# 0  imdb.com/title/tt1517451            7.6    371431
# 1  imdb.com/title/tt0090728            7.2    136325
# 2  imdb.com/title/tt0104466            7.5     29080
# 3  imdb.com/title/tt0095953            8.0    501584
# 4  imdb.com/title/tt0119978            7.2     71645
#
#                   primaryTitle                originalTitle  startYear  \
# 0               A Star Is Born               A Star Is Born       2018
# 1  Big Trouble in Little China  Big Trouble in Little China       1986
# 2           Husbands and Wives           Husbands and Wives       1992
# 3                     Rain Man                     Rain Man       1988
# 4                The Rainmaker                The Rainmaker       1997
#
#    runtimeMinutes                   genres jw_entity_id      id  \
# 0             136      Drama,Music,Romance       tm1390    1390
# 1              99  Action,Adventure,Comedy     tm112770  112770
# 2             108     Comedy,Drama,Romance     tm122601  122601
# 3             133                    Drama      tm43389   43389
# 4             135     Crime,Drama,Thriller     tm192362  192362
#
#                                title  \
# 0             Ha nacido una estrella
# 1          Golpe en la pequeña China
# 2                  Maridos y Mujeres
# 3                           Rain Man
# 4  Legítima defensa, de John Grisham
#
#                                   full_path                       poster  \
# 0  /es/pelicula/ha-nacido-una-estrella-1976  /poster/218102364/{profile}
# 1    /es/pelicula/golpe-en-la-pequena-china  /poster/248403362/{profile}
# 2           /es/pelicula/husbands-and-wives  /poster/150179154/{profile}
# 3                     /es/pelicula/rain-man   /poster/14863126/{profile}
# 4                /es/pelicula/the-rainmaker  /poster/131360806/{profile}
#
#                                    short_description  original_release_year  \
# 0  El éxito como cantante de Esther Hoffman es pa...                   1976
# 1  Jack Burton es un camionero que, en una de sus...                   1986
# 2  Jack y Sally, dos de sus mejores amigos, sorpr...                   1992
# 3  Charlie Babbitt, un joven sin corazón, espera ...                   1988
# 4  Un joven abogado, recién licenciado e idealist...                   1997
#
#   object_type  runtime production_countries age_certification
# 0       movie      139                 [US]               NaN
# 1       movie       99                 [US]               NaN
# 2       movie      108                 [US]                12
# 3       movie      134                 [US]              APTA
# 4       movie      135                 [US]               NaN
