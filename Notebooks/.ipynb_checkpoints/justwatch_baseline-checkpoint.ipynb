# %%
import pandas as pd
from justwatch import JustWatch

# %%
proveedores = ['prv','nfx', 'dnp', 'dnp']
just_watch = JustWatch(country='ES', providers = proveedores)

# %%
just_watch.get_providers()
# Out:
# [{'id': 8,
#   'technical_name': 'netflix',
#   'short_name': 'nfx',
#   'clear_name': 'Netflix',
#   'display_priority': 1,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/207360008/{profile}',
#   'icon_blur_hash': 'KVBJXFjt1^jto1a|A;a|,Z',
#   'slug': 'netflix',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 119,
#   'technical_name': 'amazonprimevideo',
#   'short_name': 'prv',
#   'clear_name': 'Amazon Prime Video',
#   'display_priority': 2,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/52449861/{profile}',
#   'icon_blur_hash': 'KMQAQ@%M~Ux]WCjF~qj[IU',
#   'slug': 'amazon-prime-video',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': ['afg',
#    'abm',
#    'alo',
#    'ast',
#    'acb',
#    'azt',
#    'ado',
#    'aim',
#    'aoc',
#    'asb',
#    'ang',
#    'abo',
#    'abb',
#    'abe',
#    'ame',
#    'app',
#    'ait',
#    'apo',
#    'asm',
#    'anh',
#    'aep',
#    'adp',
#    'ahh',
#    'abp',
#    'aln',
#    'agc',
#    'ach',
#    'afl',
#    'aft',
#    'ahb',
#    'fac',
#    'bpc',
#    'nic',
#    'aav',
#    'amu',
#    'ahy',
#    'aum',
#    'aan',
#    'acu',
#    'asf',
#    'acm',
#    'afa',
#    'ash',
#    'asn',
#    'avt',
#    'ahm',
#    'apa',
#    'apm',
#    'afm',
#    'apg',
#    'asd',
#    'abf',
#    'aah',
#    'ask',
#    'adw',
#    'aen',
#    'afb',
#    'acs',
#    'apk',
#    'azp',
#    'amg',
#    'aot',
#    'aac',
#    'azh',
#    'acn',
#    'asu'],
#   'parent_packages': None},
#  {'id': 337,
#   'technical_name': 'disneyplus',
#   'short_name': 'dnp',
#   'clear_name': 'Disney Plus',
#   'display_priority': 3,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/147638351/{profile}',
#   'icon_blur_hash': 'KQ5=;uogRNR1f5ohIUWBt6',
#   'slug': 'disney-plus',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 257,
#   'technical_name': 'fubotv',
#   'short_name': 'fuv',
#   'clear_name': 'fuboTV',
#   'display_priority': 4,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/124248862/{profile}',
#   'icon_blur_hash': 'L~K@38j[1IayoLfQayfQaKf6kWfk',
#   'slug': 'fubotv',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 2,
#   'technical_name': 'itunes',
#   'short_name': 'itu',
#   'clear_name': 'Apple iTunes',
#   'display_priority': 5,
#   'priority': 0,
#   'monetization_types': ['rent', 'buy'],
#   'icon_url': '/icon/190848813/{profile}',
#   'icon_blur_hash': 'KSA^OK%MIUoffQay00M{%M',
#   'slug': 'apple-itunes',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 350,
#   'technical_name': 'appletvplus',
#   'short_name': 'atp',
#   'clear_name': 'Apple TV Plus',
#   'display_priority': 6,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/152862153/{profile}',
#   'icon_blur_hash': 'KH7w?1%MIUj[j[ay00IUxu',
#   'slug': 'apple-tv-plus',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 223,
#   'technical_name': 'hayu',
#   'short_name': 'hay',
#   'clear_name': 'hayu',
#   'display_priority': 7,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/89154446/{profile}',
#   'icon_blur_hash': 'KdRCMd#S.mpcS#rru4kqR6',
#   'slug': 'hayu',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 63,
#   'technical_name': 'filmin',
#   'short_name': 'fil',
#   'clear_name': 'Filmin',
#   'display_priority': 8,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/187161245/{profile}',
#   'icon_blur_hash': 'Ka72{LJ5n6kBa{f7D6$lXQ',
#   'slug': 'filmin',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 64,
#   'technical_name': 'filminplus',
#   'short_name': 'fip',
#   'clear_name': 'Filmin Plus',
#   'display_priority': 9,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/188383996/{profile}',
#   'icon_blur_hash': 'KS7et-JOVajFoLbHD5w~o|',
#   'slug': 'filmin-plus',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 384,
#   'technical_name': 'hbomax',
#   'short_name': 'hbm',
#   'clear_name': 'HBO Max',
#   'display_priority': 10,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/182948653/{profile}',
#   'icon_blur_hash': 'KI9@PAog4m_2jtD%D}WTxv',
#   'slug': 'hbo-max',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 149,
#   'technical_name': 'movistar',
#   'short_name': 'mvs',
#   'clear_name': 'Movistar Plus',
#   'display_priority': 11,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/5985414/{profile}',
#   'icon_blur_hash': 'KYQTDoM{-pRkf6of~p%MM|',
#   'slug': 'movistar-plus',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 35,
#   'technical_name': 'wuaki',
#   'short_name': 'wki',
#   'clear_name': 'Rakuten TV',
#   'display_priority': 12,
#   'priority': 0,
#   'monetization_types': ['rent', 'buy', 'flatrate'],
#   'icon_url': '/icon/128599720/{profile}',
#   'icon_blur_hash': 'KVNtRli_D4oLozozHrj[x]',
#   'slug': 'rakuten-tv',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 62,
#   'technical_name': 'atres',
#   'short_name': 'atr',
#   'clear_name': 'Atres Player',
#   'display_priority': 14,
#   'priority': 0,
#   'monetization_types': ['flatrate', 'ads'],
#   'icon_url': '/icon/179272126/{profile}',
#   'icon_blur_hash': 'K64_hC-;R*t7ofay0KIAof',
#   'slug': 'atres-player',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 3,
#   'technical_name': 'play',
#   'short_name': 'ply',
#   'clear_name': 'Google Play Movies',
#   'display_priority': 15,
#   'priority': 0,
#   'monetization_types': ['rent', 'buy'],
#   'icon_url': '/icon/169478387/{profile}',
#   'icon_blur_hash': 'KSQ,j#Ac~XK#JB$S%MxBMe',
#   'slug': 'google-play-movies',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 68,
#   'technical_name': 'microsoft',
#   'short_name': 'msf',
#   'clear_name': 'Microsoft Store',
#   'display_priority': 16,
#   'priority': 0,
#   'monetization_types': ['buy', 'rent'],
#   'icon_url': '/icon/820542/{profile}',
#   'icon_blur_hash': 'KYDBUIof0NWFjuWC4qWC?Y',
#   'slug': 'microsoft-store',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 11,
#   'technical_name': 'mubi',
#   'short_name': 'mbi',
#   'clear_name': 'Mubi',
#   'display_priority': 17,
#   'priority': 0,
#   'monetization_types': ['flatrate', 'rent'],
#   'icon_url': '/icon/164970114/{profile}',
#   'icon_blur_hash': 'KF5rQpoiRib2axj@9DWCt7',
#   'slug': 'mubi',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 100,
#   'technical_name': 'guidedoc',
#   'short_name': 'gdc',
#   'clear_name': 'GuideDoc',
#   'display_priority': 18,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/2625277/{profile}',
#   'icon_blur_hash': 'KOB6fcS50NW?ayj[4=s:-n',
#   'slug': 'guidedoc',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 188,
#   'technical_name': 'youtubered',
#   'short_name': 'ytr',
#   'clear_name': 'YouTube Premium',
#   'display_priority': 19,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/70189310/{profile}',
#   'icon_blur_hash': 'KgRx[mof*JrDf6o}*Jj[Q-',
#   'slug': 'youtube-premium',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 393,
#   'technical_name': 'flixole',
#   'short_name': 'flx',
#   'clear_name': 'FlixOlé',
#   'display_priority': 20,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/198144240/{profile}',
#   'icon_blur_hash': 'KaS6DG?It7-;oej[_NNtRj',
#   'slug': 'flixole',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 283,
#   'technical_name': 'crunchyroll',
#   'short_name': 'cru',
#   'clear_name': 'Crunchyroll',
#   'display_priority': 21,
#   'priority': 0,
#   'monetization_types': ['free'],
#   'icon_url': '/icon/127445869/{profile}',
#   'icon_blur_hash': 'KjSD4wozQRn$kCj]UvaKpJ',
#   'slug': 'crunchyroll',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': '',
#     'webos': '',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 190,
#   'technical_name': 'curiositystream',
#   'short_name': 'cts',
#   'clear_name': 'Curiosity Stream',
#   'display_priority': 22,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/48600036/{profile}',
#   'icon_blur_hash': 'KjS#6LoeiHn#fQkCU[f6em',
#   'slug': 'curiosity-stream',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 456,
#   'technical_name': 'mitele',
#   'short_name': 'mte',
#   'clear_name': 'Mitele ',
#   'display_priority': 23,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/202925890/{profile}',
#   'icon_blur_hash': 'KsKBO7oz00R%RjV[00oKxu',
#   'slug': 'mitele',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 457,
#   'technical_name': 'vixtv',
#   'short_name': 'vix',
#   'clear_name': 'VIX ',
#   'display_priority': 24,
#   'priority': 0,
#   'monetization_types': ['ads'],
#   'icon_url': '/icon/202926990/{profile}',
#   'icon_blur_hash': 'KI9QmxayIUofj[ay00j]%M',
#   'slug': 'vix',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 475,
#   'technical_name': 'docsville',
#   'short_name': 'dsv',
#   'clear_name': 'DOCSVILLE',
#   'display_priority': 25,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/208148387/{profile}',
#   'icon_blur_hash': 'KFS=u7xuuPxuj[bHuOaenj',
#   'slug': 'docsville',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 521,
#   'technical_name': 'spamflix',
#   'short_name': 'sfx',
#   'clear_name': 'Spamflix',
#   'display_priority': 101,
#   'priority': 0,
#   'monetization_types': ['rent'],
#   'icon_url': '/icon/240831409/{profile}',
#   'icon_blur_hash': 'KY1hy+fjU[cOfRilbBfPjf',
#   'slug': 'spamflix',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 194,
#   'technical_name': 'amazonstarzplay',
#   'short_name': 'ast',
#   'clear_name': 'Starz Play Amazon Channel',
#   'display_priority': 1003,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/241732487/{profile}',
#   'icon_blur_hash': 'KyHx$%ayWB00j[WB-;ayof',
#   'slug': 'starz-play-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 541,
#   'technical_name': 'rtve',
#   'short_name': 'rtv',
#   'clear_name': 'rtve',
#   'display_priority': 1005,
#   'priority': 0,
#   'monetization_types': ['free'],
#   'icon_url': '/icon/243087006/{profile}',
#   'icon_blur_hash': 'KTSe]X%chyyBkBaJZgfjk?',
#   'slug': 'rtve',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 538,
#   'technical_name': 'plex',
#   'short_name': 'plx',
#   'clear_name': 'Plex',
#   'display_priority': 1006,
#   'priority': 0,
#   'monetization_types': ['free'],
#   'icon_url': '/icon/243059301/{profile}',
#   'icon_blur_hash': 'KJ9tM+o#IUj[j[j[01V?%M',
#   'slug': 'plex',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 546,
#   'technical_name': 'wowpresentsplus',
#   'short_name': 'wow',
#   'clear_name': 'WOW Presents Plus',
#   'display_priority': 1007,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/243229654/{profile}',
#   'icon_blur_hash': 'KZQ?aoxaae^Pjtj[UbaekC',
#   'slug': 'wow-presents-plus',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 551,
#   'technical_name': 'magellantv',
#   'short_name': 'mgl',
#   'clear_name': 'Magellan TV',
#   'display_priority': 1008,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/243233518/{profile}',
#   'icon_blur_hash': 'KF8q?BZ$9Fo}aeae00X9-p',
#   'slug': 'magellan-tv',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 554,
#   'technical_name': 'broadwayhd',
#   'short_name': 'bhd',
#   'clear_name': 'BroadwayHD',
#   'display_priority': 1009,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/243239329/{profile}',
#   'icon_blur_hash': 'KYCAn$tlPnM_baWUQ6RPq^',
#   'slug': 'broadwayhd',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 559,
#   'technical_name': 'filmzie',
#   'short_name': 'fmz',
#   'clear_name': 'Filmzie',
#   'display_priority': 1010,
#   'priority': 0,
#   'monetization_types': ['ads'],
#   'icon_url': '/icon/269433194/{profile}',
#   'icon_blur_hash': 'K43ufijuNHoejtay0Na{xZ',
#   'slug': 'filmzie',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 444,
#   'technical_name': 'dekkoo',
#   'short_name': 'dkk',
#   'clear_name': 'Dekkoo',
#   'display_priority': 1011,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/202068207/{profile}',
#   'icon_blur_hash': 'KHQm0MoM?^{xo0O?.mt7R5',
#   'slug': 'dekkoo',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 567,
#   'technical_name': 'truestory',
#   'short_name': 'trs',
#   'clear_name': 'True Story',
#   'display_priority': 1012,
#   'priority': 0,
#   'monetization_types': ['rent', 'flatrate'],
#   'icon_url': '/icon/244289819/{profile}',
#   'icon_blur_hash': 'K7J[9c~nt7%Moej[tV9JRj',
#   'slug': 'true-story',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 569,
#   'technical_name': 'dafilms',
#   'short_name': 'daf',
#   'clear_name': 'DocAlliance Films',
#   'display_priority': 1013,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/244290074/{profile}',
#   'icon_blur_hash': 'KjI5Y-ay00t7ofay4nt7t7',
#   'slug': 'docalliance-films',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 315,
#   'technical_name': 'hoichoi',
#   'short_name': 'hoc',
#   'clear_name': 'Hoichoi',
#   'display_priority': 1014,
#   'priority': 0,
#   'monetization_types': ['free'],
#   'icon_url': '/icon/141253805/{profile}',
#   'icon_blur_hash': 'KLR%r+=1y@=yniV@v2jFY5',
#   'slug': 'hoichoi',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 10,
#   'technical_name': 'amazon',
#   'short_name': 'amz',
#   'clear_name': 'Amazon Video',
#   'display_priority': 10004,
#   'priority': 0,
#   'monetization_types': ['rent', 'buy'],
#   'icon_url': '/icon/430993/{profile}',
#   'icon_blur_hash': 'KYPG%2-p-;~AIoNHXU%2s+',
#   'slug': 'amazon-video',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 43,
#   'technical_name': 'starz',
#   'short_name': 'stz',
#   'clear_name': 'Starz',
#   'display_priority': 10005,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/902247/{profile}',
#   'icon_blur_hash': 'KC7w.@WBD%xuWBay00WB-:',
#   'slug': 'starz',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': 'enabled'}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 300,
#   'technical_name': 'plutotv',
#   'short_name': 'ptv',
#   'clear_name': 'Pluto TV',
#   'display_priority': 10007,
#   'priority': 0,
#   'monetization_types': ['ads'],
#   'icon_url': '/icon/131862988/{profile}',
#   'icon_blur_hash': 'KMBg3uj[00j[fQ%M4nay-;',
#   'slug': 'pluto-tv',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 524,
#   'technical_name': 'discoverypluseurope',
#   'short_name': 'dpe',
#   'clear_name': 'Discovery Plus',
#   'display_priority': 10009,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/241126382/{profile}',
#   'icon_blur_hash': 'KYDvKBIx4.#RbEOr0Kxm-o',
#   'slug': 'discovery-plus',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': 'enabled',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 677,
#   'technical_name': 'eventive',
#   'short_name': 'eve',
#   'clear_name': 'Eventive',
#   'display_priority': 10010,
#   'priority': 0,
#   'monetization_types': ['rent', 'free'],
#   'icon_url': '/icon/258768419/{profile}',
#   'icon_blur_hash': 'KRB~h^x]03tSR+V]4qM|%K',
#   'slug': 'eventive',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 296,
#   'technical_name': 'amazonhayu',
#   'short_name': 'ahy',
#   'clear_name': 'Hayu Amazon Channel',
#   'display_priority': 10011,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/241732559/{profile}',
#   'icon_blur_hash': 'K#I5MbozRj00ofWB-;WBt7',
#   'slug': 'hayu-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 201,
#   'technical_name': 'amazonmubi',
#   'short_name': 'amu',
#   'clear_name': 'Mubi Amazon Channel',
#   'display_priority': 10012,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/241732473/{profile}',
#   'icon_blur_hash': 'KzGb-]azWB02fRWB?Zayof',
#   'slug': 'mubi-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 607,
#   'technical_name': 'amazonouttv',
#   'short_name': 'aot',
#   'clear_name': 'OUTtv Amazon Channel',
#   'display_priority': 10013,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/248045085/{profile}',
#   'icon_blur_hash': 'KxJR8WodE14ToeNG.8WCxa',
#   'slug': 'outtv-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 196,
#   'technical_name': 'amazonacorntv',
#   'short_name': 'aac',
#   'clear_name': 'AcornTV Amazon Channel',
#   'display_priority': 10014,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/241732555/{profile}',
#   'icon_blur_hash': 'K$GSDmW;ax00fkWB?bayof',
#   'slug': 'acorntv-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 262,
#   'technical_name': 'amazonnoggin',
#   'short_name': 'ang',
#   'clear_name': 'Noggin Amazon Channel',
#   'display_priority': 10015,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/241732611/{profile}',
#   'icon_blur_hash': 'K+F=:paybE00j[WU?aayoN',
#   'slug': 'noggin-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 588,
#   'technical_name': 'amazonmgm',
#   'short_name': 'amg',
#   'clear_name': 'MGM Amazon Channel',
#   'display_priority': 10016,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/246682790/{profile}',
#   'icon_blur_hash': 'KmJ*uAayWB00j[WB%Mayof',
#   'slug': 'mgm-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 684,
#   'technical_name': 'amazonflixole',
#   'short_name': 'afl',
#   'clear_name': 'FlixOlé Amazon Channel',
#   'display_priority': 10017,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/259252096/{profile}',
#   'icon_blur_hash': 'K*HU^IV@ay00jZWB.8kCof',
#   'slug': 'flixole-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': 'enabled',
#     'fire_tv': 'enabled',
#     'tvos': 'enabled',
#     'tizenos': 'enabled',
#     'webos': 'enabled',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': ['prv', 'amp']},
#  {'id': 689,
#   'technical_name': 'amazontvcortos',
#   'short_name': 'atc',
#   'clear_name': 'TVCortos Amazon Channel',
#   'display_priority': 10018,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/260448137/{profile}',
#   'icon_blur_hash': 'K8SPU:%2?H~W%2fR?vIoRj',
#   'slug': 'tvcortos-amazon-channel',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 692,
#   'technical_name': 'cultpix',
#   'short_name': 'ctx',
#   'clear_name': 'Cultpix',
#   'display_priority': 10019,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/264459628/{profile}',
#   'icon_blur_hash': 'KC6$v3oLJQsofQWo1uWV$Q',
#   'slug': 'cultpix',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None},
#  {'id': 701,
#   'technical_name': 'filmbox',
#   'short_name': 'flb',
#   'clear_name': 'FilmBox+',
#   'display_priority': 10020,
#   'priority': 0,
#   'monetization_types': ['flatrate'],
#   'icon_url': '/icon/269959825/{profile}',
#   'icon_blur_hash': 'KmSrQ6pwpcoLaykC*Jm,VY',
#   'slug': 'filmbox',
#   'data': {'deeplink_data': [],
#    'packages': {'android_tv': '',
#     'fire_tv': '',
#     'tvos': '',
#     'tizenos': '',
#     'webos': '',
#     'xbox': ''}},
#   'addon_packages': None,
#   'parent_packages': None}]

# %%
peli_key = 'hotel'
lista_pelis = just_watch.search_for_item(query=peli_key, content_types=['movie'], providers = proveedores, monetization_types=['flatrate'])

# %%
total_list = len(lista_pelis['items'])
total_list
# Out:
# 30

# %%
total_pelis = []
for item in range(total_list):
    total_pelis.append(lista_pelis['items'][item]['id'])
total_pelis
# Out:
# [460828,
#  69164,
#  244157,
#  132278,
#  162843,
#  176016,
#  135121,
#  1031933,
#  244366,
#  128879,
#  138793,
#  372685,
#  823136,
#  96276,
#  232799,
#  181889,
#  243264,
#  267401,
#  855362,
#  65295,
#  224498,
#  218129,
#  49864,
#  142571,
#  57798,
#  138369,
#  137702,
#  370650,
#  172251,
#  47174]

# %%
len(total_pelis)
# Out:
# 30

# %%
extra_info = []
for e in range(len(total_pelis)):
    try:
        peli = just_watch.get_title(title_id=total_pelis[e])
        extra_info.append(peli)
    except:
        extra_info.append('/-----------------------------no info-----------------------------------/')
extra_info
# Out:
# [{'jw_entity_id': 'tm460828',
#   'id': 460828,
#   'title': 'Hotel Transilvania: Transformanía',
#   'full_path': '/es/pelicula/hotel-transilvania-4',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/hotel-transilvania-4'},
#   'poster': '/poster/259379170/{profile}',
#   'poster_blur_hash': 'TEE.w.D91jxwVco}93xvnft*awRV',
#   'backdrops': [{'backdrop_url': '/backdrop/248340077/{profile}',
#     'backdrop_blur_hash': 'L^L4BQ02tTRiR-aybEbZs.WAa#t7'},
#    {'backdrop_url': '/backdrop/259397249/{profile}',
#     'backdrop_blur_hash': 'L9EJ[5QTxYXlXmELTIV@0zTIofRj'},
#    {'backdrop_url': '/backdrop/260257543/{profile}',
#     'backdrop_blur_hash': 'LRCj3NL+GQ#Pv~TJaKadGHa0bWR%'},
#    {'backdrop_url': '/backdrop/247179030/{profile}',
#     'backdrop_blur_hash': 'L2AJJ]Gj0{1EqvH^Q]-D0Lt8$xs;'},
#    {'backdrop_url': '/backdrop/247945759/{profile}',
#     'backdrop_blur_hash': 'LKEV.-DN_1W%sjJER5k;ITnOT1WY'}],
#   'short_description': 'Drac y la pandilla vuelven, como nunca los habías visto antes en Hotel Transilvania: Transformanía. Volveremos a encontrarnos con nuestros monstruos favoritos en una aventura completamente nueva en la que Drac se enfrentará a una de las situaciones más aterradoras vividas hasta el momento. Cuando el misterioso invento de Van Helsing, el "Rayo Monstrificador", se vuelve totalmente fuera de control, Drac y sus monstruosos amigos se transforman en humanos, ¡y Johnny se convierte en un monstruo!',
#   'original_release_year': 2022,
#   'object_type': 'movie',
#   'original_title': 'Hotel Transylvania: Transformania',
#   'localized_release_date': '2022-01-14T00:00:00Z',
#   'offers': [{'jw_entity_id': 'tm460828',
#     'monetization_type': 'flatrate',
#     'provider_id': 119,
#     'package_short_name': 'prv',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.3a1c3b5e-9245-47d7-abc2-3adda85afacf',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.3a1c3b5e-9245-47d7-abc2-3adda85afacf',
#      'deeplink_rokuos': 'launch/13?contentID=B09M89BYZL&MediaType=movie'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm460828',
#     'monetization_type': 'flatrate',
#     'provider_id': 119,
#     'package_short_name': 'prv',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.3a1c3b5e-9245-47d7-abc2-3adda85afacf',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.3a1c3b5e-9245-47d7-abc2-3adda85afacf',
#      'deeplink_rokuos': 'launch/13?contentID=B09M89BYZL&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm460828',
#     'monetization_type': 'flatrate',
#     'provider_id': 119,
#     'package_short_name': 'prv',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.3a1c3b5e-9245-47d7-abc2-3adda85afacf',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.3a1c3b5e-9245-47d7-abc2-3adda85afacf',
#      'deeplink_rokuos': 'launch/13?contentID=B09M89BYZL&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'scoring': [{'provider_type': 'imdb:score', 'value': 6},
#    {'provider_type': 'imdb:votes', 'value': 25853},
#    {'provider_type': 'tmdb:score', 'value': 7.1},
#    {'provider_type': 'imdb:multiplied', 'value': 155118},
#    {'provider_type': 'imdb:popularity', 'value': 366},
#    {'provider_type': 'tmdb:popularity', 'value': 1204.294},
#    {'provider_type': 'tmdb:id', 'value': 585083}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Mavis Dracula (voice)',
#     'person_id': 5144,
#     'name': 'Selena Gomez'},
#    {'role': 'ACTOR',
#     'character_name': 'Johnny Loughran (voice)',
#     'person_id': 5143,
#     'name': 'Andy Samberg'},
#    {'role': 'ACTOR',
#     'character_name': 'Ericka Van Helsing (voice)',
#     'person_id': 2167,
#     'name': 'Kathryn Hahn'},
#    {'role': 'ACTOR',
#     'character_name': 'Van Helsing (voice)',
#     'person_id': 12686,
#     'name': 'Jim Gaffigan'},
#    {'role': 'ACTOR',
#     'character_name': 'Wayne (voice)',
#     'person_id': 5145,
#     'name': 'Steve Buscemi'},
#    {'role': 'ACTOR',
#     'character_name': 'Wanda (voice)',
#     'person_id': 5151,
#     'name': 'Molly Shannon'},
#    {'role': 'ACTOR',
#     'character_name': 'Griffin (voice)',
#     'person_id': 5146,
#     'name': 'David Spade'},
#    {'role': 'ACTOR',
#     'character_name': 'Murray (voice)',
#     'person_id': 2170,
#     'name': 'Keegan-Michael Key'},
#    {'role': 'ACTOR',
#     'character_name': 'Dracula (voice)',
#     'person_id': 234384,
#     'name': 'Brian Hull'},
#    {'role': 'ACTOR',
#     'character_name': 'Eunice (voice)',
#     'person_id': 5148,
#     'name': 'Fran Drescher'},
#    {'role': 'ACTOR',
#     'character_name': 'Frankenstein (voice)',
#     'person_id': 80693,
#     'name': 'Brad Abrell'},
#    {'role': 'ACTOR',
#     'character_name': 'Dennis (voice)',
#     'person_id': 5147,
#     'name': 'Asher Blinkoff'},
#    {'role': 'ACTOR',
#     'character_name': 'Party Monster (voice)',
#     'person_id': 1641748,
#     'name': 'Ninja'},
#    {'role': 'ACTOR',
#     'character_name': 'Winnie (voice)',
#     'person_id': 1286024,
#     'name': 'Zoe Berri'},
#    {'role': 'ACTOR',
#     'character_name': 'Blobby (voice)',
#     'person_id': 5159,
#     'name': 'Genndy Tartakovsky'},
#    {'role': 'ACTOR',
#     'character_name': 'Wesley (voice)',
#     'person_id': 1399754,
#     'name': 'Asher Bishop'},
#    {'role': 'ACTOR',
#     'character_name': 'Wendy (voice)',
#     'person_id': 933302,
#     'name': 'Jennifer Kluska'},
#    {'role': 'ACTOR',
#     'character_name': 'Young Mavis / Wilma (voice)',
#     'person_id': 2208346,
#     'name': 'Victoria Gomez'},
#    {'role': 'ACTOR',
#     'character_name': 'Human Zombie (voice)',
#     'person_id': 81411,
#     'name': 'Derek Drymon'},
#    {'role': 'ACTOR',
#     'character_name': 'Gremlin Pilot / Gremlin Stewardess (voice)',
#     'person_id': 25829,
#     'name': 'Aaron LaPlante'},
#    {'role': 'ACTOR',
#     'character_name': 'Airbag Monster / Phone Voice (voice)',
#     'person_id': 10876,
#     'name': 'Melissa Sturm'},
#    {'role': 'ACTOR',
#     'character_name': 'Female Newscaster (voice)',
#     'person_id': 2208441,
#     'name': 'Chloé Malaisé'},
#    {'role': 'ACTOR',
#     'character_name': 'Male Newscaster (voice)',
#     'person_id': 592185,
#     'name': 'Scott Underwood'},
#    {'role': 'ACTOR',
#     'character_name': 'Witch (voice)',
#     'person_id': 11703,
#     'name': 'Michelle Murdocca'},
#    {'role': 'ACTOR',
#     'character_name': 'Zombie (voice)',
#     'person_id': 729850,
#     'name': 'William Townsend'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 210186,
#     'name': 'David Berón'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 80581,
#     'name': 'Natalia Castellanos'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 1022102,
#     'name': 'Todd Haberkorn'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 5646,
#     'name': 'Jess Harnell'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 857966,
#     'name': 'Marabina Jaimes'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 35190,
#     'name': 'Lex Lang'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 7493,
#     'name': 'Caitlin McKenna-Wilkinson'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 116038,
#     'name': 'David Michie'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 326755,
#     'name': 'Juan Pacheco'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 89993,
#     'name': 'Jacqueline Pinol'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 206286,
#     'name': 'Ben Pronsky'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 2471,
#     'name': 'Michelle Ruff'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 6821,
#     'name': 'Fred Tatasciore'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 97127,
#     'name': 'Amanda Troop'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 58669,
#     'name': 'Debra Wilson'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 14118,
#     'name': 'Michael-Leon Wooley'},
#    {'role': 'CO_PRODUCER', 'person_id': 416311, 'name': 'Ryan Gilleland'},
#    {'role': 'DIRECTOR', 'person_id': 81411, 'name': 'Derek Drymon'},
#    {'role': 'DIRECTOR', 'person_id': 933302, 'name': 'Jennifer Kluska'},
#    {'role': 'EDITOR', 'person_id': 81413, 'name': 'Lynn Hobson'},
#    {'role': 'EXECUTIVE_PRODUCER', 'person_id': 5144, 'name': 'Selena Gomez'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 5159,
#     'name': 'Genndy Tartakovsky'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 11703,
#     'name': 'Michelle Murdocca'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 4010,
#     'name': 'Mark Mothersbaugh'},
#    {'role': 'PRODUCER', 'person_id': 12191, 'name': 'Alice Dewey'},
#    {'role': 'PRODUCTION_DESIGN',
#     'person_id': 868103,
#     'name': 'Richard Daskas'},
#    {'role': 'SCREENPLAY', 'person_id': 613526, 'name': 'Nunzio Randazzo'},
#    {'role': 'SCREENPLAY', 'person_id': 1221967, 'name': 'Amos Vernon'},
#    {'role': 'SCREENPLAY', 'person_id': 5159, 'name': 'Genndy Tartakovsky'}],
#   'external_ids': [{'provider': 'tmdb', 'external_id': '585083'},
#    {'provider': 'eidr', 'external_id': '10.5240/BFF2-2822-0EED-2E87-34F9-P'},
#    {'provider': 'imdb', 'external_id': 'tt9848626'},
#    {'provider': 'imdb_latest', 'external_id': 'tt9848626'},
#    {'provider': 'tmdb_latest', 'external_id': '585083'}],
#   'upcoming': [{'package_id': 119,
#     'release_window_from': '2022-01-14T00:00:00',
#     'release_window_to': '2022-01-14T23:59:59',
#     'release_window_days': 1,
#     'release_type': 'digital'}],
#   'genre_ids': [10, 7, 3, 1, 2, 9, 14, 13],
#   'age_certification': '7',
#   'runtime': 87,
#   'production_countries': ['US'],
#   'permanent_audiences': ['pa:cd84cbfd-3ce4-4a92-a412-abe6b69d8dca']},
#  {'jw_entity_id': 'tm69164',
#   'id': 69164,
#   'title': 'Hotel Transilvania',
#   'full_path': '/es/pelicula/hotel-transilvania',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/hotel-transilvania'},
#   'poster': '/poster/248781262/{profile}',
#   'poster_blur_hash': 'ToEW2it7xu.ToKtRt-RjoKOaWCt6',
#   'backdrops': [{'backdrop_url': '/backdrop/8828104/{profile}',
#     'backdrop_blur_hash': 'LHF4o|57R+IosWJ7M|^i0ys:SLxH'},
#    {'backdrop_url': '/backdrop/8828102/{profile}',
#     'backdrop_blur_hash': 'L7A0OLsiAx0M-nImkYV@0dj]wHXS'},
#    {'backdrop_url': '/backdrop/182812056/{profile}',
#     'backdrop_blur_hash': 'LtD,+dnibvt8*0V@WCkDE,WBn%ae'},
#    {'backdrop_url': '/backdrop/8828105/{profile}',
#     'backdrop_blur_hash': 'LCCF0H}SEL9}}m^jjFE2xtxYNHI;'},
#    {'backdrop_url': '/backdrop/250567411/{profile}',
#     'backdrop_blur_hash': 'L8ASf2It57r]b^$$VsI;0fofxtoy'}],
#   'short_description': 'Drácula regenta un hotel en el que se alojan personajes como Frankenstein, la Momia, el Hombre Invisible, hombres-lobo... El problema del conde es que tiene una hija de espíritu aventurero a la que le resulta difícil controlar. El conflicto surge cuando se aloja en el hotel un ser humano que se siente atraído por la hija del dueño.',
#   'original_release_year': 2012,
#   'object_type': 'movie',
#   'original_title': 'Hotel Transylvania',
#   'offers': [{'jw_entity_id': 'tm69164',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 11.99,
#     'last_change_retail_price': 3.99,
#     'last_change_difference': 8,
#     'last_change_percent': 200.50125,
#     'last_change_date': '2021-08-14',
#     'last_change_date_provider_id': '2021-08-14_2',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/hotel-transilvania/umc.cmc.2h71bi3jo9hf3cwezn38k35gg?playableId=tvs.sbd.9001%3A573267363',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fhotel-transilvania%2Fumc.cmc.2h71bi3jo9hf3cwezn38k35gg%3FplayableId%3Dtvs.sbd.9001%253A573267363&MediaType=movie'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 11.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/hotel-transilvania/umc.cmc.2h71bi3jo9hf3cwezn38k35gg?playableId=tvs.sbd.9001%3A573267363',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fhotel-transilvania%2Fumc.cmc.2h71bi3jo9hf3cwezn38k35gg%3FplayableId%3Dtvs.sbd.9001%253A573267363&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 5.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/hotel-transilvania/umc.cmc.2h71bi3jo9hf3cwezn38k35gg?playableId=tvs.sbd.9001%3A573267363',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fhotel-transilvania%2Fumc.cmc.2h71bi3jo9hf3cwezn38k35gg%3FplayableId%3Dtvs.sbd.9001%253A573267363&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/hotel-transilvania/umc.cmc.2h71bi3jo9hf3cwezn38k35gg?playableId=tvs.sbd.9001%3A573267363',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fhotel-transilvania%2Fumc.cmc.2h71bi3jo9hf3cwezn38k35gg%3FplayableId%3Dtvs.sbd.9001%253A573267363&MediaType=movie'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/hotel-transilvania/umc.cmc.2h71bi3jo9hf3cwezn38k35gg?playableId=tvs.sbd.9001%3A573267363',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fhotel-transilvania%2Fumc.cmc.2h71bi3jo9hf3cwezn38k35gg%3FplayableId%3Dtvs.sbd.9001%253A573267363&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/hotel-transilvania/umc.cmc.2h71bi3jo9hf3cwezn38k35gg?playableId=tvs.sbd.9001%3A573267363',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fhotel-transilvania%2Fumc.cmc.2h71bi3jo9hf3cwezn38k35gg%3FplayableId%3Dtvs.sbd.9001%253A573267363&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'buy',
#     'provider_id': 3,
#     'package_short_name': 'ply',
#     'retail_price': 8.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.google.com/store/movies/details/Hotel_Transilvania_Pel%C3%ADcula_Completa_en_Espa%C3%B1ol?gl=ES&hl=en&id=_39V31ctaAQ'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'buy',
#     'provider_id': 3,
#     'package_short_name': 'ply',
#     'retail_price': 5.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.google.com/store/movies/details/Hotel_Transilvania_Pel%C3%ADcula_Completa_en_Espa%C3%B1ol?gl=ES&hl=en&id=_39V31ctaAQ'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'rent',
#     'provider_id': 3,
#     'package_short_name': 'ply',
#     'retail_price': 2.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.google.com/store/movies/details/Hotel_Transilvania_Pel%C3%ADcula_Completa_en_Espa%C3%B1ol?gl=ES&hl=en&id=_39V31ctaAQ'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'rent',
#     'provider_id': 3,
#     'package_short_name': 'ply',
#     'retail_price': 1.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.google.com/store/movies/details/Hotel_Transilvania_Pel%C3%ADcula_Completa_en_Espa%C3%B1ol?gl=ES&hl=en&id=_39V31ctaAQ'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'flatrate',
#     'provider_id': 8,
#     'package_short_name': 'nfx',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'http://www.netflix.com/title/70220028',
#      'deeplink_web': 'http://www.netflix.com/watch/70220028',
#      'deeplink_rokuos': 'launch/12?contentID=70220028&MediaType=movie'},
#     'available_to': '2023-02-28',
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'flatrate',
#     'provider_id': 8,
#     'package_short_name': 'nfx',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'http://www.netflix.com/title/70220028',
#      'deeplink_web': 'http://www.netflix.com/watch/70220028',
#      'deeplink_rokuos': 'launch/12?contentID=70220028&MediaType=movie'},
#     'available_to': '2023-02-28',
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 8.99,
#     'last_change_retail_price': 11.99,
#     'last_change_difference': -3,
#     'last_change_percent': -25.020851,
#     'last_change_date': '2022-03-06',
#     'last_change_date_provider_id': '2022-03-06_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.ccadf766-d004-ab4e-945a-23c1c6286014',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.ccadf766-d004-ab4e-945a-23c1c6286014',
#      'deeplink_rokuos': 'launch/13?contentID=B071RZ7WGR&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 5.99,
#     'last_change_retail_price': 4.99,
#     'last_change_difference': 1,
#     'last_change_percent': 20.040081,
#     'last_change_date': '2022-01-31',
#     'last_change_date_provider_id': '2022-01-31_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.ccadf766-d004-ab4e-945a-23c1c6286014',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.ccadf766-d004-ab4e-945a-23c1c6286014',
#      'deeplink_rokuos': 'launch/13?contentID=B071RZ7WGR&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'rent',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 2.99,
#     'last_change_retail_price': 3.99,
#     'last_change_difference': -1,
#     'last_change_percent': -25.062656,
#     'last_change_date': '2022-03-06',
#     'last_change_date_provider_id': '2022-03-06_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.ccadf766-d004-ab4e-945a-23c1c6286014',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.ccadf766-d004-ab4e-945a-23c1c6286014',
#      'deeplink_rokuos': 'launch/13?contentID=B071RZ7WGR&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'rent',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 1.99,
#     'last_change_retail_price': 3.99,
#     'last_change_difference': -2,
#     'last_change_percent': -50.125313,
#     'last_change_date': '2022-03-06',
#     'last_change_date_provider_id': '2022-03-06_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.ccadf766-d004-ab4e-945a-23c1c6286014',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.ccadf766-d004-ab4e-945a-23c1c6286014',
#      'deeplink_rokuos': 'launch/13?contentID=B071RZ7WGR&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 14.99,
#     'last_change_retail_price': 13.99,
#     'last_change_difference': 1,
#     'last_change_percent': 7.147963,
#     'last_change_date': '2022-03-04',
#     'last_change_date_provider_id': '2022-03-04_35',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/hotel-transilvania'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 9.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/hotel-transilvania'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 5.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/hotel-transilvania'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 4.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/hotel-transilvania'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/hotel-transilvania'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 2.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/hotel-transilvania'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'buy',
#     'provider_id': 68,
#     'package_short_name': 'msf',
#     'retail_price': 13.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.microsoft.com/es-es/p/hotel-transilvania/8d6kgwzl5sl5'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'buy',
#     'provider_id': 68,
#     'package_short_name': 'msf',
#     'retail_price': 12.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.microsoft.com/es-es/p/hotel-transilvania/8d6kgwzl5sl5'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'rent',
#     'provider_id': 68,
#     'package_short_name': 'msf',
#     'retail_price': 2.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.microsoft.com/es-es/p/hotel-transilvania/8d6kgwzl5sl5'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm69164',
#     'monetization_type': 'rent',
#     'provider_id': 68,
#     'package_short_name': 'msf',
#     'retail_price': 1.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.microsoft.com/es-es/p/hotel-transilvania/8d6kgwzl5sl5'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'clips': [{'type': 'trailer',
#     'provider': 'youtube',
#     'external_id': 'HRvfDRPxTIg',
#     'name': 'Hotel Transilvania: Transformanía - Tráiler oficial EN ESPAÑOL | Sony Pictures España'},
#    {'type': 'trailer',
#     'provider': 'youtube',
#     'external_id': 'YdnUwyxSRgw',
#     'name': 'Hotel Transylvania - Trailer en español'},
#    {'type': 'trailer',
#     'provider': 'youtube',
#     'external_id': 'mZ7wb2SmDMI',
#     'name': 'HOTEL TRANSILVANIA - Tráiler en ESPAÑOL | Sony Pictures España'},
#    {'type': 'trailer',
#     'provider': 'youtube',
#     'external_id': 'qqUQJKVDq9A',
#     'name': 'HOTEL TRANSILVANIA - Tráiler Oficial en ESPAÑOL | Sony Pictures España'},
#    {'type': 'trailer',
#     'provider': 'youtube',
#     'external_id': 'AmTFjiuxgc4',
#     'name': 'HOTEL TRANSILVANIA - Tráiler Oficial en ESPAÑOL | Sony Pictures España'},
#    {'type': 'trailer',
#     'provider': 'youtube',
#     'external_id': '4MjJa_cQIgo',
#     'name': 'Hotel Transylvania - Tráiler B doblado'}],
#   'scoring': [{'provider_type': 'imdb:multiplied', 'value': 1739899},
#    {'provider_type': 'imdb:popularity', 'value': 1382},
#    {'provider_type': 'tmdb:popularity', 'value': 79.272},
#    {'provider_type': 'tmdb:id', 'value': 76492},
#    {'provider_type': 'imdb:score', 'value': 7},
#    {'provider_type': 'imdb:votes', 'value': 248557},
#    {'provider_type': 'tmdb:score', 'value': 7}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Count Dracula (voice)',
#     'person_id': 2317,
#     'name': 'Adam Sandler'},
#    {'role': 'ACTOR',
#     'character_name': 'Jonathan Loughran (voice)',
#     'person_id': 5143,
#     'name': 'Andy Samberg'},
#    {'role': 'ACTOR',
#     'character_name': 'Mavis Dracula (voice)',
#     'person_id': 5144,
#     'name': 'Selena Gomez'},
#    {'role': 'ACTOR',
#     'character_name': 'Frankenstein (voice)',
#     'person_id': 2322,
#     'name': 'Kevin James'},
#    {'role': 'ACTOR',
#     'character_name': 'Eunice (voice)',
#     'person_id': 5148,
#     'name': 'Fran Drescher'},
#    {'role': 'ACTOR',
#     'character_name': 'Wayne (voice)',
#     'person_id': 5145,
#     'name': 'Steve Buscemi'},
#    {'role': 'ACTOR',
#     'character_name': 'Wanda (voice)',
#     'person_id': 5151,
#     'name': 'Molly Shannon'},
#    {'role': 'ACTOR',
#     'character_name': 'Griffin (voice)',
#     'person_id': 5146,
#     'name': 'David Spade'},
#    {'role': 'ACTOR',
#     'character_name': 'Murray the Mummy (voice)',
#     'person_id': 64520,
#     'name': 'Cee Lo Green'},
#    {'role': 'ACTOR',
#     'character_name': 'Young Mavis / Winnie (voice)',
#     'person_id': 2350,
#     'name': 'Sadie Sandler'},
#    {'role': 'ACTOR',
#     'character_name': 'Quasimodo Wilson (voice)',
#     'person_id': 5158,
#     'name': 'Jon Lovitz'},
#    {'role': 'ACTOR',
#     'character_name': 'Shrunken Head (voice)',
#     'person_id': 31873,
#     'name': 'Luenell'},
#    {'role': 'ACTOR',
#     'character_name': 'Mr. Fly (voice)',
#     'person_id': 8707,
#     'name': 'Chris Parnell'},
#    {'role': 'ACTOR',
#     'character_name': 'Suit of Animated Armor (voice)',
#     'person_id': 27095,
#     'name': 'Brian George'},
#    {'role': 'ACTOR',
#     'character_name': 'Pilot (voice)',
#     'person_id': 78433,
#     'name': 'Brian Stack'},
#    {'role': 'ACTOR',
#     'character_name': 'Martha (voice)',
#     'person_id': 2327,
#     'name': 'Jackie Sandler'},
#    {'role': 'ACTOR',
#     'character_name': 'Skeleton Husband (voice)',
#     'person_id': 5153,
#     'name': 'Rob Riggle'},
#    {'role': 'ACTOR',
#     'character_name': 'Zombie Pulmber / Hydra Head (voice)',
#     'person_id': 78434,
#     'name': 'Paul Brittain'},
#    {'role': 'ACTOR',
#     'character_name': 'Fake Dracula / Marty (voice)',
#     'person_id': 2330,
#     'name': 'Robert Smigel'},
#    {'role': 'ACTOR',
#     'character_name': 'Gremlin Man / Hydra Head (voice)',
#     'person_id': 5155,
#     'name': 'Jonny Solomon'},
#    {'role': 'ACTOR',
#     'character_name': 'Shrunken Head / Hydra Head (voice)',
#     'person_id': 78436,
#     'name': 'Jim Wise'},
#    {'role': 'ACTOR',
#     'character_name': 'Guy / Hydra Head (voice)',
#     'person_id': 81510,
#     'name': 'Craig Kellman'},
#    {'role': 'ACTOR',
#     'character_name': 'Hairy Monster / Hydra  Head(voice)',
#     'person_id': 78435,
#     'name': 'Brian McCann'},
#    {'role': 'ACTOR',
#     'character_name': 'Foreman (voice)',
#     'person_id': 78437,
#     'name': 'James C.J. Williams'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 319959,
#     'name': 'Ashley Lambert'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 8535,
#     'name': 'Rose Abdoo'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 47378,
#     'name': 'Kirk Baily'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 4894,
#     'name': 'Ranjani Brow'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 19829,
#     'name': 'Corey Burton'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 405,
#     'name': 'Cam Clarke'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 182272,
#     'name': 'Michael Corbett'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 2345,
#     'name': 'Allen Covert'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 190972,
#     'name': 'Rachel Crane'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 125788,
#     'name': 'Collin Dean'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 80697,
#     'name': 'Eddie Frierson'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 6803,
#     'name': 'Bridget Hoffman'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 92133,
#     'name': 'Rif Hutton'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 12050,
#     'name': 'Tom Kenny'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 4895,
#     'name': 'Scott Menville'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 375355,
#     'name': 'Edie Mirman'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 244,
#     'name': 'Jessica Pennington'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 1231535,
#     'name': 'Alec Rosenthal'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 6819,
#     'name': 'Katie Silverman'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 4902,
#     'name': 'John Hans Tester'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 98836,
#     'name': 'Sarah Thyre'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 120657,
#     'name': 'Chris Titone'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice)',
#     'person_id': 40024,
#     'name': 'David Zyler'},
#    {'role': 'ACTOR',
#     'character_name': 'Additional Voices (voice) (uncredited)',
#     'person_id': 12791,
#     'name': 'Maddie Taylor'},
#    {'role': 'CO_PRODUCER', 'person_id': 14156, 'name': 'Lydia Bottegoni'},
#    {'role': 'DIRECTOR', 'person_id': 5159, 'name': 'Genndy Tartakovsky'},
#    {'role': 'EDITOR', 'person_id': 1194889, 'name': 'Catherine Apple'},
#    {'role': 'EXECUTIVE_PRODUCER', 'person_id': 2345, 'name': 'Allen Covert'},
#    {'role': 'EXECUTIVE_PRODUCER', 'person_id': 2330, 'name': 'Robert Smigel'},
#    {'role': 'EXECUTIVE_PRODUCER', 'person_id': 2317, 'name': 'Adam Sandler'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 4010,
#     'name': 'Mark Mothersbaugh'},
#    {'role': 'PRODUCER', 'person_id': 11703, 'name': 'Michelle Murdocca'},
#    {'role': 'SCREENPLAY', 'person_id': 31208, 'name': 'Peter Baynham'},
#    {'role': 'SCREENPLAY', 'person_id': 2330, 'name': 'Robert Smigel'},
#    {'role': 'SONGS', 'person_id': 64013, 'name': 'Becky G'},
#    {'role': 'SONGS', 'person_id': 8986, 'name': 'Will.i.am'}],
#   'external_ids': [{'provider': 'tmdb_latest', 'external_id': '76492'},
#    {'provider': 'tmdb', 'external_id': '76492'},
#    {'provider': 'gowatchit', 'external_id': '264531'},
#    {'provider': 'tms', 'external_id': 'MV003904140000'},
#    {'provider': 'imdb', 'external_id': 'tt0837562'},
#    {'provider': 'eidr', 'external_id': '10.5240/309C-5691-E3CF-8294-6F5E-2'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0837562'},
#    {'provider': 'rovi', 'external_id': '302378'},
#    {'provider': 'iva', 'external_id': '912789'}],
#   'genre_ids': [7, 13, 2, 3, 10, 9],
#   'age_certification': 'APTA',
#   'runtime': 91,
#   'production_countries': ['US'],
#   'permanent_audiences': ['pa:cd84cbfd-3ce4-4a92-a412-abe6b69d8dca']},
#  {'jw_entity_id': 'tm244157',
#   'id': 244157,
#   'title': 'Hotel Transilvania 3: Unas vacaciones monstruosas',
#   'full_path': '/es/pelicula/hotel-transylvania-3',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/hotel-transylvania-3'},
#   'poster': '/poster/127021459/{profile}',
#   'poster_blur_hash': 'TbIhphNztm1QXTNHXoj^skI?bHnP',
#   'backdrops': [{'backdrop_url': '/backdrop/56424832/{profile}',
#     'backdrop_blur_hash': 'LECr+oRB0}NGrho?WFo#E1w4o{ov'},
#    {'backdrop_url': '/backdrop/56424829/{profile}',
#     'backdrop_blur_hash': 'LJFhn@I99Z~CDixvkWM{9]IqenS5'},
#    {'backdrop_url': '/backdrop/56424830/{profile}',
#     'backdrop_blur_hash': 'LJCiB~O@Q+Rj^-OZR3jEJ7W=IoM{'},
#    {'backdrop_url': '/backdrop/56424790/{profile}',
#     'backdrop_blur_hash': 'LKCF#V#$E2NecunMRkWYETNFslt7'},
#    {'backdrop_url': '/backdrop/34342188/{profile}',
#     'backdrop_blur_hash': 'LDCj3AImDPIp.ls?4m%20dN?IqX4'}],
#   'short_description': 'Nuestra familia de monstruos favorita se embarca en un crucero de lujo para que por fin Drac pueda tomarse un descanso de proveer de vacaciones al resto en el hotel. Es una navegación tranquila para la pandilla de Drac, ya que los monstruos se entregan a toda la diversión a bordo que ofrece el crucero, desde el voleibol de monstruos y las excursiones exóticas, a ponerse al día con sus bronceados de luna. Pero las vacaciones de ensueño se convierten en una pesadilla cuando Mavis se da cuenta de que Drac se ha enamorado de la misteriosa capitana de la nave, Ericka, quien esconde un peligroso secreto que podría destruir a todos los monstruos.',
#   'original_release_year': 2018,
#   'object_type': 'movie',
#   'original_title': 'Hotel Transylvania 3: Summer Vacation',
#   'offers': [{'jw_entity_id': 'tm244157',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 11.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/hotel-transilvania-3-unas-vacaciones-monstruosas/umc.cmc.6z4lexpy9dmleds7i1vxvxnec?playableId=tvs.sbd.9001%3A1400554510',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fhotel-transilvania-3-unas-vacaciones-monstruosas%2Fumc.cmc.6z4lexpy9dmleds7i1vxvxnec%3FplayableId%3Dtvs.sbd.9001%253A1400554510&MediaType=movie'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 11.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/hotel-transilvania-3-unas-vacaciones-monstruosas/umc.cmc.6z4lexpy9dmleds7i1vxvxnec?playableId=tvs.sbd.9001%3A1400554510',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fhotel-transilvania-3-unas-vacaciones-monstruosas%2Fumc.cmc.6z4lexpy9dmleds7i1vxvxnec%3FplayableId%3Dtvs.sbd.9001%253A1400554510&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 5.99,
#     'last_change_retail_price': 7.99,
#     'last_change_difference': -2,
#     'last_change_percent': -25.03129,
#     'last_change_date': '2020-11-07',
#     'last_change_date_provider_id': '2020-11-07_2',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/hotel-transilvania-3-unas-vacaciones-monstruosas/umc.cmc.6z4lexpy9dmleds7i1vxvxnec?playableId=tvs.sbd.9001%3A1400554510',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fhotel-transilvania-3-unas-vacaciones-monstruosas%2Fumc.cmc.6z4lexpy9dmleds7i1vxvxnec%3FplayableId%3Dtvs.sbd.9001%253A1400554510&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/hotel-transilvania-3-unas-vacaciones-monstruosas/umc.cmc.6z4lexpy9dmleds7i1vxvxnec?playableId=tvs.sbd.9001%3A1400554510',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fhotel-transilvania-3-unas-vacaciones-monstruosas%2Fumc.cmc.6z4lexpy9dmleds7i1vxvxnec%3FplayableId%3Dtvs.sbd.9001%253A1400554510&MediaType=movie'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/hotel-transilvania-3-unas-vacaciones-monstruosas/umc.cmc.6z4lexpy9dmleds7i1vxvxnec?playableId=tvs.sbd.9001%3A1400554510',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fhotel-transilvania-3-unas-vacaciones-monstruosas%2Fumc.cmc.6z4lexpy9dmleds7i1vxvxnec%3FplayableId%3Dtvs.sbd.9001%253A1400554510&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/hotel-transilvania-3-unas-vacaciones-monstruosas/umc.cmc.6z4lexpy9dmleds7i1vxvxnec?playableId=tvs.sbd.9001%3A1400554510',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fhotel-transilvania-3-unas-vacaciones-monstruosas%2Fumc.cmc.6z4lexpy9dmleds7i1vxvxnec%3FplayableId%3Dtvs.sbd.9001%253A1400554510&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'buy',
#     'provider_id': 3,
#     'package_short_name': 'ply',
#     'retail_price': 8.99,
#     'last_change_retail_price': 6.99,
#     'last_change_difference': 2,
#     'last_change_percent': 28.612303,
#     'last_change_date': '2021-07-02',
#     'last_change_date_provider_id': '2021-07-02_3',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.google.com/store/movies/details/Hotel_Transilvania_3_Unas_Vacaciones_Monstruosas?gl=ES&hl=en&id=FC0NCdosjxU'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'buy',
#     'provider_id': 3,
#     'package_short_name': 'ply',
#     'retail_price': 5.99,
#     'last_change_retail_price': 4.99,
#     'last_change_difference': 1,
#     'last_change_percent': 20.040081,
#     'last_change_date': '2022-02-13',
#     'last_change_date_provider_id': '2022-02-13_3',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.google.com/store/movies/details/Hotel_Transilvania_3_Unas_Vacaciones_Monstruosas?gl=ES&hl=en&id=FC0NCdosjxU'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'rent',
#     'provider_id': 3,
#     'package_short_name': 'ply',
#     'retail_price': 2.99,
#     'last_change_retail_price': 1.99,
#     'last_change_difference': 1,
#     'last_change_percent': 50.251255,
#     'last_change_date': '2022-02-13',
#     'last_change_date_provider_id': '2022-02-13_3',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.google.com/store/movies/details/Hotel_Transilvania_3_Unas_Vacaciones_Monstruosas?gl=ES&hl=en&id=FC0NCdosjxU'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'rent',
#     'provider_id': 3,
#     'package_short_name': 'ply',
#     'retail_price': 1.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://play.google.com/store/movies/details/Hotel_Transilvania_3_Unas_Vacaciones_Monstruosas?gl=ES&hl=en&id=FC0NCdosjxU'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'flatrate',
#     'provider_id': 8,
#     'package_short_name': 'nfx',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'http://www.netflix.com/title/80233925',
#      'deeplink_web': 'http://www.netflix.com/watch/80233925',
#      'deeplink_rokuos': 'launch/12?contentID=80233925&MediaType=movie'},
#     'available_to': '2022-11-06',
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'flatrate',
#     'provider_id': 8,
#     'package_short_name': 'nfx',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'http://www.netflix.com/title/80233925',
#      'deeplink_web': 'http://www.netflix.com/watch/80233925',
#      'deeplink_rokuos': 'launch/12?contentID=80233925&MediaType=movie'},
#     'available_to': '2022-11-06',
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'flatrate',
#     'provider_id': 8,
#     'package_short_name': 'nfx',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'http://www.netflix.com/title/80233925',
#      'deeplink_web': 'http://www.netflix.com/watch/80233925',
#      'deeplink_rokuos': 'launch/12?contentID=80233925&MediaType=movie'},
#     'available_to': '2022-11-06',
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 8.99,
#     'last_change_retail_price': 10.99,
#     'last_change_difference': -2,
#     'last_change_percent': -18.198362,
#     'last_change_date': '2022-03-09',
#     'last_change_date_provider_id': '2022-03-09_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.9ab5188b-c707-ec80-2b34-be2d35222ad1',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.9ab5188b-c707-ec80-2b34-be2d35222ad1',
#      'deeplink_rokuos': 'launch/13?contentID=B07QX1Y1QR&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'buy',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 5.99,
#     'last_change_retail_price': 7.99,
#     'last_change_difference': -2,
#     'last_change_percent': -25.03129,
#     'last_change_date': '2022-03-09',
#     'last_change_date_provider_id': '2022-03-09_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.9ab5188b-c707-ec80-2b34-be2d35222ad1',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.9ab5188b-c707-ec80-2b34-be2d35222ad1',
#      'deeplink_rokuos': 'launch/13?contentID=B07QX1Y1QR&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'rent',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 2.99,
#     'last_change_retail_price': 3.99,
#     'last_change_difference': -1,
#     'last_change_percent': -25.062656,
#     'last_change_date': '2022-03-09',
#     'last_change_date_provider_id': '2022-03-09_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.9ab5188b-c707-ec80-2b34-be2d35222ad1',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.9ab5188b-c707-ec80-2b34-be2d35222ad1',
#      'deeplink_rokuos': 'launch/13?contentID=B07QX1Y1QR&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'rent',
#     'provider_id': 10,
#     'package_short_name': 'amz',
#     'retail_price': 1.99,
#     'last_change_retail_price': 3.99,
#     'last_change_difference': -2,
#     'last_change_percent': -50.125313,
#     'last_change_date': '2022-03-09',
#     'last_change_date_provider_id': '2022-03-09_10',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.9ab5188b-c707-ec80-2b34-be2d35222ad1',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.9ab5188b-c707-ec80-2b34-be2d35222ad1',
#      'deeplink_rokuos': 'launch/13?contentID=B07QX1Y1QR&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 14.99,
#     'last_change_retail_price': 13.99,
#     'last_change_difference': 1,
#     'last_change_percent': 7.147963,
#     'last_change_date': '2022-03-04',
#     'last_change_date_provider_id': '2022-03-04_35',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/hotel-transilvania-3-unas-vacaciones-monstruosas'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 9.99,
#     'last_change_retail_price': 5.99,
#     'last_change_difference': 4,
#     'last_change_percent': 66.77796,
#     'last_change_date': '2021-07-26',
#     'last_change_date_provider_id': '2021-07-26_35',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/hotel-transilvania-3-unas-vacaciones-monstruosas'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 5.99,
#     'last_change_retail_price': 4.99,
#     'last_change_difference': 1,
#     'last_change_percent': 20.040081,
#     'last_change_date': '2021-07-26',
#     'last_change_date_provider_id': '2021-07-26_35',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/hotel-transilvania-3-unas-vacaciones-monstruosas'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 4.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/hotel-transilvania-3-unas-vacaciones-monstruosas'},
#     'presentation_type': '4k',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 3.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/hotel-transilvania-3-unas-vacaciones-monstruosas'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 2.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/hotel-transilvania-3-unas-vacaciones-monstruosas'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'buy',
#     'provider_id': 68,
#     'package_short_name': 'msf',
#     'retail_price': 13.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.microsoft.com/es-es/p/hotel-transilvania-3-unas-vacaciones-monstruosas/8d6kgwxn27cs'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm244157',
#     'monetization_type': 'buy',
# ...
#     'character_name': 'Bonded Warehouse Clerk #2',
#     'person_id': 508760,
#     'name': 'Douglas Warhit'},
#    {'role': 'ACTOR',
#     'character_name': 'Holdup Man #1',
#     'person_id': 24200,
#     'name': 'Paul Drake'},
#    {'role': 'ACTOR',
#     'character_name': 'Holdup Man #2',
#     'person_id': 10483,
#     'name': 'Tom Everett'},
#    {'role': 'ACTOR',
#     'character_name': 'Waitress',
#     'person_id': 1801898,
#     'name': 'Sally Kishbaugh'},
#    {'role': 'ACTOR',
#     'character_name': 'Valet',
#     'person_id': 1802347,
#     'name': 'Barry Shade'},
#    {'role': 'ACTOR',
#     'character_name': "Harrow Club Maitre D'",
#     'person_id': 242014,
#     'name': 'Jack Heller'},
#    {'role': 'ACTOR',
#     'character_name': 'Harrow Club Arresting Officer',
#     'person_id': 657355,
#     'name': 'Michael Harrington'},
#    {'role': 'ACTOR',
#     'character_name': 'Dispatcher',
#     'person_id': 10454,
#     'name': 'David Wells'},
#    {'role': 'ACTOR',
#     'character_name': '2nd Detroit Cop',
#     'person_id': 126847,
#     'name': 'John Achorn'},
#    {'role': 'ACTOR',
#     'character_name': '3rd Detroit Cop',
#     'person_id': 1802297,
#     'name': 'John Pettis'},
#    {'role': 'ACTOR',
#     'character_name': 'Detroit Station Cop #1',
#     'person_id': 475303,
#     'name': 'Nicholas Shields'},
#    {'role': 'ACTOR',
#     'character_name': 'Detroit Station Cop #2',
#     'person_id': 89685,
#     'name': 'Carl Weintraub'},
#    {'role': 'ACTOR',
#     'character_name': 'Detroit Station Cop #3',
#     'person_id': 1802417,
#     'name': 'Anthony De Fonte'},
#    {'role': 'ACTOR',
#     'character_name': 'Barmaid',
#     'person_id': 466034,
#     'name': 'Darwyn Carson'},
#    {'role': 'ACTOR',
#     'character_name': 'Pool Player',
#     'person_id': 1802007,
#     'name': 'Mark E. Corry'},
#    {'role': 'ACTOR',
#     'character_name': 'Maitland Bodyguard',
#     'person_id': 1310073,
#     'name': 'Thomas J. Hageboeck'},
#    {'role': 'DIRECTOR', 'person_id': 14252, 'name': 'Martin Brest'},
#    {'role': 'EDITOR', 'person_id': 16313, 'name': 'Billy Weber'},
#    {'role': 'EDITOR', 'person_id': 9043, 'name': 'Arthur Coburn'},
#    {'role': 'EXECUTIVE_PRODUCER', 'person_id': 125627, 'name': 'Mike Moder'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 80263,
#     'name': 'Keith Forsey'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 16312,
#     'name': 'Harold Faltermeyer'},
#    {'role': 'PRODUCER', 'person_id': 3448, 'name': 'Jerry Bruckheimer'},
#    {'role': 'PRODUCER', 'person_id': 16311, 'name': 'Don Simpson'},
#    {'role': 'PRODUCTION_DESIGN',
#     'person_id': 7667,
#     'name': 'Angelo P. Graham'},
#    {'role': 'SCREENPLAY', 'person_id': 70807, 'name': 'Daniel Petrie Jr.'}],
#   'external_ids': [{'provider': 'iva', 'external_id': '917'},
#    {'provider': 'tmdb_latest', 'external_id': '90'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0086960'},
#    {'provider': 'rovi', 'external_id': '982878477'},
#    {'provider': 'gowatchit', 'external_id': '45904'},
#    {'provider': 'eidr', 'external_id': '10.5240/6408-C6F7-D980-83D7-AB41-7'},
#    {'provider': 'tmdb', 'external_id': '90'},
#    {'provider': 'tms', 'external_id': 'MV000186590000'},
#    {'provider': 'imdb', 'external_id': 'tt0086960'}],
#   'genre_ids': [3, 4, 12, 1],
#   'age_certification': '12',
#   'runtime': 105,
#   'production_countries': ['US'],
#   'permanent_audiences': ['pa:b6d69ea4-b214-4a39-b42e-4c033b850d77']},
#  {'jw_entity_id': 'tm47174',
#   'id': 47174,
#   'title': 'La novena puerta',
#   'full_path': '/es/pelicula/la-novena-puerta',
#   'full_paths': {'MOVIE_DETAIL_OVERVIEW': '/es/pelicula/la-novena-puerta'},
#   'poster': '/poster/252088882/{profile}',
#   'poster_blur_hash': 'TGA9.+R+0gnNRkNdEMjZ-UI@xt$%',
#   'backdrops': [{'backdrop_url': '/backdrop/239594824/{profile}',
#     'backdrop_blur_hash': 'LKEe0*AD0$n-nQ5S?F=^9[aJ#lI@'},
#    {'backdrop_url': '/backdrop/199999623/{profile}',
#     'backdrop_blur_hash': 'L9Bp2,p09ZSt%%NO9to?14-WxZNX'},
#    {'backdrop_url': '/backdrop/199999622/{profile}',
#     'backdrop_blur_hash': 'L88:V5RQ0#=yxaNHRkxaX8snoLNH'},
#    {'backdrop_url': '/backdrop/176474377/{profile}',
#     'backdrop_blur_hash': 'LNE1y-5R0#jKi|9v={=^F0s,$gNd'},
#    {'backdrop_url': '/backdrop/39243558/{profile}',
#     'backdrop_blur_hash': 'LG83twxZ0#E3j[oeazR*9vR+-U$%'}],
#   'short_description': 'Dean Corso (Johnny Depp) trabaja de forma confidencial, con sumo cuidado, dotado de una sólida cultura, nervios de acero y pocos escrúpulos. Su reputación le ha servido para recibir la llamada de Boris Balkan (Frank Langella), un apasionado de los textos demoníacos que quiere encontrar los dos últimos libros del legendario manual de invocación satánica De umbrarum regni novem portis: Las nueve puertas del Reino de las Sombras. De Nueva York a Toledo y de París a Sintra, Corso se verá inmerso en un laberinto lleno de peligro, tentaciones, aterradoras sorpresas, violencia y muertes inesperadas.',
#   'original_release_year': 1999,
#   'object_type': 'movie',
#   'original_title': 'The Ninth Gate',
#   'offers': [{'jw_entity_id': 'tm47174',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 6.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/la-novena-puerta/umc.cmc.95h9hxga7cy1xmsp9ss13fy6?playableId=tvs.sbd.9001%3A1175755522',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fla-novena-puerta%2Fumc.cmc.95h9hxga7cy1xmsp9ss13fy6%3FplayableId%3Dtvs.sbd.9001%253A1175755522&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'buy',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 5.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/la-novena-puerta/umc.cmc.95h9hxga7cy1xmsp9ss13fy6?playableId=tvs.sbd.9001%3A1175755522',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fla-novena-puerta%2Fumc.cmc.95h9hxga7cy1xmsp9ss13fy6%3FplayableId%3Dtvs.sbd.9001%253A1175755522&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 2.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/la-novena-puerta/umc.cmc.95h9hxga7cy1xmsp9ss13fy6?playableId=tvs.sbd.9001%3A1175755522',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fla-novena-puerta%2Fumc.cmc.95h9hxga7cy1xmsp9ss13fy6%3FplayableId%3Dtvs.sbd.9001%253A1175755522&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'rent',
#     'provider_id': 2,
#     'package_short_name': 'itu',
#     'retail_price': 2.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://tv.apple.com/es/movie/la-novena-puerta/umc.cmc.95h9hxga7cy1xmsp9ss13fy6?playableId=tvs.sbd.9001%3A1175755522',
#      'deeplink_rokuos': 'launch/551012?contentID=https%3A%2F%2Ftv.apple.com%2Fes%2Fmovie%2Fla-novena-puerta%2Fumc.cmc.95h9hxga7cy1xmsp9ss13fy6%3FplayableId%3Dtvs.sbd.9001%253A1175755522&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'buy',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 7.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/la-novena-puerta'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'rent',
#     'provider_id': 35,
#     'package_short_name': 'wki',
#     'retail_price': 1.99,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://rakuten.tv/es/movies/la-novena-puerta'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'flatrate',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/la-novena-puerta'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'rent',
#     'provider_id': 63,
#     'package_short_name': 'fil',
#     'retail_price': 1.95,
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://www.filmin.es/pelicula/la-novena-puerta'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'flatrate',
#     'provider_id': 119,
#     'package_short_name': 'prv',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.815bf0fb-920d-4bdf-80d5-58d5540929b6',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.815bf0fb-920d-4bdf-80d5-58d5540929b6',
#      'deeplink_rokuos': 'launch/13?contentID=B09KKFWJMY&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'flatrate',
#     'provider_id': 119,
#     'package_short_name': 'prv',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.815bf0fb-920d-4bdf-80d5-58d5540929b6',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.815bf0fb-920d-4bdf-80d5-58d5540929b6',
#      'deeplink_rokuos': 'launch/13?contentID=B09KKFWJMY&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'flatrate',
#     'provider_id': 393,
#     'package_short_name': 'flx',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://ver.flixole.com/watch/da0cdb76-d4b3-4f2b-9185-79986cad00e2'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'flatrate',
#     'provider_id': 393,
#     'package_short_name': 'flx',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://ver.flixole.com/watch/da0cdb76-d4b3-4f2b-9185-79986cad00e2'},
#     'presentation_type': 'sd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'flatrate',
#     'provider_id': 684,
#     'package_short_name': 'afl',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.94b3186a-f203-1e66-cff3-28136e35c898',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.94b3186a-f203-1e66-cff3-28136e35c898',
#      'deeplink_rokuos': 'launch/13?contentID=B07HXP11SM&MediaType=movie'},
#     'presentation_type': 'hd',
#     'country': 'ES'},
#    {'jw_entity_id': 'tm47174',
#     'monetization_type': 'flatrate',
#     'provider_id': 684,
#     'package_short_name': 'afl',
#     'currency': 'EUR',
#     'urls': {'standard_web': 'https://app.primevideo.com/detail?gti=amzn1.dv.gti.94b3186a-f203-1e66-cff3-28136e35c898',
#      'deeplink_web': 'https://app.primevideo.com/watch?gti=amzn1.dv.gti.94b3186a-f203-1e66-cff3-28136e35c898',
#      'deeplink_rokuos': 'launch/13?contentID=B07HXP11SM&MediaType=movie'},
#     'presentation_type': 'sd',
#     'country': 'ES'}],
#   'clips': [{'type': 'trailer',
#     'provider': 'youtube',
#     'external_id': '6QdBiSIgtg4',
#     'name': 'La Novena Puerta (Trailer español)'}],
#   'scoring': [{'provider_type': 'tmdb:id', 'value': 622},
#    {'provider_type': 'imdb:score', 'value': 6.7},
#    {'provider_type': 'imdb:votes', 'value': 178735},
#    {'provider_type': 'tmdb:score', 'value': 6.4},
#    {'provider_type': 'imdb:multiplied', 'value': 1197524.5},
#    {'provider_type': 'imdb:popularity', 'value': 2490},
#    {'provider_type': 'tmdb:popularity', 'value': 23.409}],
#   'credits': [{'role': 'ACTOR',
#     'character_name': 'Dean Corso',
#     'person_id': 3381,
#     'name': 'Johnny Depp'},
#    {'role': 'ACTOR',
#     'character_name': 'Boris Balkan',
#     'person_id': 9059,
#     'name': 'Frank Langella'},
#    {'role': 'ACTOR',
#     'character_name': 'Liana Telfer',
#     'person_id': 21537,
#     'name': 'Lena Olin'},
#    {'role': 'ACTOR',
#     'character_name': 'The Girl',
#     'person_id': 24070,
#     'name': 'Emmanuelle Seigner'},
#    {'role': 'ACTOR',
#     'character_name': 'Baroness Kessler',
#     'person_id': 24072,
#     'name': 'Barbara Jefford'},
#    {'role': 'ACTOR',
#     'character_name': 'Victor Fargas',
#     'person_id': 24071,
#     'name': 'Jack Taylor'},
#    {'role': 'ACTOR',
#     'character_name': 'Pablo & Pedro Ceniza/1st & 2nd Workmen',
#     'person_id': 22288,
#     'name': 'José López Rodero'},
#    {'role': 'ACTOR',
#     'character_name': 'Bernie',
#     'person_id': 5750,
#     'name': 'James Russo'},
#    {'role': 'ACTOR',
#     'character_name': 'Andrew Telfer',
#     'person_id': 24073,
#     'name': 'Willy Holt'},
#    {'role': 'ACTOR',
#     'character_name': 'Witkin',
#     'person_id': 16310,
#     'name': 'Allen Garfield'},
#    {'role': 'ACTOR',
#     'character_name': "Liana's Bodyguard",
#     'person_id': 24074,
#     'name': 'Tony Amoni'},
#    {'role': 'ACTOR',
#     'character_name': 'Old Man',
#     'person_id': 24075,
#     'name': 'Jacques Dacqmine'},
#    {'role': 'ACTOR',
#     'character_name': "Old Man's Son",
#     'person_id': 24077,
#     'name': 'Joe Sheridan'},
#    {'role': 'ACTOR',
#     'character_name': 'Daughter-In-Law',
#     'person_id': 24076,
#     'name': 'Rebecca Pauly'},
#    {'role': 'ACTOR',
#     'character_name': 'Concierge',
#     'person_id': 24078,
#     'name': 'Catherine Benguigui'},
#    {'role': 'ACTOR',
#     'character_name': 'Secretary',
#     'person_id': 24079,
#     'name': 'Maria Ducceschi'},
#    {'role': 'ACTOR',
#     'character_name': 'Gruber',
#     'person_id': 24080,
#     'name': 'Jacques Collard'},
#    {'role': 'ACTOR',
#     'character_name': 'Desk Clerk',
#     'person_id': 24081,
#     'name': 'Dominique Pozzetto'},
#    {'role': 'ACTOR',
#     'character_name': 'Baker',
#     'person_id': 24082,
#     'name': 'Emanuel Booz'},
#    {'role': 'ACTOR',
#     'character_name': 'Hotel Porter',
#     'person_id': 24083,
#     'name': 'Lino Ribeiro de Sousa'},
#    {'role': 'ACTOR',
#     'character_name': 'Cabby',
#     'person_id': 24084,
#     'name': 'Asil Raïs'},
#    {'role': 'ACTOR',
#     'character_name': 'Cafe Owner',
#     'person_id': 24085,
#     'name': 'Bernard Richier'},
#    {'role': 'ACTOR',
#     'character_name': 'Cafe Owner',
#     'person_id': 24086,
#     'name': 'Marinette Richier'},
#    {'role': 'CO_PRODUCER', 'person_id': 24093, 'name': 'Alain Vannier'},
#    {'role': 'CO_PRODUCER', 'person_id': 24088, 'name': 'Mark Allan'},
#    {'role': 'CO_PRODUCER', 'person_id': 24089, 'name': 'Antonio Cardenal'},
#    {'role': 'CO_PRODUCER', 'person_id': 24092, 'name': 'Iñaki Núñez'},
#    {'role': 'DIRECTOR', 'person_id': 17776, 'name': 'Roman Polanski'},
#    {'role': 'EDITOR', 'person_id': 17781, 'name': 'Hervé de Luze'},
#    {'role': 'EXECUTIVE_PRODUCER',
#     'person_id': 15121,
#     'name': 'Wolfgang Glattes'},
#    {'role': 'EXECUTIVE_PRODUCER', 'person_id': 24090, 'name': 'Michel Cheyko'},
#    {'role': 'ORIGINAL_MUSIC_COMPOSER',
#     'person_id': 24094,
#     'name': 'Wojciech Kilar'},
#    {'role': 'PRODUCER', 'person_id': 17776, 'name': 'Roman Polanski'},
#    {'role': 'PRODUCTION_DESIGN',
#     'person_id': 14884,
#     'name': 'Dean Tavoularis'},
#    {'role': 'SCREENPLAY', 'person_id': 24087, 'name': 'John Brownjohn'},
#    {'role': 'SCREENPLAY', 'person_id': 17776, 'name': 'Roman Polanski'},
#    {'role': 'SCREENPLAY', 'person_id': 24095, 'name': 'Enrique Urbizu'}],
#   'external_ids': [{'provider': 'tms', 'external_id': 'MV000790560000'},
#    {'provider': 'tmdb_latest', 'external_id': '622'},
#    {'provider': 'gowatchit', 'external_id': '30420'},
#    {'provider': 'tmdb', 'external_id': '622'},
#    {'provider': 'eidr', 'external_id': '10.5240/740B-7228-3500-2BB0-B6DF-G'},
#    {'provider': 'iva', 'external_id': '482444'},
#    {'provider': 'imdb', 'external_id': 'tt0142688'},
#    {'provider': 'rovi', 'external_id': '1203893'},
#    {'provider': 'imdb_latest', 'external_id': 'tt0142688'}],
#   'genre_ids': [12, 18],
#   'age_certification': '12',
#   'runtime': 133,
#   'production_countries': ['ES', 'FR'],
#   'permanent_audiences': ['pa:e995ff56-e2ad-460e-a897-f70f4e1c5e3e']}]

# %%
len(extra_info)
# Out:
# 30

# %%
# Generar dataframes con el listado de peliculas asociadas a lo que el usuario introduzca en peli_key 
# con todas las columnas que consideres relevantes y el total serán las pelis que te salgan del primer request (e.g.: 22)

# %%
table = pd.json_normalize(extra_info)
table
# Out:
#    jw_entity_id       id                                              title  \
# 0      tm460828   460828                  Hotel Transilvania: Transformanía
# 1       tm69164    69164                                 Hotel Transilvania
# 2      tm244157   244157  Hotel Transilvania 3: Unas vacaciones monstruosas
# 3      tm132278   132278                               Hotel Transilvania 2
# 4      tm162843   162843                             El gran hotel Budapest
# 5      tm176016   176016                          El exótico Hotel Marigold
# 6      tm135121   135121                                  Hotel para perros
# 7     tm1031933  1031933  Mascotas monstruosas: un corto de Hotel Transi...
# 8      tm244366   244366                                      Hotel Artemis
# 9      tm128879   128879                          Una habitación con vistas
# 10     tm138793   138793                    El nuevo exótico hotel Marigold
# 11     tm372685   372685                                  Muerte en el Nilo
# 12     tm823136   823136                      Hotel Explotación: Las Kellys
# 13      tm96276    96276                                    El hombre verde
# 14     tm232799   232799                              Sin tiempo para morir
# 15     tm181889   181889                                Antes del anochecer
# 16     tm243264   243264                                   Hotel Coolgardie
# 17     tm267401   267401                                       Contratiempo
# 18     tm855362   855362                  El callejón de las almas perdidas
# 19      tm65295    65295                                    A Roma con amor
# 20     tm224498   224498                                     Hell House LLC
# 21     tm218129   218129                        Jack Reacher: Never Go Back
# 22      tm49864    49864              Los Tenenbaums. Una familia de genios
# 23     tm142571   142571                                    Lío en Broadway
# 24      tm57798    57798                        Venganza: Conexión Estambul
# 25     tm138369   138369                                        Antes de ti
# 26     tm137702   137702                                    Golpe de estado
# 27     tm370650   370650                              Timadoras compulsivas
# 28     tm172251   172251                        Superdetective en Hollywood
# 29      tm47174    47174                                   La novena puerta
#
#                                             full_path  \
# 0                   /es/pelicula/hotel-transilvania-4
# 1                     /es/pelicula/hotel-transilvania
# 2                   /es/pelicula/hotel-transylvania-3
# 3                   /es/pelicula/hotel-transilvania-2
# 4                 /es/pelicula/el-gran-hotel-budapest
# 5              /es/pelicula/el-exotico-hotel-marigold
# 6                      /es/pelicula/hotel-para-perros
# 7   /es/pelicula/monster-pets-a-hotel-transylvania...
# 8                          /es/pelicula/hotel-artemis
# 9              /es/pelicula/una-habitacion-con-vistas
# 10       /es/pelicula/el-nuevo-exotico-hotel-marigold
# 11                /es/pelicula/muerte-en-el-nilo-2022
# 12          /es/pelicula/hotel-explotacion-las-kellys
# 13                       /es/pelicula/el-hombre-verde
# 14                 /es/pelicula/sin-tiempo-para-morir
# 15                   /es/pelicula/antes-del-anochecer
# 16                      /es/pelicula/hotel-coolgardie
# 17                          /es/pelicula/contratiempo
# 18                       /es/pelicula/nightmare-alley
# 19                       /es/pelicula/a-roma-con-amor
# 20                        /es/pelicula/hell-house-llc
# 21            /es/pelicula/jack-reacher-never-go-back
# 22  /es/pelicula/los-tenenbaums-una-familia-de-genios
# 23                       /es/pelicula/lio-en-broadway
# 24            /es/pelicula/venganza-conexion-estambul
# 25                           /es/pelicula/antes-de-ti
# 26                       /es/pelicula/golpe-de-estado
# 27                 /es/pelicula/timadoras-compulsivas
# 28           /es/pelicula/superdetective-en-hollywood
# 29                      /es/pelicula/la-novena-puerta
#
#                          poster              poster_blur_hash  \
# 0   /poster/259379170/{profile}  TEE.w.D91jxwVco}93xvnft*awRV
# 1   /poster/248781262/{profile}  ToEW2it7xu.ToKtRt-RjoKOaWCt6
# 2   /poster/127021459/{profile}  TbIhphNztm1QXTNHXoj^skI?bHnP
# 3   /poster/135971272/{profile}  TYCsp,I[R*t:oxNGKkn,n+ofWCof
# 4   /poster/255241071/{profile}  THF5miad9ZtOayWC4.oe%M~Dt7NG
# 5    /poster/85019324/{profile}  TbLzdHxtnOo}M{RP~Wt7tR-AWBW;
# 6   /poster/207108814/{profile}  TcMZ~~xu?b.TRkxu?vozD%S$WVIU
# 7   /poster/245233793/{profile}  TBA]srELE2m+R%%M_Nw|M{S0n%xv
# 8   /poster/152515134/{profile}  TXG845Nd0OnNsmT00ioJ-jozR-Rj
# 9   /poster/198869904/{profile}  TqEgaVt7bHysjaf+5RV@ayIpj[jF
# 10  /poster/100768291/{profile}  TSOVcJROrqPXNIWT8{%2-nD$kqW?
# 11  /poster/272327055/{profile}  TmFNe@xCR%}rxCSOxDs-W=RjoeW;
# 12  /poster/227577090/{profile}  TMGbYZ~WRj-pRiRkf4M{WG^*t6xa
# 13  /poster/107883442/{profile}  TQM7PQ$dyW}:-iNdII-,xZAaafwc
# 14  /poster/205566863/{profile}  TfKduXNG~qJ:RktR%1xuM|Net7RP
# 15   /poster/77913152/{profile}  TdKVEtI9M{.TNIV?4nt5bISjjEof
# 16   /poster/12414320/{profile}  TWF6d?WBM|.Tj[V@R5ofRks+WVj[
# 17   /poster/10382158/{profile}  TJCGrwD%4n_4RjNGD%xu%NOGxtae
# 18  /poster/268347634/{profile}  T9A]B3NH0$S|s:xG0}NHW=RkoeI;
# 19  /poster/263861413/{profile}  TkOoC0Wr$y~7Woj]bbs.V@M}juNd
# 20  /poster/101683739/{profile}  TOFOS?ofMx0ffkxu^*j]M|a1fkM|
# 21  /poster/122924039/{profile}  THD[,=-;~o_2%1%f0zM{R:-T9HxZ
# 22   /poster/10488264/{profile}  TYO3FQo}.St6oyWX?wnOMdI:RPs9
# 23  /poster/127948063/{profile}  TpN+@gafXLHqWCOE?vo0fmJ;R*$d
# 24  /poster/242968219/{profile}  TE9%6k4T%#Tx9Z-V=|RPW;xao0M{
# 25  /poster/127059403/{profile}  ToLDSyMyt5~VfiIoS}R*s:xF%2oL
# 26  /poster/209156331/{profile}  TVFFvmaiIVt7M{a_01a{t7bYt8oM
# 27  /poster/146555909/{profile}  TYJaGLe.?E~TRkRjxZWEE3NdxtoL
# 28  /poster/179752804/{profile}  TPGQIp6%;{1F#SBB5l+]WA{LBp#m
# 29  /poster/252088882/{profile}  TGA9.+R+0gnNRkNdEMjZ-UI@xt$%
#
#                                             backdrops  \
# 0   [{'backdrop_url': '/backdrop/248340077/{profil...
# 1   [{'backdrop_url': '/backdrop/8828104/{profile}...
# 2   [{'backdrop_url': '/backdrop/56424832/{profile...
# 3   [{'backdrop_url': '/backdrop/175748127/{profil...
# 4   [{'backdrop_url': '/backdrop/188496756/{profil...
# 5   [{'backdrop_url': '/backdrop/242587308/{profil...
# 6   [{'backdrop_url': '/backdrop/264987948/{profil...
# 7   [{'backdrop_url': '/backdrop/245394520/{profil...
# 8   [{'backdrop_url': '/backdrop/56053895/{profile...
# 9   [{'backdrop_url': '/backdrop/71057512/{profile...
# 10  [{'backdrop_url': '/backdrop/242580218/{profil...
# 11  [{'backdrop_url': '/backdrop/257956084/{profil...
# 12                                                NaN
# 13  [{'backdrop_url': '/backdrop/11792765/{profile...
# 14  [{'backdrop_url': '/backdrop/253750993/{profil...
# 15  [{'backdrop_url': '/backdrop/9602678/{profile}...
# 16  [{'backdrop_url': '/backdrop/14840121/{profile...
# 17  [{'backdrop_url': '/backdrop/5236870/{profile}...
# 18  [{'backdrop_url': '/backdrop/258185325/{profil...
# 19  [{'backdrop_url': '/backdrop/10652221/{profile...
# 20  [{'backdrop_url': '/backdrop/178118841/{profil...
# 21  [{'backdrop_url': '/backdrop/2756054/{profile}...
# 22  [{'backdrop_url': '/backdrop/57782478/{profile...
# 23  [{'backdrop_url': '/backdrop/273155811/{profil...
# 24  [{'backdrop_url': '/backdrop/8711216/{profile}...
# 25  [{'backdrop_url': '/backdrop/824909/{profile}'...
# 26  [{'backdrop_url': '/backdrop/200818253/{profil...
# 27  [{'backdrop_url': '/backdrop/127064293/{profil...
# 28  [{'backdrop_url': '/backdrop/9030857/{profile}...
# 29  [{'backdrop_url': '/backdrop/239594824/{profil...
#
#                                     short_description  original_release_year  \
# 0   Drac y la pandilla vuelven, como nunca los hab...                   2022
# 1   Drácula regenta un hotel en el que se alojan p...                   2012
# 2   Nuestra familia de monstruos favorita se embar...                   2018
# 3   Todo parece mejorar en el Hotel Transilvania. ...                   2015
# 4   El Sr. Gustave H., un legendario conserje de u...                   2014
# 5   Un grupo de ancianos ingleses deciden disfruta...                   2011
# 6   Narra la historia de dos huérfanos adolescente...                   2009
# 7   En ‘Mascotas Monstruosas’, Pipis, el adorable ...                   2021
# 8   Los Ángeles, año 2028. El Hotel Artemis es un ...                   2018
# 9   Lucy Honey Church una joven inglesa de buena f...                   1985
# 10  El Hotel Marigold, segundo lugar más exótico e...                   2015
# 11  Vuelven las pesquisas del célebre detective Hé...                   2022
# 12  More than two hundred thousand women work as m...                   2018
# 13  A las órdenes de sus misteriosos jefes de Orie...                   1956
# 14  James Bond se encuentra disfrutando de unas me...                   2020
# 15  Han pasado dos décadas desde que se encontraro...                   2013
# 16  Described as “a nightmare version of Cheers” (...                   2016
# 17  Barcelona, España. Adrián Doria, un joven y ex...                   2017
# 18  Un buscavidas se compincha con una pitonisa pa...                   2021
# 19  Cuatro historias independientes con un escenar...                   2012
# 20  Cinco años después de una inexplicada tragedia...                   2015
# 21  La Mayor Susan Turner, líder de la antigua uni...                   2016
# 22  Royal Tenenbaum (Gene Hackman) y su mujer Ethe...                   2001
# 23  Arnold (Owen Wilson) tiene una vida perfecta: ...                   2015
# 24  Aunque ya está retirado, Bryan Mills se ve obl...                   2012
# 25  Una chica (Emilia Clarke) de una pequeña pobla...                   2016
# 26  En su casa en un país del sudeste asiático, un...                   2015
# 27  Dos artistas del engaño, una de clase alta y l...                   2019
# 28  Axel Foley es un impetuoso e inteligente detec...                   1984
# 29  Dean Corso (Johnny Depp) trabaja de forma conf...                   1999
#
#    object_type  ...                                            credits  \
# 0        movie  ...  [{'role': 'ACTOR', 'character_name': 'Mavis Dr...
# 1        movie  ...  [{'role': 'ACTOR', 'character_name': 'Count Dr...
# 2        movie  ...  [{'role': 'ACTOR', 'character_name': 'Count Dr...
# 3        movie  ...  [{'role': 'ACTOR', 'character_name': 'Dracula ...
# 4        movie  ...  [{'role': 'ACTOR', 'character_name': 'Monsieur...
# 5        movie  ...  [{'role': 'ACTOR', 'character_name': 'Douglas ...
# 6        movie  ...  [{'role': 'ACTOR', 'character_name': 'Andi', '...
# 7        movie  ...  [{'role': 'ACTOR', 'character_name': 'Dracula ...
# 8        movie  ...  [{'role': 'ACTOR', 'character_name': 'Jean Tho...
# 9        movie  ...  [{'role': 'ACTOR', 'character_name': 'Lucy Hon...
# 10       movie  ...  [{'role': 'ACTOR', 'character_name': 'Sonny Ka...
# 11       movie  ...  [{'role': 'ACTOR', 'character_name': 'Hercule ...
# 12       movie  ...  [{'role': 'DIRECTOR', 'person_id': 1681032, 'n...
# 13       movie  ...  [{'role': 'ACTOR', 'character_name': 'Hawkins'...
# 14       movie  ...  [{'role': 'ACTOR', 'character_name': 'James Bo...
# 15       movie  ...  [{'role': 'ACTOR', 'character_name': 'Jesse', ...
# 16       movie  ...  [{'role': 'CO_PRODUCER', 'person_id': 820623, ...
# 17       movie  ...  [{'role': 'ACTOR', 'character_name': 'Adrián D...
# 18       movie  ...  [{'role': 'ACTOR', 'character_name': 'Stanton ...
# 19       movie  ...  [{'role': 'ACTOR', 'character_name': 'Jerry', ...
# 20       movie  ...  [{'role': 'ACTOR', 'character_name': 'Kate', '...
# 21       movie  ...  [{'role': 'ACTOR', 'character_name': 'Jack Rea...
# 22       movie  ...  [{'role': 'ACTOR', 'character_name': 'Royal Te...
# 23       movie  ...  [{'role': 'ACTOR', 'character_name': 'Arnold A...
# 24       movie  ...  [{'role': 'ACTOR', 'character_name': 'Bryan Mi...
# 25       movie  ...  [{'role': 'ACTOR', 'character_name': 'Louisa '...
# 26       movie  ...  [{'role': 'ACTOR', 'character_name': 'Jack Dwy...
# 27       movie  ...  [{'role': 'ACTOR', 'character_name': 'Josephin...
# 28       movie  ...  [{'role': 'ACTOR', 'character_name': 'Det. Axe...
# 29       movie  ...  [{'role': 'ACTOR', 'character_name': 'Dean Cor...
#
#                                          external_ids  \
# 0   [{'provider': 'tmdb', 'external_id': '585083'}...
# 1   [{'provider': 'tmdb_latest', 'external_id': '7...
# 2   [{'provider': 'tmdb_latest', 'external_id': '4...
# 3   [{'provider': 'imdb_latest', 'external_id': 't...
# 4   [{'provider': 'imdb', 'external_id': 'tt227838...
# 5   [{'provider': 'tmdb_latest', 'external_id': '7...
# 6   [{'provider': 'tmdb_latest', 'external_id': '1...
# 7   [{'provider': 'tmdb', 'external_id': '813258'}...
# 8   [{'provider': 'imdb', 'external_id': 'tt583426...
# 9   [{'provider': 'iva', 'external_id': '1505'}, {...
# 10  [{'provider': 'gowatchit', 'external_id': '268...
# 11  [{'provider': 'eidr', 'external_id': '10.5240/...
# 12  [{'provider': 'tmdb', 'external_id': '617948'}...
# 13  [{'provider': 'tmdb', 'external_id': '58470'},...
# 14  [{'provider': 'imdb', 'external_id': 'tt238232...
# 15  [{'provider': 'tms', 'external_id': 'MV0045749...
# 16  [{'provider': 'eidr', 'external_id': '10.5240/...
# 17  [{'provider': 'imdb', 'external_id': 'tt485726...
# 18  [{'provider': 'imdb', 'external_id': 'tt774049...
# 19  [{'provider': 'gowatchit', 'external_id': '265...
# 20  [{'provider': 'eidr', 'external_id': '10.5240/...
# 21  [{'provider': 'imdb_latest', 'external_id': 't...
# 22  [{'provider': 'imdb_latest', 'external_id': 't...
# 23  [{'provider': 'imdb', 'external_id': 'tt176737...
# 24  [{'provider': 'iva', 'external_id': '802252'},...
# 25  [{'provider': 'imdb', 'external_id': 'tt267442...
# 26  [{'provider': 'tmdb', 'external_id': '192141'}...
# 27  [{'provider': 'tms', 'external_id': 'MV0109047...
# 28  [{'provider': 'iva', 'external_id': '917'}, {'...
# 29  [{'provider': 'tms', 'external_id': 'MV0007905...
#
#                                              upcoming  \
# 0   [{'package_id': 119, 'release_window_from': '2...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  [{'package_id': 337, 'release_window_from': '2...
# 12                                                NaN
# 13                                                NaN
# 14  [{'package_id': 252, 'release_window_from': '2...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  [{'package_id': 0, 'release_window_from': '202...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                          genre_ids age_certification runtime  \
# 0      [10, 7, 3, 1, 2, 9, 14, 13]                 7      87
# 1             [7, 13, 2, 3, 10, 9]              APTA      91
# 2             [7, 3, 10, 9, 13, 2]              APTA      97
# 3   [3, 7, 9, 2, 1, 13, 11, 10, 6]              APTA      89
# 4                    [3, 6, 18, 4]                12     101
# 5                       [3, 6, 13]              APTA     124
# 6                  [3, 14, 10, 18]              APTA     100
# 7                           [7, 3]              APTA       6
# 8                [14, 6, 12, 1, 4]                12      94
# 9                          [6, 13]               NaN     117
# 10                      [6, 3, 13]               NaN     122
# 11                      [12, 6, 4]                12     127
# 12                             [5]              APTA      55
# 13                          [3, 4]               NaN      80
# 14                         [12, 1]                12     163
# 15                         [6, 13]                 7     109
# 16                             [5]               NaN      84
# 17                  [12, 4, 6, 18]                12     107
# 18             [12, 7, 9, 1, 4, 6]                16     150
# 19                 [13, 3, 11, 18]              APTA     111
# 20                         [12, 9]               NaN      93
# 21                   [12, 1, 4, 6]                12     118
# 22                          [6, 3]               NaN     109
# 23                      [3, 18, 6]                 7      93
# 24                  [12, 1, 4, 18]                12      91
# 25                         [13, 6]                12     110
# 26                   [12, 1, 6, 4]                16     103
# 27                          [3, 4]                 7      93
# 28                   [3, 4, 12, 1]                12     105
# 29                        [12, 18]                12     133
#
#    production_countries                                permanent_audiences  \
# 0                  [US]          [pa:cd84cbfd-3ce4-4a92-a412-abe6b69d8dca]
# 1                  [US]          [pa:cd84cbfd-3ce4-4a92-a412-abe6b69d8dca]
# 2                  [US]          [pa:cd84cbfd-3ce4-4a92-a412-abe6b69d8dca]
# 3                  [US]          [pa:cd84cbfd-3ce4-4a92-a412-abe6b69d8dca]
# 4              [US, DE]          [pa:9a1c71b9-6530-49ab-b8fc-54f16a94a006]
# 5          [AE, GB, US]          [pa:9a1c71b9-6530-49ab-b8fc-54f16a94a006]
# 6                  [US]          [pa:52d5dd3d-f67d-460c-bff8-3d03d7656971]
# 7                  [US]          [pa:cd84cbfd-3ce4-4a92-a412-abe6b69d8dca]
# 8              [GB, US]          [pa:b71b706d-6c43-4573-8d96-370463aaca8f]
# 9                  [GB]          [pa:b879dad8-8dd3-4518-a89e-243ddda6f514]
# 10             [GB, US]  [pa:12415b46-6819-4d98-b4f9-8dcc123c86f8, pa:9...
# 11             [US, GB]          [pa:e995ff56-e2ad-460e-a897-f70f4e1c5e3e]
# 12                 [ES]                                                NaN
# 13                 [GB]                                                NaN
# 14             [GB, US]          [pa:2b02372a-507b-4bd4-9ed4-7457fa71fb07]
# 15             [GR, US]          [pa:1d663345-e54f-459f-8e43-aec14733b446]
# 16                 [AU]          [pa:e4910e61-890a-4db6-88f9-4c3d4a768259]
# 17                 [ES]          [pa:e995ff56-e2ad-460e-a897-f70f4e1c5e3e]
# 18                 [US]          [pa:6f295818-b61f-495f-91f1-af373c542f0a]
# 19         [IT, ES, US]          [pa:12415b46-6819-4d98-b4f9-8dcc123c86f8]
# 20                 [US]          [pa:06016e7b-74d4-49c7-b21d-0f8c4812732f]
# 21             [US, CN]          [pa:b71b706d-6c43-4573-8d96-370463aaca8f]
# 22                 [US]          [pa:9a1c71b9-6530-49ab-b8fc-54f16a94a006]
# 23             [US, DE]          [pa:9a1c71b9-6530-49ab-b8fc-54f16a94a006]
# 24                 [FR]          [pa:b71b706d-6c43-4573-8d96-370463aaca8f]
# 25                 [US]  [pa:86881be2-bab4-4379-ad20-ce03e12212aa, pa:b...
# 26                 [US]          [pa:b71b706d-6c43-4573-8d96-370463aaca8f]
# 27                 [US]  [pa:76eea35e-e680-440a-a92c-7c3238bbfb0e, pa:8...
# 28                 [US]          [pa:b6d69ea4-b214-4a39-b42e-4c033b850d77]
# 29             [ES, FR]          [pa:e995ff56-e2ad-460e-a897-f70f4e1c5e3e]
#
#                      full_paths.MOVIE_DETAIL_OVERVIEW  \
# 0                   /es/pelicula/hotel-transilvania-4
# 1                     /es/pelicula/hotel-transilvania
# 2                   /es/pelicula/hotel-transylvania-3
# 3                   /es/pelicula/hotel-transilvania-2
# 4                 /es/pelicula/el-gran-hotel-budapest
# 5              /es/pelicula/el-exotico-hotel-marigold
# 6                      /es/pelicula/hotel-para-perros
# 7   /es/pelicula/monster-pets-a-hotel-transylvania...
# 8                          /es/pelicula/hotel-artemis
# 9              /es/pelicula/una-habitacion-con-vistas
# 10       /es/pelicula/el-nuevo-exotico-hotel-marigold
# 11                /es/pelicula/muerte-en-el-nilo-2022
# 12          /es/pelicula/hotel-explotacion-las-kellys
# 13                       /es/pelicula/el-hombre-verde
# 14                 /es/pelicula/sin-tiempo-para-morir
# 15                   /es/pelicula/antes-del-anochecer
# 16                      /es/pelicula/hotel-coolgardie
# 17                          /es/pelicula/contratiempo
# 18                       /es/pelicula/nightmare-alley
# 19                       /es/pelicula/a-roma-con-amor
# 20                        /es/pelicula/hell-house-llc
# 21            /es/pelicula/jack-reacher-never-go-back
# 22  /es/pelicula/los-tenenbaums-una-familia-de-genios
# 23                       /es/pelicula/lio-en-broadway
# 24            /es/pelicula/venganza-conexion-estambul
# 25                           /es/pelicula/antes-de-ti
# 26                       /es/pelicula/golpe-de-estado
# 27                 /es/pelicula/timadoras-compulsivas
# 28           /es/pelicula/superdetective-en-hollywood
# 29                      /es/pelicula/la-novena-puerta
#
#                                                 clips
# 0                                                 NaN
# 1   [{'type': 'trailer', 'provider': 'youtube', 'e...
# 2   [{'type': 'trailer', 'provider': 'youtube', 'e...
# 3   [{'type': 'trailer', 'provider': 'youtube', 'e...
# 4   [{'type': 'trailer', 'provider': 'youtube', 'e...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 12                                                NaN
# 13                                                NaN
# 14  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 15  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 16                                                NaN
# 17  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 18  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 24  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 25  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 26                                                NaN
# 27  [{'type': 'trailer', 'provider': 'youtube', 'e...
# 28                                                NaN
# 29  [{'type': 'trailer', 'provider': 'youtube', 'e...
#
# [30 rows x 24 columns]

# %%
offers = pd.json_normalize(table['offers'][1])
offers
# Out:
#    jw_entity_id monetization_type  provider_id package_short_name  \
# 0       tm69164               buy            2                itu
# 1       tm69164               buy            2                itu
# 2       tm69164               buy            2                itu
# 3       tm69164              rent            2                itu
# 4       tm69164              rent            2                itu
# 5       tm69164              rent            2                itu
# 6       tm69164               buy            3                ply
# 7       tm69164               buy            3                ply
# 8       tm69164              rent            3                ply
# 9       tm69164              rent            3                ply
# 10      tm69164          flatrate            8                nfx
# 11      tm69164          flatrate            8                nfx
# 12      tm69164               buy           10                amz
# 13      tm69164               buy           10                amz
# 14      tm69164              rent           10                amz
# 15      tm69164              rent           10                amz
# 16      tm69164               buy           35                wki
# 17      tm69164               buy           35                wki
# 18      tm69164               buy           35                wki
# 19      tm69164              rent           35                wki
# 20      tm69164              rent           35                wki
# 21      tm69164              rent           35                wki
# 22      tm69164               buy           68                msf
# 23      tm69164               buy           68                msf
# 24      tm69164              rent           68                msf
# 25      tm69164              rent           68                msf
#
#     retail_price  last_change_retail_price  last_change_difference  \
# 0          11.99                      3.99                     8.0
# 1          11.99                       NaN                     NaN
# 2           5.99                       NaN                     NaN
# 3           3.99                       NaN                     NaN
# 4           3.99                       NaN                     NaN
# 5           3.99                       NaN                     NaN
# 6           8.99                       NaN                     NaN
# 7           5.99                       NaN                     NaN
# 8           2.99                       NaN                     NaN
# 9           1.99                       NaN                     NaN
# 10           NaN                       NaN                     NaN
# 11           NaN                       NaN                     NaN
# 12          8.99                     11.99                    -3.0
# 13          5.99                      4.99                     1.0
# 14          2.99                      3.99                    -1.0
# 15          1.99                      3.99                    -2.0
# 16         14.99                     13.99                     1.0
# 17          9.99                       NaN                     NaN
# 18          5.99                       NaN                     NaN
# 19          4.99                       NaN                     NaN
# 20          3.99                       NaN                     NaN
# 21          2.99                       NaN                     NaN
# 22         13.99                       NaN                     NaN
# 23         12.99                       NaN                     NaN
# 24          2.99                       NaN                     NaN
# 25          1.99                       NaN                     NaN
#
#     last_change_percent last_change_date last_change_date_provider_id  \
# 0            200.501250       2021-08-14                 2021-08-14_2
# 1                   NaN              NaN                          NaN
# 2                   NaN              NaN                          NaN
# 3                   NaN              NaN                          NaN
# 4                   NaN              NaN                          NaN
# 5                   NaN              NaN                          NaN
# 6                   NaN              NaN                          NaN
# 7                   NaN              NaN                          NaN
# 8                   NaN              NaN                          NaN
# 9                   NaN              NaN                          NaN
# 10                  NaN              NaN                          NaN
# 11                  NaN              NaN                          NaN
# 12           -25.020851       2022-03-06                2022-03-06_10
# 13            20.040081       2022-01-31                2022-01-31_10
# 14           -25.062656       2022-03-06                2022-03-06_10
# 15           -50.125313       2022-03-06                2022-03-06_10
# 16             7.147963       2022-03-04                2022-03-04_35
# 17                  NaN              NaN                          NaN
# 18                  NaN              NaN                          NaN
# 19                  NaN              NaN                          NaN
# 20                  NaN              NaN                          NaN
# 21                  NaN              NaN                          NaN
# 22                  NaN              NaN                          NaN
# 23                  NaN              NaN                          NaN
# 24                  NaN              NaN                          NaN
# 25                  NaN              NaN                          NaN
#
#    currency presentation_type country  \
# 0       EUR                4k      ES
# 1       EUR                hd      ES
# 2       EUR                sd      ES
# 3       EUR                4k      ES
# 4       EUR                hd      ES
# 5       EUR                sd      ES
# 6       EUR                hd      ES
# 7       EUR                sd      ES
# 8       EUR                hd      ES
# 9       EUR                sd      ES
# 10      EUR                hd      ES
# 11      EUR                sd      ES
# 12      EUR                hd      ES
# 13      EUR                sd      ES
# 14      EUR                hd      ES
# 15      EUR                sd      ES
# 16      EUR                4k      ES
# 17      EUR                hd      ES
# 18      EUR                sd      ES
# 19      EUR                4k      ES
# 20      EUR                hd      ES
# 21      EUR                sd      ES
# 22      EUR                hd      ES
# 23      EUR                sd      ES
# 24      EUR                hd      ES
# 25      EUR                sd      ES
#
#                                     urls.standard_web  \
# 0   https://tv.apple.com/es/movie/hotel-transilvan...
# 1   https://tv.apple.com/es/movie/hotel-transilvan...
# 2   https://tv.apple.com/es/movie/hotel-transilvan...
# 3   https://tv.apple.com/es/movie/hotel-transilvan...
# 4   https://tv.apple.com/es/movie/hotel-transilvan...
# 5   https://tv.apple.com/es/movie/hotel-transilvan...
# 6   https://play.google.com/store/movies/details/H...
# 7   https://play.google.com/store/movies/details/H...
# 8   https://play.google.com/store/movies/details/H...
# 9   https://play.google.com/store/movies/details/H...
# 10              http://www.netflix.com/title/70220028
# 11              http://www.netflix.com/title/70220028
# 12  https://app.primevideo.com/detail?gti=amzn1.dv...
# 13  https://app.primevideo.com/detail?gti=amzn1.dv...
# 14  https://app.primevideo.com/detail?gti=amzn1.dv...
# 15  https://app.primevideo.com/detail?gti=amzn1.dv...
# 16    https://rakuten.tv/es/movies/hotel-transilvania
# 17    https://rakuten.tv/es/movies/hotel-transilvania
# 18    https://rakuten.tv/es/movies/hotel-transilvania
# 19    https://rakuten.tv/es/movies/hotel-transilvania
# 20    https://rakuten.tv/es/movies/hotel-transilvania
# 21    https://rakuten.tv/es/movies/hotel-transilvania
# 22  https://www.microsoft.com/es-es/p/hotel-transi...
# 23  https://www.microsoft.com/es-es/p/hotel-transi...
# 24  https://www.microsoft.com/es-es/p/hotel-transi...
# 25  https://www.microsoft.com/es-es/p/hotel-transi...
#
#                                  urls.deeplink_rokuos available_to  \
# 0   launch/551012?contentID=https%3A%2F%2Ftv.apple...          NaN
# 1   launch/551012?contentID=https%3A%2F%2Ftv.apple...          NaN
# 2   launch/551012?contentID=https%3A%2F%2Ftv.apple...          NaN
# 3   launch/551012?contentID=https%3A%2F%2Ftv.apple...          NaN
# 4   launch/551012?contentID=https%3A%2F%2Ftv.apple...          NaN
# 5   launch/551012?contentID=https%3A%2F%2Ftv.apple...          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10       launch/12?contentID=70220028&MediaType=movie   2023-02-28
# 11       launch/12?contentID=70220028&MediaType=movie   2023-02-28
# 12     launch/13?contentID=B071RZ7WGR&MediaType=movie          NaN
# 13     launch/13?contentID=B071RZ7WGR&MediaType=movie          NaN
# 14     launch/13?contentID=B071RZ7WGR&MediaType=movie          NaN
# 15     launch/13?contentID=B071RZ7WGR&MediaType=movie          NaN
# 16                                                NaN          NaN
# 17                                                NaN          NaN
# 18                                                NaN          NaN
# 19                                                NaN          NaN
# 20                                                NaN          NaN
# 21                                                NaN          NaN
# 22                                                NaN          NaN
# 23                                                NaN          NaN
# 24                                                NaN          NaN
# 25                                                NaN          NaN
#
#                                     urls.deeplink_web
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10              http://www.netflix.com/watch/70220028
# 11              http://www.netflix.com/watch/70220028
# 12  https://app.primevideo.com/watch?gti=amzn1.dv....
# 13  https://app.primevideo.com/watch?gti=amzn1.dv....
# 14  https://app.primevideo.com/watch?gti=amzn1.dv....
# 15  https://app.primevideo.com/watch?gti=amzn1.dv....
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN

# %%
table.columns
# Out:
# Index(['jw_entity_id', 'id', 'title', 'full_path', 'poster',
#        'poster_blur_hash', 'backdrops', 'short_description',
#        'original_release_year', 'object_type', 'original_title',
#        'localized_release_date', 'offers', 'scoring', 'credits',
#        'external_ids', 'upcoming', 'genre_ids', 'age_certification', 'runtime',
#        'production_countries', 'permanent_audiences',
#        'full_paths.MOVIE_DETAIL_OVERVIEW', 'clips'],
#       dtype='object')

# %%
table_col = table.drop(['backdrops', 'external_ids', 'genre_ids', 'permanent_audiences', 
                            'localized_release_date','poster_blur_hash', 
                            'full_paths.MOVIE_DETAIL_OVERVIEW','clips', 'scoring','credits'], axis = 1)
table_col
# Out:
#    jw_entity_id       id                                              title  \
# 0      tm460828   460828                  Hotel Transilvania: Transformanía
# 1       tm69164    69164                                 Hotel Transilvania
# 2      tm244157   244157  Hotel Transilvania 3: Unas vacaciones monstruosas
# 3      tm132278   132278                               Hotel Transilvania 2
# 4      tm162843   162843                             El gran hotel Budapest
# 5      tm176016   176016                          El exótico Hotel Marigold
# 6      tm135121   135121                                  Hotel para perros
# 7     tm1031933  1031933  Mascotas monstruosas: un corto de Hotel Transi...
# 8      tm244366   244366                                      Hotel Artemis
# 9      tm128879   128879                          Una habitación con vistas
# 10     tm138793   138793                    El nuevo exótico hotel Marigold
# 11     tm372685   372685                                  Muerte en el Nilo
# 12     tm823136   823136                      Hotel Explotación: Las Kellys
# 13      tm96276    96276                                    El hombre verde
# 14     tm232799   232799                              Sin tiempo para morir
# 15     tm181889   181889                                Antes del anochecer
# 16     tm243264   243264                                   Hotel Coolgardie
# 17     tm267401   267401                                       Contratiempo
# 18     tm855362   855362                  El callejón de las almas perdidas
# 19      tm65295    65295                                    A Roma con amor
# 20     tm224498   224498                                     Hell House LLC
# 21     tm218129   218129                        Jack Reacher: Never Go Back
# 22      tm49864    49864              Los Tenenbaums. Una familia de genios
# 23     tm142571   142571                                    Lío en Broadway
# 24      tm57798    57798                        Venganza: Conexión Estambul
# 25     tm138369   138369                                        Antes de ti
# 26     tm137702   137702                                    Golpe de estado
# 27     tm370650   370650                              Timadoras compulsivas
# 28     tm172251   172251                        Superdetective en Hollywood
# 29      tm47174    47174                                   La novena puerta
#
#                                             full_path  \
# 0                   /es/pelicula/hotel-transilvania-4
# 1                     /es/pelicula/hotel-transilvania
# 2                   /es/pelicula/hotel-transylvania-3
# 3                   /es/pelicula/hotel-transilvania-2
# 4                 /es/pelicula/el-gran-hotel-budapest
# 5              /es/pelicula/el-exotico-hotel-marigold
# 6                      /es/pelicula/hotel-para-perros
# 7   /es/pelicula/monster-pets-a-hotel-transylvania...
# 8                          /es/pelicula/hotel-artemis
# 9              /es/pelicula/una-habitacion-con-vistas
# 10       /es/pelicula/el-nuevo-exotico-hotel-marigold
# 11                /es/pelicula/muerte-en-el-nilo-2022
# 12          /es/pelicula/hotel-explotacion-las-kellys
# 13                       /es/pelicula/el-hombre-verde
# 14                 /es/pelicula/sin-tiempo-para-morir
# 15                   /es/pelicula/antes-del-anochecer
# 16                      /es/pelicula/hotel-coolgardie
# 17                          /es/pelicula/contratiempo
# 18                       /es/pelicula/nightmare-alley
# 19                       /es/pelicula/a-roma-con-amor
# 20                        /es/pelicula/hell-house-llc
# 21            /es/pelicula/jack-reacher-never-go-back
# 22  /es/pelicula/los-tenenbaums-una-familia-de-genios
# 23                       /es/pelicula/lio-en-broadway
# 24            /es/pelicula/venganza-conexion-estambul
# 25                           /es/pelicula/antes-de-ti
# 26                       /es/pelicula/golpe-de-estado
# 27                 /es/pelicula/timadoras-compulsivas
# 28           /es/pelicula/superdetective-en-hollywood
# 29                      /es/pelicula/la-novena-puerta
#
#                          poster  \
# 0   /poster/259379170/{profile}
# 1   /poster/248781262/{profile}
# 2   /poster/127021459/{profile}
# 3   /poster/135971272/{profile}
# 4   /poster/255241071/{profile}
# 5    /poster/85019324/{profile}
# 6   /poster/207108814/{profile}
# 7   /poster/245233793/{profile}
# 8   /poster/152515134/{profile}
# 9   /poster/198869904/{profile}
# 10  /poster/100768291/{profile}
# 11  /poster/272327055/{profile}
# 12  /poster/227577090/{profile}
# 13  /poster/107883442/{profile}
# 14  /poster/205566863/{profile}
# 15   /poster/77913152/{profile}
# 16   /poster/12414320/{profile}
# 17   /poster/10382158/{profile}
# 18  /poster/268347634/{profile}
# 19  /poster/263861413/{profile}
# 20  /poster/101683739/{profile}
# 21  /poster/122924039/{profile}
# 22   /poster/10488264/{profile}
# 23  /poster/127948063/{profile}
# 24  /poster/242968219/{profile}
# 25  /poster/127059403/{profile}
# 26  /poster/209156331/{profile}
# 27  /poster/146555909/{profile}
# 28  /poster/179752804/{profile}
# 29  /poster/252088882/{profile}
#
#                                     short_description  original_release_year  \
# 0   Drac y la pandilla vuelven, como nunca los hab...                   2022
# 1   Drácula regenta un hotel en el que se alojan p...                   2012
# 2   Nuestra familia de monstruos favorita se embar...                   2018
# 3   Todo parece mejorar en el Hotel Transilvania. ...                   2015
# 4   El Sr. Gustave H., un legendario conserje de u...                   2014
# 5   Un grupo de ancianos ingleses deciden disfruta...                   2011
# 6   Narra la historia de dos huérfanos adolescente...                   2009
# 7   En ‘Mascotas Monstruosas’, Pipis, el adorable ...                   2021
# 8   Los Ángeles, año 2028. El Hotel Artemis es un ...                   2018
# 9   Lucy Honey Church una joven inglesa de buena f...                   1985
# 10  El Hotel Marigold, segundo lugar más exótico e...                   2015
# 11  Vuelven las pesquisas del célebre detective Hé...                   2022
# 12  More than two hundred thousand women work as m...                   2018
# 13  A las órdenes de sus misteriosos jefes de Orie...                   1956
# 14  James Bond se encuentra disfrutando de unas me...                   2020
# 15  Han pasado dos décadas desde que se encontraro...                   2013
# 16  Described as “a nightmare version of Cheers” (...                   2016
# 17  Barcelona, España. Adrián Doria, un joven y ex...                   2017
# 18  Un buscavidas se compincha con una pitonisa pa...                   2021
# 19  Cuatro historias independientes con un escenar...                   2012
# 20  Cinco años después de una inexplicada tragedia...                   2015
# 21  La Mayor Susan Turner, líder de la antigua uni...                   2016
# 22  Royal Tenenbaum (Gene Hackman) y su mujer Ethe...                   2001
# 23  Arnold (Owen Wilson) tiene una vida perfecta: ...                   2015
# 24  Aunque ya está retirado, Bryan Mills se ve obl...                   2012
# 25  Una chica (Emilia Clarke) de una pequeña pobla...                   2016
# 26  En su casa en un país del sudeste asiático, un...                   2015
# 27  Dos artistas del engaño, una de clase alta y l...                   2019
# 28  Axel Foley es un impetuoso e inteligente detec...                   1984
# 29  Dean Corso (Johnny Depp) trabaja de forma conf...                   1999
#
#    object_type                            original_title  \
# 0        movie         Hotel Transylvania: Transformania
# 1        movie                        Hotel Transylvania
# 2        movie     Hotel Transylvania 3: Summer Vacation
# 3        movie                      Hotel Transylvania 2
# 4        movie                  The Grand Budapest Hotel
# 5        movie            The Best Exotic Marigold Hotel
# 6        movie                            Hotel for Dogs
# 7        movie  Monster Pets: A Hotel Transylvania Short
# 8        movie                             Hotel Artemis
# 9        movie                        A Room with a View
# 10       movie     The Second Best Exotic Marigold Hotel
# 11       movie                         Death on the Nile
# 12       movie             Hotel Explotación: Las Kellys
# 13       movie                             The Green Man
# 14       movie                            No Time to Die
# 15       movie                           Before Midnight
# 16       movie                          Hotel Coolgardie
# 17       movie                              Contratiempo
# 18       movie                           Nightmare Alley
# 19       movie                         To Rome with Love
# 20       movie                            Hell House LLC
# 21       movie               Jack Reacher: Never Go Back
# 22       movie                      The Royal Tenenbaums
# 23       movie                      She's Funny That Way
# 24       movie                                   Taken 2
# 25       movie                             Me Before You
# 26       movie                                 No Escape
# 27       movie                                The Hustle
# 28       movie                         Beverly Hills Cop
# 29       movie                            The Ninth Gate
#
#                                                offers  \
# 0   [{'jw_entity_id': 'tm460828', 'monetization_ty...
# 1   [{'jw_entity_id': 'tm69164', 'monetization_typ...
# 2   [{'jw_entity_id': 'tm244157', 'monetization_ty...
# 3   [{'jw_entity_id': 'tm132278', 'monetization_ty...
# 4   [{'jw_entity_id': 'tm162843', 'monetization_ty...
# 5   [{'jw_entity_id': 'tm176016', 'monetization_ty...
# 6   [{'jw_entity_id': 'tm135121', 'monetization_ty...
# 7   [{'jw_entity_id': 'tm1031933', 'monetization_t...
# 8   [{'jw_entity_id': 'tm244366', 'monetization_ty...
# 9   [{'jw_entity_id': 'tm128879', 'monetization_ty...
# 10  [{'jw_entity_id': 'tm138793', 'monetization_ty...
# 11  [{'jw_entity_id': 'tm372685', 'monetization_ty...
# 12  [{'jw_entity_id': 'tm823136', 'monetization_ty...
# 13  [{'jw_entity_id': 'tm96276', 'monetization_typ...
# 14  [{'jw_entity_id': 'tm232799', 'monetization_ty...
# 15  [{'jw_entity_id': 'tm181889', 'monetization_ty...
# 16  [{'jw_entity_id': 'tm243264', 'monetization_ty...
# 17  [{'jw_entity_id': 'tm267401', 'monetization_ty...
# 18  [{'jw_entity_id': 'tm855362', 'monetization_ty...
# 19  [{'jw_entity_id': 'tm65295', 'monetization_typ...
# 20  [{'jw_entity_id': 'tm224498', 'monetization_ty...
# 21  [{'jw_entity_id': 'tm218129', 'monetization_ty...
# 22  [{'jw_entity_id': 'tm49864', 'monetization_typ...
# 23  [{'jw_entity_id': 'tm142571', 'monetization_ty...
# 24  [{'jw_entity_id': 'tm57798', 'monetization_typ...
# 25  [{'jw_entity_id': 'tm138369', 'monetization_ty...
# 26  [{'jw_entity_id': 'tm137702', 'monetization_ty...
# 27  [{'jw_entity_id': 'tm370650', 'monetization_ty...
# 28  [{'jw_entity_id': 'tm172251', 'monetization_ty...
# 29  [{'jw_entity_id': 'tm47174', 'monetization_typ...
#
#                                              upcoming age_certification  \
# 0   [{'package_id': 119, 'release_window_from': '2...                 7
# 1                                                 NaN              APTA
# 2                                                 NaN              APTA
# 3                                                 NaN              APTA
# 4                                                 NaN                12
# 5                                                 NaN              APTA
# 6                                                 NaN              APTA
# 7                                                 NaN              APTA
# 8                                                 NaN                12
# 9                                                 NaN               NaN
# 10                                                NaN               NaN
# 11  [{'package_id': 337, 'release_window_from': '2...                12
# 12                                                NaN              APTA
# 13                                                NaN               NaN
# 14  [{'package_id': 252, 'release_window_from': '2...                12
# 15                                                NaN                 7
# 16                                                NaN               NaN
# 17                                                NaN                12
# 18  [{'package_id': 0, 'release_window_from': '202...                16
# 19                                                NaN              APTA
# 20                                                NaN               NaN
# 21                                                NaN                12
# 22                                                NaN               NaN
# 23                                                NaN                 7
# 24                                                NaN                12
# 25                                                NaN                12
# 26                                                NaN                16
# 27                                                NaN                 7
# 28                                                NaN                12
# 29                                                NaN                12
#
#     runtime production_countries
# 0        87                 [US]
# 1        91                 [US]
# 2        97                 [US]
# 3        89                 [US]
# 4       101             [US, DE]
# 5       124         [AE, GB, US]
# 6       100                 [US]
# 7         6                 [US]
# 8        94             [GB, US]
# 9       117                 [GB]
# 10      122             [GB, US]
# 11      127             [US, GB]
# 12       55                 [ES]
# 13       80                 [GB]
# 14      163             [GB, US]
# 15      109             [GR, US]
# 16       84                 [AU]
# 17      107                 [ES]
# 18      150                 [US]
# 19      111         [IT, ES, US]
# 20       93                 [US]
# 21      118             [US, CN]
# 22      109                 [US]
# 23       93             [US, DE]
# 24       91                 [FR]
# 25      110                 [US]
# 26      103                 [US]
# 27       93                 [US]
# 28      105                 [US]
# 29      133             [ES, FR]

# %%
table_col.rename(columns = {'original_title':'originalTitle'}, inplace = True)
table_col
# Out:
#    jw_entity_id       id                                              title  \
# 0      tm460828   460828                  Hotel Transilvania: Transformanía
# 1       tm69164    69164                                 Hotel Transilvania
# 2      tm244157   244157  Hotel Transilvania 3: Unas vacaciones monstruosas
# 3      tm132278   132278                               Hotel Transilvania 2
# 4      tm162843   162843                             El gran hotel Budapest
# 5      tm176016   176016                          El exótico Hotel Marigold
# 6      tm135121   135121                                  Hotel para perros
# 7     tm1031933  1031933  Mascotas monstruosas: un corto de Hotel Transi...
# 8      tm244366   244366                                      Hotel Artemis
# 9      tm128879   128879                          Una habitación con vistas
# 10     tm138793   138793                    El nuevo exótico hotel Marigold
# 11     tm372685   372685                                  Muerte en el Nilo
# 12     tm823136   823136                      Hotel Explotación: Las Kellys
# 13      tm96276    96276                                    El hombre verde
# 14     tm232799   232799                              Sin tiempo para morir
# 15     tm181889   181889                                Antes del anochecer
# 16     tm243264   243264                                   Hotel Coolgardie
# 17     tm267401   267401                                       Contratiempo
# 18     tm855362   855362                  El callejón de las almas perdidas
# 19      tm65295    65295                                    A Roma con amor
# 20     tm224498   224498                                     Hell House LLC
# 21     tm218129   218129                        Jack Reacher: Never Go Back
# 22      tm49864    49864              Los Tenenbaums. Una familia de genios
# 23     tm142571   142571                                    Lío en Broadway
# 24      tm57798    57798                        Venganza: Conexión Estambul
# 25     tm138369   138369                                        Antes de ti
# 26     tm137702   137702                                    Golpe de estado
# 27     tm370650   370650                              Timadoras compulsivas
# 28     tm172251   172251                        Superdetective en Hollywood
# 29      tm47174    47174                                   La novena puerta
#
#                                             full_path  \
# 0                   /es/pelicula/hotel-transilvania-4
# 1                     /es/pelicula/hotel-transilvania
# 2                   /es/pelicula/hotel-transylvania-3
# 3                   /es/pelicula/hotel-transilvania-2
# 4                 /es/pelicula/el-gran-hotel-budapest
# 5              /es/pelicula/el-exotico-hotel-marigold
# 6                      /es/pelicula/hotel-para-perros
# 7   /es/pelicula/monster-pets-a-hotel-transylvania...
# 8                          /es/pelicula/hotel-artemis
# 9              /es/pelicula/una-habitacion-con-vistas
# 10       /es/pelicula/el-nuevo-exotico-hotel-marigold
# 11                /es/pelicula/muerte-en-el-nilo-2022
# 12          /es/pelicula/hotel-explotacion-las-kellys
# 13                       /es/pelicula/el-hombre-verde
# 14                 /es/pelicula/sin-tiempo-para-morir
# 15                   /es/pelicula/antes-del-anochecer
# 16                      /es/pelicula/hotel-coolgardie
# 17                          /es/pelicula/contratiempo
# 18                       /es/pelicula/nightmare-alley
# 19                       /es/pelicula/a-roma-con-amor
# 20                        /es/pelicula/hell-house-llc
# 21            /es/pelicula/jack-reacher-never-go-back
# 22  /es/pelicula/los-tenenbaums-una-familia-de-genios
# 23                       /es/pelicula/lio-en-broadway
# 24            /es/pelicula/venganza-conexion-estambul
# 25                           /es/pelicula/antes-de-ti
# 26                       /es/pelicula/golpe-de-estado
# 27                 /es/pelicula/timadoras-compulsivas
# 28           /es/pelicula/superdetective-en-hollywood
# 29                      /es/pelicula/la-novena-puerta
#
#                          poster  \
# 0   /poster/259379170/{profile}
# 1   /poster/248781262/{profile}
# 2   /poster/127021459/{profile}
# 3   /poster/135971272/{profile}
# 4   /poster/255241071/{profile}
# 5    /poster/85019324/{profile}
# 6   /poster/207108814/{profile}
# 7   /poster/245233793/{profile}
# 8   /poster/152515134/{profile}
# 9   /poster/198869904/{profile}
# 10  /poster/100768291/{profile}
# 11  /poster/272327055/{profile}
# 12  /poster/227577090/{profile}
# 13  /poster/107883442/{profile}
# 14  /poster/205566863/{profile}
# 15   /poster/77913152/{profile}
# 16   /poster/12414320/{profile}
# 17   /poster/10382158/{profile}
# 18  /poster/268347634/{profile}
# 19  /poster/263861413/{profile}
# 20  /poster/101683739/{profile}
# 21  /poster/122924039/{profile}
# 22   /poster/10488264/{profile}
# 23  /poster/127948063/{profile}
# 24  /poster/242968219/{profile}
# 25  /poster/127059403/{profile}
# 26  /poster/209156331/{profile}
# 27  /poster/146555909/{profile}
# 28  /poster/179752804/{profile}
# 29  /poster/252088882/{profile}
#
#                                     short_description  original_release_year  \
# 0   Drac y la pandilla vuelven, como nunca los hab...                   2022
# 1   Drácula regenta un hotel en el que se alojan p...                   2012
# 2   Nuestra familia de monstruos favorita se embar...                   2018
# 3   Todo parece mejorar en el Hotel Transilvania. ...                   2015
# 4   El Sr. Gustave H., un legendario conserje de u...                   2014
# 5   Un grupo de ancianos ingleses deciden disfruta...                   2011
# 6   Narra la historia de dos huérfanos adolescente...                   2009
# 7   En ‘Mascotas Monstruosas’, Pipis, el adorable ...                   2021
# 8   Los Ángeles, año 2028. El Hotel Artemis es un ...                   2018
# 9   Lucy Honey Church una joven inglesa de buena f...                   1985
# 10  El Hotel Marigold, segundo lugar más exótico e...                   2015
# 11  Vuelven las pesquisas del célebre detective Hé...                   2022
# 12  More than two hundred thousand women work as m...                   2018
# 13  A las órdenes de sus misteriosos jefes de Orie...                   1956
# 14  James Bond se encuentra disfrutando de unas me...                   2020
# 15  Han pasado dos décadas desde que se encontraro...                   2013
# 16  Described as “a nightmare version of Cheers” (...                   2016
# 17  Barcelona, España. Adrián Doria, un joven y ex...                   2017
# 18  Un buscavidas se compincha con una pitonisa pa...                   2021
# 19  Cuatro historias independientes con un escenar...                   2012
# 20  Cinco años después de una inexplicada tragedia...                   2015
# 21  La Mayor Susan Turner, líder de la antigua uni...                   2016
# 22  Royal Tenenbaum (Gene Hackman) y su mujer Ethe...                   2001
# 23  Arnold (Owen Wilson) tiene una vida perfecta: ...                   2015
# 24  Aunque ya está retirado, Bryan Mills se ve obl...                   2012
# 25  Una chica (Emilia Clarke) de una pequeña pobla...                   2016
# 26  En su casa en un país del sudeste asiático, un...                   2015
# 27  Dos artistas del engaño, una de clase alta y l...                   2019
# 28  Axel Foley es un impetuoso e inteligente detec...                   1984
# 29  Dean Corso (Johnny Depp) trabaja de forma conf...                   1999
#
#    object_type                             originalTitle  \
# 0        movie         Hotel Transylvania: Transformania
# 1        movie                        Hotel Transylvania
# 2        movie     Hotel Transylvania 3: Summer Vacation
# 3        movie                      Hotel Transylvania 2
# 4        movie                  The Grand Budapest Hotel
# 5        movie            The Best Exotic Marigold Hotel
# 6        movie                            Hotel for Dogs
# 7        movie  Monster Pets: A Hotel Transylvania Short
# 8        movie                             Hotel Artemis
# 9        movie                        A Room with a View
# 10       movie     The Second Best Exotic Marigold Hotel
# 11       movie                         Death on the Nile
# 12       movie             Hotel Explotación: Las Kellys
# 13       movie                             The Green Man
# 14       movie                            No Time to Die
# 15       movie                           Before Midnight
# 16       movie                          Hotel Coolgardie
# 17       movie                              Contratiempo
# 18       movie                           Nightmare Alley
# 19       movie                         To Rome with Love
# 20       movie                            Hell House LLC
# 21       movie               Jack Reacher: Never Go Back
# 22       movie                      The Royal Tenenbaums
# 23       movie                      She's Funny That Way
# 24       movie                                   Taken 2
# 25       movie                             Me Before You
# 26       movie                                 No Escape
# 27       movie                                The Hustle
# 28       movie                         Beverly Hills Cop
# 29       movie                            The Ninth Gate
#
#                                                offers  \
# 0   [{'jw_entity_id': 'tm460828', 'monetization_ty...
# 1   [{'jw_entity_id': 'tm69164', 'monetization_typ...
# 2   [{'jw_entity_id': 'tm244157', 'monetization_ty...
# 3   [{'jw_entity_id': 'tm132278', 'monetization_ty...
# 4   [{'jw_entity_id': 'tm162843', 'monetization_ty...
# 5   [{'jw_entity_id': 'tm176016', 'monetization_ty...
# 6   [{'jw_entity_id': 'tm135121', 'monetization_ty...
# 7   [{'jw_entity_id': 'tm1031933', 'monetization_t...
# 8   [{'jw_entity_id': 'tm244366', 'monetization_ty...
# 9   [{'jw_entity_id': 'tm128879', 'monetization_ty...
# 10  [{'jw_entity_id': 'tm138793', 'monetization_ty...
# 11  [{'jw_entity_id': 'tm372685', 'monetization_ty...
# 12  [{'jw_entity_id': 'tm823136', 'monetization_ty...
# 13  [{'jw_entity_id': 'tm96276', 'monetization_typ...
# 14  [{'jw_entity_id': 'tm232799', 'monetization_ty...
# 15  [{'jw_entity_id': 'tm181889', 'monetization_ty...
# 16  [{'jw_entity_id': 'tm243264', 'monetization_ty...
# 17  [{'jw_entity_id': 'tm267401', 'monetization_ty...
# 18  [{'jw_entity_id': 'tm855362', 'monetization_ty...
# 19  [{'jw_entity_id': 'tm65295', 'monetization_typ...
# 20  [{'jw_entity_id': 'tm224498', 'monetization_ty...
# 21  [{'jw_entity_id': 'tm218129', 'monetization_ty...
# 22  [{'jw_entity_id': 'tm49864', 'monetization_typ...
# 23  [{'jw_entity_id': 'tm142571', 'monetization_ty...
# 24  [{'jw_entity_id': 'tm57798', 'monetization_typ...
# 25  [{'jw_entity_id': 'tm138369', 'monetization_ty...
# 26  [{'jw_entity_id': 'tm137702', 'monetization_ty...
# 27  [{'jw_entity_id': 'tm370650', 'monetization_ty...
# 28  [{'jw_entity_id': 'tm172251', 'monetization_ty...
# 29  [{'jw_entity_id': 'tm47174', 'monetization_typ...
#
#                                              upcoming age_certification  \
# 0   [{'package_id': 119, 'release_window_from': '2...                 7
# 1                                                 NaN              APTA
# 2                                                 NaN              APTA
# 3                                                 NaN              APTA
# 4                                                 NaN                12
# 5                                                 NaN              APTA
# 6                                                 NaN              APTA
# 7                                                 NaN              APTA
# 8                                                 NaN                12
# 9                                                 NaN               NaN
# 10                                                NaN               NaN
# 11  [{'package_id': 337, 'release_window_from': '2...                12
# 12                                                NaN              APTA
# 13                                                NaN               NaN
# 14  [{'package_id': 252, 'release_window_from': '2...                12
# 15                                                NaN                 7
# 16                                                NaN               NaN
# 17                                                NaN                12
# 18  [{'package_id': 0, 'release_window_from': '202...                16
# 19                                                NaN              APTA
# 20                                                NaN               NaN
# 21                                                NaN                12
# 22                                                NaN               NaN
# 23                                                NaN                 7
# 24                                                NaN                12
# 25                                                NaN                12
# 26                                                NaN                16
# 27                                                NaN                 7
# 28                                                NaN                12
# 29                                                NaN                12
#
#     runtime production_countries
# 0        87                 [US]
# 1        91                 [US]
# 2        97                 [US]
# 3        89                 [US]
# 4       101             [US, DE]
# 5       124         [AE, GB, US]
# 6       100                 [US]
# 7         6                 [US]
# 8        94             [GB, US]
# 9       117                 [GB]
# 10      122             [GB, US]
# 11      127             [US, GB]
# 12       55                 [ES]
# 13       80                 [GB]
# 14      163             [GB, US]
# 15      109             [GR, US]
# 16       84                 [AU]
# 17      107                 [ES]
# 18      150                 [US]
# 19      111         [IT, ES, US]
# 20       93                 [US]
# 21      118             [US, CN]
# 22      109                 [US]
# 23       93             [US, DE]
# 24       91                 [FR]
# 25      110                 [US]
# 26      103                 [US]
# 27       93                 [US]
# 28      105                 [US]
# 29      133             [ES, FR]

# %%
recommend = pd.read_csv('../data/recommend.csv')
recommend
# Out:
#                          tconst  averageRating  numVotes  \
# 0     imdb.com/title/tt15097216            9.4    185162
# 1      imdb.com/title/tt0252487            9.3     39990
# 2      imdb.com/title/tt0111161            9.3   2572812
# 3      imdb.com/title/tt5354160            9.2     25759
# 4     imdb.com/title/tt10189514            9.2    109309
# ...                         ...            ...       ...
# 2546   imdb.com/title/tt0099763            7.0     35438
# 2547   imdb.com/title/tt6324278            7.0     37215
# 2548   imdb.com/title/tt0061747            7.0     38612
# 2549  imdb.com/title/tt10083340            7.0     38248
# 2550   imdb.com/title/tt0048750            7.0     37818
#
#                             primaryTitle                       originalTitle  \
# 0                               Jai Bhim                            Jai Bhim
# 1                        The Chaos Class                      Hababam Sinifi
# 2               The Shawshank Redemption            The Shawshank Redemption
# 3                            Mirror Game                            Aynabaji
# 4                        Soorarai Pottru                     Soorarai Pottru
# ...                                  ...                                 ...
# 2546  Henry: Portrait of a Serial Killer  Henry: Portrait of a Serial Killer
# 2547                          Abominable                          Abominable
# 2548                       Hang 'Em High                       Hang 'Em High
# 2549                 Gangubai Kathiawadi                 Gangubai Kathiawadi
# 2550              The Trouble with Harry              The Trouble with Harry
#
#       startYear  runtimeMinutes                      genres
# 0          2021             164         Crime,Drama,Mystery
# 1          1975              87                Comedy,Drama
# 2          1994             142                       Drama
# 3          2016             147      Crime,Mystery,Thriller
# 4          2020             153                       Drama
# ...         ...             ...                         ...
# 2546       1986              83       Biography,Crime,Drama
# 2547       2019              97  Adventure,Animation,Comedy
# 2548       1968             114               Drama,Western
# 2549       2022             152       Biography,Crime,Drama
# 2550       1955              99              Comedy,Mystery
#
# [2551 rows x 8 columns]

# %%
my_recommendation = pd.merge(recommend, table_col, how='inner', on=['originalTitle'], left_on=None, right_on=None,
left_index=False, right_index=False, sort=True)
my_recommendation
# Out:
#                       tconst  averageRating  numVotes  \
# 0   imdb.com/title/tt0091867            7.2     43082
# 1   imdb.com/title/tt2209418            7.9    153518
# 2   imdb.com/title/tt0086960            7.3    179380
# 3   imdb.com/title/tt4857264            8.0    169470
# 4   imdb.com/title/tt0077413            7.2     33227
# 5   imdb.com/title/tt0837562            7.0    247946
# 6   imdb.com/title/tt2674426            7.4    241130
# 7   imdb.com/title/tt7740496            7.1    109132
# 8   imdb.com/title/tt2382320            7.3    337764
# 9   imdb.com/title/tt1412386            7.2     94380
# 10  imdb.com/title/tt2278388            8.1    777120
# 11  imdb.com/title/tt0265666            7.6    286594
#
#                       primaryTitle                   originalTitle  startYear  \
# 0               A Room with a View              A Room with a View       1985
# 1                  Before Midnight                 Before Midnight       2013
# 2                Beverly Hills Cop               Beverly Hills Cop       1984
# 3              The Invisible Guest                    Contratiempo       2016
# 4                Death on the Nile               Death on the Nile       1978
# 5               Hotel Transylvania              Hotel Transylvania       2012
# 6                    Me Before You                   Me Before You       2016
# 7                  Nightmare Alley                 Nightmare Alley       2021
# 8                   No Time to Die                  No Time to Die       2021
# 9   The Best Exotic Marigold Hotel  The Best Exotic Marigold Hotel       2011
# 10        The Grand Budapest Hotel        The Grand Budapest Hotel       2014
# 11            The Royal Tenenbaums            The Royal Tenenbaums       2001
#
#     runtimeMinutes                     genres jw_entity_id      id  ...  \
# 0              117              Drama,Romance     tm128879  128879  ...
# 1              109              Drama,Romance     tm181889  181889  ...
# 2              105        Action,Comedy,Crime     tm172251  172251  ...
# 3              106        Crime,Drama,Mystery     tm267401  267401  ...
# 4              140        Crime,Drama,Mystery     tm372685  372685  ...
# 5               91    Animation,Comedy,Family      tm69164   69164  ...
# 6              106              Drama,Romance     tm138369  138369  ...
# 7              150       Crime,Drama,Thriller     tm855362  855362  ...
# 8              163  Action,Adventure,Thriller     tm232799  232799  ...
# 9              124       Comedy,Drama,Romance     tm176016  176016  ...
# 10              99     Adventure,Comedy,Crime     tm162843  162843  ...
# 11             110               Comedy,Drama      tm49864   49864  ...
#
#                                             full_path  \
# 0              /es/pelicula/una-habitacion-con-vistas
# 1                    /es/pelicula/antes-del-anochecer
# 2            /es/pelicula/superdetective-en-hollywood
# 3                           /es/pelicula/contratiempo
# 4                 /es/pelicula/muerte-en-el-nilo-2022
# 5                     /es/pelicula/hotel-transilvania
# 6                            /es/pelicula/antes-de-ti
# 7                        /es/pelicula/nightmare-alley
# 8                  /es/pelicula/sin-tiempo-para-morir
# 9              /es/pelicula/el-exotico-hotel-marigold
# 10                /es/pelicula/el-gran-hotel-budapest
# 11  /es/pelicula/los-tenenbaums-una-familia-de-genios
#
#                          poster  \
# 0   /poster/198869904/{profile}
# 1    /poster/77913152/{profile}
# 2   /poster/179752804/{profile}
# 3    /poster/10382158/{profile}
# 4   /poster/272327055/{profile}
# 5   /poster/248781262/{profile}
# 6   /poster/127059403/{profile}
# 7   /poster/268347634/{profile}
# 8   /poster/205566863/{profile}
# 9    /poster/85019324/{profile}
# 10  /poster/255241071/{profile}
# 11   /poster/10488264/{profile}
#
#                                     short_description original_release_year  \
# 0   Lucy Honey Church una joven inglesa de buena f...                  1985
# 1   Han pasado dos décadas desde que se encontraro...                  2013
# 2   Axel Foley es un impetuoso e inteligente detec...                  1984
# 3   Barcelona, España. Adrián Doria, un joven y ex...                  2017
# 4   Vuelven las pesquisas del célebre detective Hé...                  2022
# 5   Drácula regenta un hotel en el que se alojan p...                  2012
# 6   Una chica (Emilia Clarke) de una pequeña pobla...                  2016
# 7   Un buscavidas se compincha con una pitonisa pa...                  2021
# 8   James Bond se encuentra disfrutando de unas me...                  2020
# 9   Un grupo de ancianos ingleses deciden disfruta...                  2011
# 10  El Sr. Gustave H., un legendario conserje de u...                  2014
# 11  Royal Tenenbaum (Gene Hackman) y su mujer Ethe...                  2001
#
#     object_type                                             offers  \
# 0         movie  [{'jw_entity_id': 'tm128879', 'monetization_ty...
# 1         movie  [{'jw_entity_id': 'tm181889', 'monetization_ty...
# 2         movie  [{'jw_entity_id': 'tm172251', 'monetization_ty...
# 3         movie  [{'jw_entity_id': 'tm267401', 'monetization_ty...
# 4         movie  [{'jw_entity_id': 'tm372685', 'monetization_ty...
# 5         movie  [{'jw_entity_id': 'tm69164', 'monetization_typ...
# 6         movie  [{'jw_entity_id': 'tm138369', 'monetization_ty...
# 7         movie  [{'jw_entity_id': 'tm855362', 'monetization_ty...
# 8         movie  [{'jw_entity_id': 'tm232799', 'monetization_ty...
# 9         movie  [{'jw_entity_id': 'tm176016', 'monetization_ty...
# 10        movie  [{'jw_entity_id': 'tm162843', 'monetization_ty...
# 11        movie  [{'jw_entity_id': 'tm49864', 'monetization_typ...
#
#                                              upcoming age_certification  \
# 0                                                 NaN               NaN
# 1                                                 NaN                 7
# 2                                                 NaN                12
# 3                                                 NaN                12
# 4   [{'package_id': 337, 'release_window_from': '2...                12
# 5                                                 NaN              APTA
# 6                                                 NaN                12
# 7   [{'package_id': 0, 'release_window_from': '202...                16
# 8   [{'package_id': 252, 'release_window_from': '2...                12
# 9                                                 NaN              APTA
# 10                                                NaN                12
# 11                                                NaN               NaN
#
#    runtime  production_countries
# 0      117                  [GB]
# 1      109              [GR, US]
# 2      105                  [US]
# 3      107                  [ES]
# 4      127              [US, GB]
# 5       91                  [US]
# 6      110                  [US]
# 7      150                  [US]
# 8      163              [GB, US]
# 9      124          [AE, GB, US]
# 10     101              [US, DE]
# 11     109                  [US]
#
# [12 rows x 21 columns]
